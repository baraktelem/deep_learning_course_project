# %%
import sys, os
from pathlib import Path

IS_KAGGLE = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '') != ''

if IS_KAGGLE:
    # Install packages not available on Kaggle
    # %pip install -q kymatio kornia
    
    # Add repo to path (UPDATE 'deep-learning-course-project' to your dataset slug)
    repo_path = Path('/kaggle/input/d/giladnavok/deep-learning-course-project/')
    if repo_path.exists():
        sys.path.insert(0, str(repo_path))
else:
    # Local: add project root to path (assumes notebook is in notebooks/)
    project_root = Path.cwd().parent
    if (project_root / 'src').exists():
        sys.path.insert(0, str(project_root))

from src.utils.config import *
from src.utils.datasets import *
from src.models.architectures.AdditiveHybridGaborResNet18 import *
from src.utils.training import *
from src.utils.visualization import *

from typing import Dict
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 6.5 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.
# ====================== Hyperparameters =======================
# N_EPOCHS: 200
# T_MAX: 200
# CRITERION: CrossEntropyLoss()
# DEVICE: cuda
# SEED: 42
# BATCH_SIZE: 128
# LR: 0.001
# MOMENTUM: 0.9
# WEIGHT_DECAY: 0.0001
# ================================================================
# Setting seed to 42

# %%
DEBUG = False
SKIP_TRAINING = False
EXP_NAME = "maxhybridgabor_acc_layers_vs_n_samples"
print(f"Starting experiment {EXP_NAME}. DEBUG={DEBUG}, SKIP_TRAINING={SKIP_TRAINING}")

device = DEVICE

layers = [5]
n_samples_per_class_train = [10, 50, 100, 200, 300, 400, 500, 1000]
# Out:
# Starting experiment maxhybridgabor_acc_layers_vs_n_samples. DEBUG=False, SKIP_TRAINING=False

# %%
# Train and save model for each data size
test_accs_L : dict[int, float] = {}
for L in layers:
    test_accs : dict[int, float] = {}
    for n_samples in n_samples_per_class_train:
        # Initialize model
        model = MakeAdditiveHybridGaborResNet18(L=L).to(device)
        MODEL_NAME = f"AdditiveHybridGaborResNet18_L{L}_{n_samples}"
    
        total_params, model_size_mb = get_model_summary(model)
        print(f"Total Parameters: {total_params:,}")
        print(f"Model Size: {model_size_mb:.2f} MB")
    
        # Get data loaders
        trainloader, valloader, testloader, train_set, val_set, test_set = get_cifar10_loaders_and_splits(
        n_samples_per_class_train=n_samples
        )
        optimizer, scheduler = get_optimizer_and_scheduler(model, optimizer_type='sgd-hybrid-gabor')
    
        # Train model on n_samples
        if not SKIP_TRAINING:
            train_model(
                model=model,
                trainloader=trainloader,
                valloader=valloader,
                optimizer=optimizer,
                scheduler=scheduler,
                device=device,
                experiment_name=EXP_NAME,
                model_name=MODEL_NAME,
                val_accuracy_storing_threshold=0,
                print_progress_every=50,
                DEBUG=DEBUG
            )
    
            # Save accuracy on test set
            debug_suff = "_DEBUG" if DEBUG else ""
            load_weights(model, experiment_name=EXP_NAME, model_name=(MODEL_NAME+ debug_suff), device=device)
            test_acc = calculate_accuracy(model, testloader, device)
            test_accs[n_samples] = test_acc
            print(f'Final test accuracy is: {test_acc:.3f}')
            
        test_accs_L[L] = test_accs
# Out:
# Total Parameters: 11,275,216
# Model Size: 43.01 MB
# 100%|██████████| 170M/170M [00:12<00:00, 13.9MB/s]
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 100
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(8): 10, np.int64(7): 10, np.int64(4): 10, np.int64(3): 10, np.int64(5): 10, np.int64(6): 10, np.int64(1): 10, np.int64(2): 10, np.int64(0): 10, np.int64(9): 10})
# Samples per class (val): Counter({np.int64(3): 500, np.int64(6): 500, np.int64(7): 500, np.int64(0): 500, np.int64(5): 500, np.int64(1): 500, np.int64(8): 500, np.int64(9): 500, np.int64(4): 500, np.int64(2): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_10.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_10.pkl
#
# === Starting Training: AdditiveHybridGaborResNet18_L5_10 with 200 epochs ===
#     --> New Best Saved: 10.00%
# Epoch 1/200 | Loss: 2.325 | Val Acc: 10.00%
# Epoch 51/200 | Loss: 0.123 | Val Acc: 17.88%
# Epoch 101/200 | Loss: 0.009 | Val Acc: 23.68%
# Epoch 151/200 | Loss: 0.003 | Val Acc: 25.74%
# === Finished AdditiveHybridGaborResNet18_L5_10. Total Time: 1759.1s ===
# Final test accuracy is: 25.250
# Total Parameters: 11,275,216
# Model Size: 43.01 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 500
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(3): 50, np.int64(0): 50, np.int64(8): 50, np.int64(7): 50, np.int64(2): 50, np.int64(1): 50, np.int64(6): 50, np.int64(4): 50, np.int64(5): 50, np.int64(9): 50})
# Samples per class (val): Counter({np.int64(2): 500, np.int64(4): 500, np.int64(1): 500, np.int64(3): 500, np.int64(6): 500, np.int64(0): 500, np.int64(9): 500, np.int64(5): 500, np.int64(7): 500, np.int64(8): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_50.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_50.pkl
#
# === Starting Training: AdditiveHybridGaborResNet18_L5_50 with 200 epochs ===
#     --> New Best Saved: 10.00%
# Epoch 1/200 | Loss: 3.657 | Val Acc: 10.00%
# Epoch 51/200 | Loss: 0.345 | Val Acc: 42.56%
# Epoch 101/200 | Loss: 0.202 | Val Acc: 42.24%
# Epoch 151/200 | Loss: 0.007 | Val Acc: 46.60%
# === Finished AdditiveHybridGaborResNet18_L5_50. Total Time: 2177.4s ===
# Final test accuracy is: 46.270
# Total Parameters: 11,275,216
# Model Size: 43.01 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 1000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 100, np.int64(1): 100, np.int64(8): 100, np.int64(4): 100, np.int64(3): 100, np.int64(9): 100, np.int64(5): 100, np.int64(0): 100, np.int64(2): 100, np.int64(6): 100})
# Samples per class (val): Counter({np.int64(1): 500, np.int64(9): 500, np.int64(2): 500, np.int64(4): 500, np.int64(6): 500, np.int64(5): 500, np.int64(0): 500, np.int64(3): 500, np.int64(8): 500, np.int64(7): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_100.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_100.pkl
#
# === Starting Training: AdditiveHybridGaborResNet18_L5_100 with 200 epochs ===
#     --> New Best Saved: 10.44%
# Epoch 1/200 | Loss: 3.307 | Val Acc: 10.44%
# Epoch 51/200 | Loss: 0.466 | Val Acc: 48.98%
#     --> New Best Saved: 55.92%
# Epoch 101/200 | Loss: 0.049 | Val Acc: 55.92%
# Epoch 151/200 | Loss: 0.018 | Val Acc: 56.84%
# === Finished AdditiveHybridGaborResNet18_L5_100. Total Time: 2705.6s ===
# Final test accuracy is: 58.460
# Total Parameters: 11,275,216
# Model Size: 43.01 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 2000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(6): 200, np.int64(2): 200, np.int64(8): 200, np.int64(5): 200, np.int64(7): 200, np.int64(4): 200, np.int64(9): 200, np.int64(3): 200, np.int64(1): 200, np.int64(0): 200})
# Samples per class (val): Counter({np.int64(2): 500, np.int64(9): 500, np.int64(5): 500, np.int64(6): 500, np.int64(0): 500, np.int64(7): 500, np.int64(3): 500, np.int64(4): 500, np.int64(8): 500, np.int64(1): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_200.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_200.pkl
#
# === Starting Training: AdditiveHybridGaborResNet18_L5_200 with 200 epochs ===
#     --> New Best Saved: 10.20%
# Epoch 1/200 | Loss: 3.454 | Val Acc: 10.20%
# Epoch 51/200 | Loss: 0.242 | Val Acc: 62.04%
# Epoch 101/200 | Loss: 0.062 | Val Acc: 65.90%
# Epoch 151/200 | Loss: 0.018 | Val Acc: 67.58%
# === Finished AdditiveHybridGaborResNet18_L5_200. Total Time: 3755.3s ===
# Final test accuracy is: 68.980
# Total Parameters: 11,275,216
# Model Size: 43.01 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 3000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 300, np.int64(0): 300, np.int64(6): 300, np.int64(4): 300, np.int64(9): 300, np.int64(3): 300, np.int64(8): 300, np.int64(5): 300, np.int64(1): 300, np.int64(2): 300})
# Samples per class (val): Counter({np.int64(7): 500, np.int64(2): 500, np.int64(5): 500, np.int64(9): 500, np.int64(4): 500, np.int64(0): 500, np.int64(8): 500, np.int64(6): 500, np.int64(3): 500, np.int64(1): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_300.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_300.pkl
#
# === Starting Training: AdditiveHybridGaborResNet18_L5_300 with 200 epochs ===
#     --> New Best Saved: 11.68%
# Epoch 1/200 | Loss: 2.932 | Val Acc: 11.68%
# Epoch 51/200 | Loss: 0.247 | Val Acc: 65.40%
# Epoch 101/200 | Loss: 0.063 | Val Acc: 69.46%
# Epoch 151/200 | Loss: 0.006 | Val Acc: 71.72%
# === Finished AdditiveHybridGaborResNet18_L5_300. Total Time: 4802.6s ===
# Final test accuracy is: 72.710
# Total Parameters: 11,275,216
# Model Size: 43.01 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 4000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 400, np.int64(6): 400, np.int64(5): 400, np.int64(0): 400, np.int64(1): 400, np.int64(4): 400, np.int64(8): 400, np.int64(2): 400, np.int64(3): 400, np.int64(9): 400})
# Samples per class (val): Counter({np.int64(4): 500, np.int64(6): 500, np.int64(9): 500, np.int64(5): 500, np.int64(3): 500, np.int64(7): 500, np.int64(0): 500, np.int64(1): 500, np.int64(2): 500, np.int64(8): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_400.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_400.pkl
#
# === Starting Training: AdditiveHybridGaborResNet18_L5_400 with 200 epochs ===
#     --> New Best Saved: 25.58%
# Epoch 1/200 | Loss: 2.655 | Val Acc: 25.58%
# Epoch 51/200 | Loss: 0.253 | Val Acc: 70.38%
# Epoch 101/200 | Loss: 0.050 | Val Acc: 73.78%
# Epoch 151/200 | Loss: 0.013 | Val Acc: 76.00%
# === Finished AdditiveHybridGaborResNet18_L5_400. Total Time: 5837.8s ===
# Final test accuracy is: 76.120
# Total Parameters: 11,275,216
# Model Size: 43.01 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 5000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(4): 500, np.int64(7): 500, np.int64(3): 500, np.int64(1): 500, np.int64(2): 500, np.int64(8): 500, np.int64(5): 500, np.int64(0): 500, np.int64(9): 500, np.int64(6): 500})
# Samples per class (val): Counter({np.int64(5): 500, np.int64(8): 500, np.int64(2): 500, np.int64(9): 500, np.int64(1): 500, np.int64(3): 500, np.int64(0): 500, np.int64(6): 500, np.int64(7): 500, np.int64(4): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_500.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_500.pkl
#
# === Starting Training: AdditiveHybridGaborResNet18_L5_500 with 200 epochs ===
#     --> New Best Saved: 20.66%
# Epoch 1/200 | Loss: 2.688 | Val Acc: 20.66%
#     --> New Best Saved: 71.56%
# Epoch 51/200 | Loss: 0.494 | Val Acc: 71.56%
# Epoch 101/200 | Loss: 0.206 | Val Acc: 73.12%
# Epoch 151/200 | Loss: 0.034 | Val Acc: 75.82%
# === Finished AdditiveHybridGaborResNet18_L5_500. Total Time: 6901.9s ===
# Final test accuracy is: 77.970
# Total Parameters: 11,275,216
# Model Size: 43.01 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 10000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 1000, np.int64(2): 1000, np.int64(3): 1000, np.int64(9): 1000, np.int64(6): 1000, np.int64(8): 1000, np.int64(5): 1000, np.int64(0): 1000, np.int64(4): 1000, np.int64(1): 1000})
# Samples per class (val): Counter({np.int64(0): 500, np.int64(2): 500, np.int64(7): 500, np.int64(8): 500, np.int64(3): 500, np.int64(1): 500, np.int64(5): 500, np.int64(4): 500, np.int64(9): 500, np.int64(6): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_1000.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/maxhybridgabor_acc_layers_vs_n_samples_AdditiveHybridGaborResNet18_L5_1000.pkl
#
# === Starting Training: AdditiveHybridGaborResNet18_L5_1000 with 200 epochs ===
#     --> New Best Saved: 34.20%
# Epoch 1/200 | Loss: 2.184 | Val Acc: 34.20%
# Epoch 51/200 | Loss: 0.252 | Val Acc: 75.04%
# Epoch 101/200 | Loss: 0.113 | Val Acc: 78.70%
# Epoch 151/200 | Loss: 0.014 | Val Acc: 84.50%
# === Finished AdditiveHybridGaborResNet18_L5_1000. Total Time: 12164.3s ===
# Final test accuracy is: 85.560

# %%
# Plot accuracy vs data size
plt.figure(figsize=(10, 5))
for L in layers:
    plt.plot(list(test_accs_L[L].keys()), list(test_accs_L[L].values()), marker='o', linestyle='-')
    
plt.xlabel('Number of Training Samples per Class')
plt.ylabel('Test Accuracy')
plt.xscale('log')
plt.title('Accuracy vs Number of Training Samples per Class')
plt.grid(True)
if not SKIP_TRAINING:
    plt.savefig(FIGURES_PATH / 'maxhybridgabor_acc_layers_vs_n_samples.png')
plt.show()
