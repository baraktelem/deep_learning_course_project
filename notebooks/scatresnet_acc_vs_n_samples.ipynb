# %%
import sys, os
from pathlib import Path

IS_KAGGLE = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '') != ''

if IS_KAGGLE:
    # Install packages not available on Kaggle
    # %pip install -q kymatio kornia
    
    # Add repo to path (UPDATE 'deep-learning-course-project' to your dataset slug)
    repo_path = Path('/kaggle/input/deep-learning-course-project')
    if repo_path.exists():
        sys.path.insert(0, str(repo_path))
else:
    # Local: add project root to path (assumes notebook is in notebooks/)
    project_root = Path.cwd().parent
    if (project_root / 'src').exists():
        sys.path.insert(0, str(project_root))

from src.utils.config import *
from src.utils.datasets import *
from src.models.architectures.RestNet18 import *
from src.models.architectures.ScatNet18 import *
from src.utils.training import *
from src.utils.visualization import *

from typing import Dict
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 5.6 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.
# ====================== Hyperparameters =======================
# N_EPOCHS: 200
# T_MAX: 200
# CRITERION: CrossEntropyLoss()
# DEVICE: cuda
# SEED: 42
# BATCH_SIZE: 128
# LR: 0.001
# MOMENTUM: 0.9
# WEIGHT_DECAY: 0.0001
# ================================================================
# Setting seed to 42

# %%
DEBUG = False
SKIP_TRAINING = False
EXP_NAME = "scatresnet_acc_vs_n_samples"
print(f"Starting experiment {EXP_NAME}. DEBUG={DEBUG}, SKIP_TRAINING={SKIP_TRAINING}")

device = DEVICE

L = 10 # Gave best results for 100 & 4000 samples per class
n_samples_per_class_train = [10, 50, 100, 200, 300, 400, 500, 1000, 4000]
# Out:
# Starting experiment scatresnet_acc_vs_n_samples. DEBUG=False, SKIP_TRAINING=False

# %%
test_accs : dict[int, float] = {}

# Train and save model for each data size
for n_samples in n_samples_per_class_train:
    # Initialize model
    scatresnet = MakeScatResNet18(L=L).to(device)
    MODEL_NAME = f"ScatResNet18_{n_samples}"

    total_params, model_size_mb = get_model_summary(scatresnet)
    print(f"Total Parameters: {total_params:,}")
    print(f"Model Size: {model_size_mb:.2f} MB")

    # Get data loaders
    trainloader, valloader, testloader, train_set, val_set, test_set = get_cifar10_loaders_and_splits(
    n_samples_per_class_train=n_samples
    )
    scatresnet_optimizer, scatresnet_scheduler = get_optimizer_and_scheduler(scatresnet)

    if not SKIP_TRAINING:
        train_model(
            model=scatresnet,
            trainloader=trainloader,
            valloader=valloader,
            optimizer=scatresnet_optimizer,
            scheduler=scatresnet_scheduler,
            device=device,
            experiment_name=EXP_NAME,
            model_name=MODEL_NAME,
            val_accuracy_storing_threshold=0,
            print_progress_every=50,
            DEBUG=DEBUG
        )

        # Save accuracy on test set
        debug_suff = "_DEBUG" if DEBUG else ""
        load_weights(scatresnet, experiment_name=EXP_NAME, model_name=(MODEL_NAME+ debug_suff), device=device)
        test_acc = calculate_accuracy(scatresnet, testloader, device)
        test_accs[n_samples] = test_acc
        print(f'Final test accuracy is: {test_acc:.3f}')
# Out:
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# 100%|██████████| 170M/170M [00:12<00:00, 13.7MB/s]
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 100
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(8): 10, np.int64(7): 10, np.int64(4): 10, np.int64(3): 10, np.int64(5): 10, np.int64(6): 10, np.int64(1): 10, np.int64(2): 10, np.int64(0): 10, np.int64(9): 10})
# Samples per class (val): Counter({np.int64(3): 500, np.int64(6): 500, np.int64(7): 500, np.int64(0): 500, np.int64(5): 500, np.int64(1): 500, np.int64(8): 500, np.int64(9): 500, np.int64(4): 500, np.int64(2): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/scatresnet_acc_vs_n_samples_ScatResNet18_10.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/scatresnet_acc_vs_n_samples_ScatResNet18_10.pkl
#
# === Starting Training: ScatResNet18_10 with 200 epochs ===
#     --> New Best Saved: 10.00%
# Epoch 1/200 | Loss: 2.392 | Val Acc: 10.00%
# Epoch 51/200 | Loss: 0.396 | Val Acc: 13.66%
# Epoch 101/200 | Loss: 0.248 | Val Acc: 25.82%
# Epoch 151/200 | Loss: 0.003 | Val Acc: 27.08%
# === Finished ScatResNet18_10. Total Time: 407.0s ===
# Final test accuracy is: 27.450
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 500
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(3): 50, np.int64(0): 50, np.int64(8): 50, np.int64(7): 50, np.int64(2): 50, np.int64(1): 50, np.int64(6): 50, np.int64(4): 50, np.int64(5): 50, np.int64(9): 50})
# Samples per class (val): Counter({np.int64(2): 500, np.int64(4): 500, np.int64(1): 500, np.int64(3): 500, np.int64(6): 500, np.int64(0): 500, np.int64(9): 500, np.int64(5): 500, np.int64(7): 500, np.int64(8): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/scatresnet_acc_vs_n_samples_ScatResNet18_50.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/scatresnet_acc_vs_n_samples_ScatResNet18_50.pkl
#
# === Starting Training: ScatResNet18_50 with 200 epochs ===
#     --> New Best Saved: 11.66%
# Epoch 1/200 | Loss: 3.173 | Val Acc: 11.66%
# Epoch 51/200 | Loss: 0.697 | Val Acc: 37.90%
# Epoch 101/200 | Loss: 0.105 | Val Acc: 43.48%
# Epoch 151/200 | Loss: 0.064 | Val Acc: 46.52%
# === Finished ScatResNet18_50. Total Time: 472.1s ===
# Final test accuracy is: 46.640
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 1000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 100, np.int64(1): 100, np.int64(8): 100, np.int64(4): 100, np.int64(3): 100, np.int64(9): 100, np.int64(5): 100, np.int64(0): 100, np.int64(2): 100, np.int64(6): 100})
# Samples per class (val): Counter({np.int64(1): 500, np.int64(9): 500, np.int64(2): 500, np.int64(4): 500, np.int64(6): 500, np.int64(5): 500, np.int64(0): 500, np.int64(3): 500, np.int64(8): 500, np.int64(7): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/scatresnet_acc_vs_n_samples_ScatResNet18_100.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/scatresnet_acc_vs_n_samples_ScatResNet18_100.pkl
#
# === Starting Training: ScatResNet18_100 with 200 epochs ===
#     --> New Best Saved: 10.00%
# Epoch 1/200 | Loss: 4.358 | Val Acc: 10.00%
# Epoch 51/200 | Loss: 0.461 | Val Acc: 50.18%
# Epoch 101/200 | Loss: 0.036 | Val Acc: 55.14%
# Epoch 151/200 | Loss: 0.021 | Val Acc: 57.02%
# === Finished ScatResNet18_100. Total Time: 561.4s ===
# Final test accuracy is: 57.760
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 2000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(6): 200, np.int64(2): 200, np.int64(8): 200, np.int64(5): 200, np.int64(7): 200, np.int64(4): 200, np.int64(9): 200, np.int64(3): 200, np.int64(1): 200, np.int64(0): 200})
# Samples per class (val): Counter({np.int64(2): 500, np.int64(9): 500, np.int64(5): 500, np.int64(6): 500, np.int64(0): 500, np.int64(7): 500, np.int64(3): 500, np.int64(4): 500, np.int64(8): 500, np.int64(1): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/scatresnet_acc_vs_n_samples_ScatResNet18_200.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/scatresnet_acc_vs_n_samples_ScatResNet18_200.pkl
#
# === Starting Training: ScatResNet18_200 with 200 epochs ===
#     --> New Best Saved: 10.00%
# Epoch 1/200 | Loss: 4.437 | Val Acc: 10.00%
# Epoch 51/200 | Loss: 0.443 | Val Acc: 54.28%
# Epoch 101/200 | Loss: 0.062 | Val Acc: 62.04%
# Epoch 151/200 | Loss: 0.020 | Val Acc: 63.74%
# === Finished ScatResNet18_200. Total Time: 738.3s ===
# Final test accuracy is: 64.240
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 3000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 300, np.int64(0): 300, np.int64(6): 300, np.int64(4): 300, np.int64(9): 300, np.int64(3): 300, np.int64(8): 300, np.int64(5): 300, np.int64(1): 300, np.int64(2): 300})
# Samples per class (val): Counter({np.int64(7): 500, np.int64(2): 500, np.int64(5): 500, np.int64(9): 500, np.int64(4): 500, np.int64(0): 500, np.int64(8): 500, np.int64(6): 500, np.int64(3): 500, np.int64(1): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/scatresnet_acc_vs_n_samples_ScatResNet18_300.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/scatresnet_acc_vs_n_samples_ScatResNet18_300.pkl
#
# === Starting Training: ScatResNet18_300 with 200 epochs ===
#     --> New Best Saved: 10.00%
# Epoch 1/200 | Loss: 4.155 | Val Acc: 10.00%
# Epoch 51/200 | Loss: 0.357 | Val Acc: 66.00%
# Epoch 101/200 | Loss: 0.057 | Val Acc: 68.46%
#     --> New Best Saved: 71.96%
# Epoch 151/200 | Loss: 0.010 | Val Acc: 71.96%
# === Finished ScatResNet18_300. Total Time: 918.1s ===
# Final test accuracy is: 71.920
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 4000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 400, np.int64(6): 400, np.int64(5): 400, np.int64(0): 400, np.int64(1): 400, np.int64(4): 400, np.int64(8): 400, np.int64(2): 400, np.int64(3): 400, np.int64(9): 400})
# Samples per class (val): Counter({np.int64(4): 500, np.int64(6): 500, np.int64(9): 500, np.int64(5): 500, np.int64(3): 500, np.int64(7): 500, np.int64(0): 500, np.int64(1): 500, np.int64(2): 500, np.int64(8): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/scatresnet_acc_vs_n_samples_ScatResNet18_400.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/scatresnet_acc_vs_n_samples_ScatResNet18_400.pkl
#
# === Starting Training: ScatResNet18_400 with 200 epochs ===
#     --> New Best Saved: 14.34%
# Epoch 1/200 | Loss: 3.917 | Val Acc: 14.34%
# Epoch 51/200 | Loss: 0.256 | Val Acc: 64.60%
# Epoch 101/200 | Loss: 0.088 | Val Acc: 70.78%
# Epoch 151/200 | Loss: 0.019 | Val Acc: 74.06%
# === Finished ScatResNet18_400. Total Time: 1095.7s ===
# Final test accuracy is: 74.680
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 5000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(4): 500, np.int64(7): 500, np.int64(3): 500, np.int64(1): 500, np.int64(2): 500, np.int64(8): 500, np.int64(5): 500, np.int64(0): 500, np.int64(9): 500, np.int64(6): 500})
# Samples per class (val): Counter({np.int64(5): 500, np.int64(8): 500, np.int64(2): 500, np.int64(9): 500, np.int64(1): 500, np.int64(3): 500, np.int64(0): 500, np.int64(6): 500, np.int64(7): 500, np.int64(4): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/scatresnet_acc_vs_n_samples_ScatResNet18_500.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/scatresnet_acc_vs_n_samples_ScatResNet18_500.pkl
#
# === Starting Training: ScatResNet18_500 with 200 epochs ===
#     --> New Best Saved: 12.10%
# Epoch 1/200 | Loss: 3.112 | Val Acc: 12.10%
# Epoch 51/200 | Loss: 0.386 | Val Acc: 70.16%
# Epoch 101/200 | Loss: 0.239 | Val Acc: 71.90%
#     --> New Best Saved: 75.38%
# Epoch 151/200 | Loss: 0.061 | Val Acc: 75.38%
# === Finished ScatResNet18_500. Total Time: 1285.2s ===
# Final test accuracy is: 76.440
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 10000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 1000, np.int64(2): 1000, np.int64(3): 1000, np.int64(9): 1000, np.int64(6): 1000, np.int64(8): 1000, np.int64(5): 1000, np.int64(0): 1000, np.int64(4): 1000, np.int64(1): 1000})
# Samples per class (val): Counter({np.int64(0): 500, np.int64(2): 500, np.int64(7): 500, np.int64(8): 500, np.int64(3): 500, np.int64(1): 500, np.int64(5): 500, np.int64(4): 500, np.int64(9): 500, np.int64(6): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/scatresnet_acc_vs_n_samples_ScatResNet18_1000.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/scatresnet_acc_vs_n_samples_ScatResNet18_1000.pkl
#
# === Starting Training: ScatResNet18_1000 with 200 epochs ===
#     --> New Best Saved: 32.18%
# Epoch 1/200 | Loss: 2.301 | Val Acc: 32.18%
# Epoch 51/200 | Loss: 0.298 | Val Acc: 75.08%
#     --> New Best Saved: 78.86%
# Epoch 101/200 | Loss: 0.096 | Val Acc: 78.86%
# Epoch 151/200 | Loss: 0.025 | Val Acc: 81.02%
# === Finished ScatResNet18_1000. Total Time: 2161.7s ===
# Final test accuracy is: 83.160
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 40000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(6): 4000, np.int64(7): 4000, np.int64(8): 4000, np.int64(3): 4000, np.int64(2): 4000, np.int64(1): 4000, np.int64(4): 4000, np.int64(9): 4000, np.int64(0): 4000, np.int64(5): 4000})
# Samples per class (val): Counter({np.int64(3): 500, np.int64(2): 500, np.int64(8): 500, np.int64(4): 500, np.int64(6): 500, np.int64(9): 500, np.int64(7): 500, np.int64(0): 500, np.int64(5): 500, np.int64(1): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/scatresnet_acc_vs_n_samples_ScatResNet18_4000.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/scatresnet_acc_vs_n_samples_ScatResNet18_4000.pkl
#
# === Starting Training: ScatResNet18_4000 with 200 epochs ===
#     --> New Best Saved: 53.96%
# Epoch 1/200 | Loss: 1.760 | Val Acc: 53.96%
# Epoch 51/200 | Loss: 0.314 | Val Acc: 82.80%
# Epoch 101/200 | Loss: 0.178 | Val Acc: 86.34%
# Epoch 151/200 | Loss: 0.043 | Val Acc: 90.44%
# === Finished ScatResNet18_4000. Total Time: 7464.5s ===
# Final test accuracy is: 93.220

# %%
# Plot accuracy vs data size
plt.figure(figsize=(10, 5))
plt.plot(list(test_accs.keys()), list(test_accs.values()), marker='o', linestyle='-', color='b')
plt.xlabel('Number of Training Samples per Class')
plt.ylabel('Test Accuracy')
plt.title('ScatResNet Accuracy vs Number of Training Samples per Class')
plt.grid(True)
if not SKIP_TRAINING:
    plt.savefig(FIGURES_PATH / f'{EXP_NAME}.png')
plt.show()
