# %%
import sys, os
from pathlib import Path

IS_KAGGLE = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '') != ''

if IS_KAGGLE:
    # Install packages not available on Kaggle
    # %pip install -q kymatio kornia
    
    # Add repo to path (UPDATE 'deep-learning-course-project' to your dataset slug)
    repo_path = Path('/kaggle/input/deep-learning-course-project')
    if repo_path.exists():
        sys.path.insert(0, str(repo_path))
else:
    # Local: add project root to path (assumes notebook is in notebooks/)
    project_root = Path.cwd().parent
    if (project_root / 'src').exists():
        sys.path.insert(0, str(project_root))

from src.utils.config import *
from src.utils.datasets import *
from src.models.architectures.RestNet18 import *
from src.models.architectures.ScatNet18 import *
from src.utils.training import *
from src.utils.visualization import *

from typing import Dict
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 4.3 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.
# ====================== Hyperparameters =======================
# N_EPOCHS: 200
# T_MAX: 200
# CRITERION: CrossEntropyLoss()
# DEVICE: cuda
# SEED: 42
# BATCH_SIZE: 128
# LR: 0.001
# MOMENTUM: 0.9
# WEIGHT_DECAY: 0.0001
# ================================================================
# Setting seed to 42

# %%
DEBUG = False
SKIP_TRAINING = False
EXP_NAME = "baseline_acc_vs_n_samples"
print(f"Starting experiment {EXP_NAME}. DEBUG={DEBUG}, SKIP_TRAINING={SKIP_TRAINING}")

device = DEVICE

n_samples_per_class_train = [10, 50, 100, 500, 1000, 4000]
# Out:
# Starting experiment baseline_acc_vs_n_samples. DEBUG=False, SKIP_TRAINING=False

# %%
test_accs : dict[int, float] = {}

# Train and save model for each data size
for n_samples in n_samples_per_class_train:
    # Initialize model
    resnet = MakeResNet18().to(device)
    MODEL_NAME = f"ResNet18_{n_samples}"

    total_params, model_size_mb = get_model_summary(resnet)
    print(f"Total Parameters: {total_params:,}")
    print(f"Model Size: {model_size_mb:.2f} MB")

    # Get data loaders
    trainloader, valloader, testloader, train_set, val_set, test_set = get_cifar10_loaders_and_splits(
    n_samples_per_class_train=n_samples
    )
    resnet_optimizer, resnet_scheduler = get_optimizer_and_scheduler(resnet)

    # Train model on n_samples
    if not SKIP_TRAINING:
        train_model(
            model=resnet,
            trainloader=trainloader,
            valloader=valloader,
            optimizer=resnet_optimizer,
            scheduler=resnet_scheduler,
            device=device,
            experiment_name=EXP_NAME,
            model_name=MODEL_NAME,
            val_accuracy_storing_threshold=0,
            print_progress_every=50,
            DEBUG=DEBUG
        )

        # Save accuracy on test set
        debug_suff = "_DEBUG" if DEBUG else ""
        load_weights(resnet, experiment_name=EXP_NAME, model_name=(MODEL_NAME+ debug_suff), device=device)
        test_acc = calculate_accuracy(resnet, testloader, device)
        test_accs[n_samples] = test_acc
        print(f'Final test accuracy is: {test_acc:.3f}')
# Out:
# Total Parameters: 11,173,962
# Model Size: 42.63 MB
# 100%|██████████| 170M/170M [00:04<00:00, 39.8MB/s]
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 100
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(8): 10, np.int64(7): 10, np.int64(4): 10, np.int64(3): 10, np.int64(5): 10, np.int64(6): 10, np.int64(1): 10, np.int64(2): 10, np.int64(0): 10, np.int64(9): 10})
# Samples per class (val): Counter({np.int64(3): 500, np.int64(6): 500, np.int64(7): 500, np.int64(0): 500, np.int64(5): 500, np.int64(1): 500, np.int64(8): 500, np.int64(9): 500, np.int64(4): 500, np.int64(2): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/baseline_acc_vs_n_samples_ResNet18_10.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/baseline_acc_vs_n_samples_ResNet18_10.pkl
#
# === Starting Training: ResNet18_10 with 200 epochs ===
#     --> New Best Saved: 10.00%
# Epoch 1/200 | Loss: 2.456 | Val Acc: 10.00%
# Epoch 51/200 | Loss: 0.184 | Val Acc: 18.74%
# Epoch 101/200 | Loss: 0.054 | Val Acc: 23.06%
# Epoch 151/200 | Loss: 0.003 | Val Acc: 25.86%
# === Finished ResNet18_10. Total Time: 304.2s ===
# Final test accuracy is: 25.650
# Total Parameters: 11,173,962
# Model Size: 42.63 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 500
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(3): 50, np.int64(0): 50, np.int64(8): 50, np.int64(7): 50, np.int64(2): 50, np.int64(1): 50, np.int64(6): 50, np.int64(4): 50, np.int64(5): 50, np.int64(9): 50})
# Samples per class (val): Counter({np.int64(2): 500, np.int64(4): 500, np.int64(1): 500, np.int64(3): 500, np.int64(6): 500, np.int64(0): 500, np.int64(9): 500, np.int64(5): 500, np.int64(7): 500, np.int64(8): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/baseline_acc_vs_n_samples_ResNet18_50.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/baseline_acc_vs_n_samples_ResNet18_50.pkl
#
# === Starting Training: ResNet18_50 with 200 epochs ===
#     --> New Best Saved: 10.20%
# Epoch 1/200 | Loss: 3.382 | Val Acc: 10.20%
# Epoch 51/200 | Loss: 0.763 | Val Acc: 33.90%
# Epoch 101/200 | Loss: 0.118 | Val Acc: 38.24%
# Epoch 151/200 | Loss: 0.035 | Val Acc: 40.70%
# === Finished ResNet18_50. Total Time: 363.8s ===
# Final test accuracy is: 40.540
# Total Parameters: 11,173,962
# Model Size: 42.63 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 1000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 100, np.int64(1): 100, np.int64(8): 100, np.int64(4): 100, np.int64(3): 100, np.int64(9): 100, np.int64(5): 100, np.int64(0): 100, np.int64(2): 100, np.int64(6): 100})
# Samples per class (val): Counter({np.int64(1): 500, np.int64(9): 500, np.int64(2): 500, np.int64(4): 500, np.int64(6): 500, np.int64(5): 500, np.int64(0): 500, np.int64(3): 500, np.int64(8): 500, np.int64(7): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/baseline_acc_vs_n_samples_ResNet18_100.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/baseline_acc_vs_n_samples_ResNet18_100.pkl
#
# === Starting Training: ResNet18_100 with 200 epochs ===
#     --> New Best Saved: 10.00%
# Epoch 1/200 | Loss: 4.767 | Val Acc: 10.00%
# Epoch 51/200 | Loss: 0.749 | Val Acc: 41.22%
# Epoch 101/200 | Loss: 0.070 | Val Acc: 44.72%
# Epoch 151/200 | Loss: 0.024 | Val Acc: 48.00%
# === Finished ResNet18_100. Total Time: 442.8s ===
# Final test accuracy is: 48.680
# Total Parameters: 11,173,962
# Model Size: 42.63 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 5000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(4): 500, np.int64(7): 500, np.int64(3): 500, np.int64(1): 500, np.int64(2): 500, np.int64(8): 500, np.int64(5): 500, np.int64(0): 500, np.int64(9): 500, np.int64(6): 500})
# Samples per class (val): Counter({np.int64(5): 500, np.int64(8): 500, np.int64(2): 500, np.int64(9): 500, np.int64(1): 500, np.int64(3): 500, np.int64(0): 500, np.int64(6): 500, np.int64(7): 500, np.int64(4): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/baseline_acc_vs_n_samples_ResNet18_500.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/baseline_acc_vs_n_samples_ResNet18_500.pkl
#
# === Starting Training: ResNet18_500 with 200 epochs ===
#     --> New Best Saved: 17.84%
# Epoch 1/200 | Loss: 3.205 | Val Acc: 17.84%
# Epoch 51/200 | Loss: 0.333 | Val Acc: 67.10%
# Epoch 101/200 | Loss: 0.136 | Val Acc: 72.58%
#     --> New Best Saved: 75.78%
# Epoch 151/200 | Loss: 0.039 | Val Acc: 75.78%
# === Finished ResNet18_500. Total Time: 1064.9s ===
# Final test accuracy is: 76.910
# Total Parameters: 11,173,962
# Model Size: 42.63 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 10000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 1000, np.int64(2): 1000, np.int64(3): 1000, np.int64(9): 1000, np.int64(6): 1000, np.int64(8): 1000, np.int64(5): 1000, np.int64(0): 1000, np.int64(4): 1000, np.int64(1): 1000})
# Samples per class (val): Counter({np.int64(0): 500, np.int64(2): 500, np.int64(7): 500, np.int64(8): 500, np.int64(3): 500, np.int64(1): 500, np.int64(5): 500, np.int64(4): 500, np.int64(9): 500, np.int64(6): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/baseline_acc_vs_n_samples_ResNet18_1000.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/baseline_acc_vs_n_samples_ResNet18_1000.pkl
#
# === Starting Training: ResNet18_1000 with 200 epochs ===
#     --> New Best Saved: 21.44%
# Epoch 1/200 | Loss: 2.551 | Val Acc: 21.44%
# Epoch 51/200 | Loss: 0.273 | Val Acc: 74.98%
# Epoch 101/200 | Loss: 0.149 | Val Acc: 74.42%
# Epoch 151/200 | Loss: 0.013 | Val Acc: 82.30%
# === Finished ResNet18_1000. Total Time: 1833.9s ===
# Final test accuracy is: 83.930
# Total Parameters: 11,173,962
# Model Size: 42.63 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 40000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(6): 4000, np.int64(7): 4000, np.int64(8): 4000, np.int64(3): 4000, np.int64(2): 4000, np.int64(1): 4000, np.int64(4): 4000, np.int64(9): 4000, np.int64(0): 4000, np.int64(5): 4000})
# Samples per class (val): Counter({np.int64(3): 500, np.int64(2): 500, np.int64(8): 500, np.int64(4): 500, np.int64(6): 500, np.int64(9): 500, np.int64(7): 500, np.int64(0): 500, np.int64(5): 500, np.int64(1): 500})
# T_MAX: 200
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/baseline_acc_vs_n_samples_ResNet18_4000.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/baseline_acc_vs_n_samples_ResNet18_4000.pkl
#
# === Starting Training: ResNet18_4000 with 200 epochs ===
#     --> New Best Saved: 42.28%
# Epoch 1/200 | Loss: 1.845 | Val Acc: 42.28%
# Epoch 51/200 | Loss: 0.287 | Val Acc: 84.30%
#     --> New Best Saved: 89.52%
# Epoch 101/200 | Loss: 0.174 | Val Acc: 89.52%
# Epoch 151/200 | Loss: 0.041 | Val Acc: 91.74%
# === Finished ResNet18_4000. Total Time: 6514.8s ===
# Final test accuracy is: 93.840

# %%
# Plot accuracy vs data size
plt.figure(figsize=(10, 5))
plt.plot(list(test_accs.keys()), list(test_accs.values()), marker='o', linestyle='-', color='b')
plt.xlabel('Number of Training Samples per Class')
plt.ylabel('Test Accuracy')
plt.title('Accuracy vs Number of Training Samples per Class')
plt.grid(True)
if not SKIP_TRAINING:
    plt.savefig(FIGURES_PATH / 'baseline_acc_vs_n_samples.png')
plt.show()
