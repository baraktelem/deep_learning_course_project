# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms

# !pip install kornia
from kornia import augmentation as K
from kornia.augmentation import AugmentationSequential
from torch.utils.data import random_split

import numpy as np

import os
import time
from pathlib import Path
import pickle

from torch.utils.data import Subset
from sklearn.model_selection import train_test_split

# !pip install kymatio
from kymatio.torch import Scattering2D

DEBUG = False
MODEL_NAME = "baseline_100_scat_3"
TRAIN_SIZE = 1000
VALIDATION_SIZE = 5000
env = 'kaggle' # 'kaggle' or 'colab'

if env == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')
    base_dir = Path('/content/drive/MyDrive/dl_pj')    
elif env == 'kaggle':
    base_dir = Path('/kaggle/working/')

checkpoint_dir = base_dir / 'checkpoints'
checkpoint_dir.mkdir(parents=True, exist_ok=True)
training_stats_dir = base_dir / 'stats'
training_stats_dir.mkdir(parents=True, exist_ok=True)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia) (0.1.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from kornia) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->kornia) (3.0.3)
# Collecting kymatio
#   Downloading kymatio-0.3.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting appdirs (from kymatio)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting configparser (from kymatio)
#   Downloading configparser-7.2.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from kymatio) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kymatio) (25.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from kymatio) (1.15.3)
# Downloading kymatio-0.3.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 5.5 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading configparser-7.2.0-py3-none-any.whl (17 kB)
# Installing collected packages: appdirs, configparser, kymatio
# Successfully installed appdirs-1.4.4 configparser-7.2.0 kymatio-0.3.0

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes,kernel_size=1,stride=stride,bias=False),
                nn.BatchNorm2d(planes)
            )


    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out



class ResNet(nn.Module):
    def __init__(self, scattering_output_channels, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64
        self.scat_channels = scattering_output_channels
        self.scattering = Scattering2D(J=2, shape=(32, 32), max_order=1).to(device)
        self.K = K
        self.deconv1 = nn.ConvTranspose2d(in_channels=self.scat_channels, out_channels=self.scat_channels, groups=self.scat_channels, kernel_size=4, stride=4)
        self.conv1 = nn.Conv2d(scattering_output_channels + 3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layer = []
        for s in strides:
            layer.append(block(self.in_planes, planes, s))
            self.in_planes = planes
        return nn.Sequential(*layer)

    def forward(self, x):
        x = torch.cat(
            (x, 
            self.deconv1(self.scattering(x).view(x.size(0),-1,8,8))),
            dim=1
        )
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18(scattering_output_channels):
    return ResNet(scattering_output_channels, BasicBlock, [2, 2, 2, 2])

# %%
scattering_output_channels = 17*3

# %%
def get_model_summary(model):
    num_params = sum(p.numel() for p in model.parameters())
    total_bytes = sum(p.numel() * p.element_size() for p in model.parameters())
    size_mb = total_bytes / (1024 ** 2)
    return num_params, size_mb

total_params, model_size_mb = get_model_summary(ResNet18(scattering_output_channels))
print(f"Total Parameters: {total_params:,}")
print(f"Model Size: {model_size_mb:.2f} MB")
# Out:
# Total Parameters: 11,204,205
# Model Size: 42.74 MB

# %%
def calculate_accuracy(model, dataloader, device):
    model.eval() # put in evaluation mode,  turn off Dropout, BatchNorm uses learned statistics
    total_correct = 0
    total_images = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            images = normalize(images)
            outputs = model(images)
            predictions = torch.argmax(outputs, dim=-1)
            total_images += labels.size(0)
            total_correct += (predictions == labels).sum().item()

    model_accuracy = total_correct / total_images * 100
    return model_accuracy

# %% [markdown]
# Split data set into train-validation-test.
# We are using 80% train, 20% validation split

# %%
transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor()]
)

# 80/20% split
train_val_set = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform
)


targets = np.array(train_val_set.targets)

indices = np.arange(len(targets))
train_indices, remaining_indices = train_test_split(
    indices,
    train_size=TRAIN_SIZE,
    stratify=targets,
    random_state=42
)

validation_indices, _ = train_test_split(
    remaining_indices,
    train_size=VALIDATION_SIZE,
    stratify=targets[remaining_indices],
    random_state=42
)

trainset = Subset(train_val_set, train_indices)
valset = Subset(train_val_set, validation_indices)
print(f"Original size: {len(train_val_set)}")
print(f"Train size: {len(trainset)}")
print(f"Val size: {len(valset)}")

from collections import Counter 
subset_labels = [targets[i] for i in train_indices]
print("Samples per class", Counter(subset_labels))
subset_labels = [targets[i] for i in validation_indices]
print("Samples per class", Counter(subset_labels))

testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform
)
# Out:
# 100%|██████████| 170M/170M [00:06<00:00, 28.1MB/s]
# Original size: 50000
# Train size: 1000
# Val size: 5000
# Samples per class Counter({np.int64(7): 100, np.int64(1): 100, np.int64(8): 100, np.int64(4): 100, np.int64(3): 100, np.int64(9): 100, np.int64(5): 100, np.int64(0): 100, np.int64(2): 100, np.int64(6): 100})
# Samples per class Counter({np.int64(1): 500, np.int64(9): 500, np.int64(2): 500, np.int64(4): 500, np.int64(6): 500, np.int64(5): 500, np.int64(0): 500, np.int64(3): 500, np.int64(8): 500, np.int64(7): 500})

# %%
# Hyperparamters
batch_size = 128

lr = 0.1
momentum = 0.9
weight_decay = 5e-4

T_max = 200

n_epochs = 1 if DEBUG else 200

print_progress_every = 1
val_accuracy_storing_threshold = 40

# %%
mean = torch.tensor([0.4914, 0.4822, 0.4465]).to(device)
std = torch.tensor([0.2023, 0.1994, 0.2010]).to(device)
normalize = K.Normalize(mean=mean, std=std)
# define a sequence of augmentations
aug_list = AugmentationSequential(
    K.RandomHorizontalFlip(p=0.5),
    K.ColorJitter(0.1, 0.1, 0.1, 0.1, p=0.2),
    K.RandomResizedCrop(size=(32,32), scale=(0.7, 1.0), p=0.5),
    normalize,
    same_on_batch=False
).to(device)


trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=True)
model = ResNet18(scattering_output_channels).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)

stats = {
    'total_training_time': 0,
    'loss': [],
    'time_per_epoch': [],
    'total_time_per_epoch': [],
    'val_accuracy': [],
    'max_val_accuracy': 0,
    'allocated_memory': [], # Memory currently used by Tensors
    'reserved_memory': [], # Memory held by the PyTorch caching allocator
}

start_time = time.time()
for epoch in range(n_epochs):
    model.train()
    iteration_losses = []
    epoch_start_time = time.time()
    for inputs, targets in trainloader:
        inputs = inputs.to(device)
        targets = targets.to(device)

        inputs = aug_list(inputs)

        outputs = model(inputs)

        optimizer.zero_grad()
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        iteration_losses.append(loss.item())

    scheduler.step()
    epoch_end_time = time.time()

    model.eval()
    val_accuracy = calculate_accuracy(model, valloader, device)

    # Track stats
    if (epoch % 1) == 0:
        stats['loss'].append(
            np.mean(iteration_losses)
        )
        stats['val_accuracy'].append(
            val_accuracy
        )
        stats['allocated_memory'].append(torch.cuda.memory_allocated())
        stats['reserved_memory'].append(torch.cuda.memory_reserved())
        stats['time_per_epoch'].append(epoch_end_time - epoch_start_time)
        stats['total_time_per_epoch'].append(time.time() - start_time)

    # Store best model
    if (val_accuracy > stats['max_val_accuracy']):
        if (val_accuracy > val_accuracy_storing_threshold):
            stats['max_val_accuracy'] = val_accuracy
            print('==> Saving model ...')
            state = {
                'net': model.state_dict(),
                'epoch': epoch,
                'acc':val_accuracy
            }
            save_path = checkpoint_dir / f"{MODEL_NAME}_max_acc.pth"
            torch.save(state, save_path)

    if DEBUG:
        print('==> Saving model ... DEBUG')
        state = {
            'net': model.state_dict(),
            'epoch': epoch,
            'acc':val_accuracy
        }
        save_path = checkpoint_dir / f"{MODEL_NAME}_max_acc.pth"
        torch.save(state, save_path)
        
    # Print progress
    if (epoch % print_progress_every) == 0:
        print(f"Epoch {epoch} Loss {stats['loss'][-1]:.3f} Val Acc {stats['val_accuracy'][-1]:.3f}")
# Out:
# Epoch 0 Loss 4.340 Val Acc 10.000
# Epoch 1 Loss 2.928 Val Acc 10.000
# Epoch 2 Loss 2.358 Val Acc 9.120
# Epoch 3 Loss 2.293 Val Acc 16.300
# Epoch 4 Loss 2.159 Val Acc 20.900
# Epoch 5 Loss 2.069 Val Acc 21.880
# Epoch 6 Loss 2.025 Val Acc 22.940
# Epoch 7 Loss 1.985 Val Acc 25.400
# Epoch 8 Loss 1.928 Val Acc 27.620
# Epoch 9 Loss 1.938 Val Acc 26.300
# Epoch 10 Loss 1.915 Val Acc 24.900
# Epoch 11 Loss 1.818 Val Acc 31.220
# Epoch 12 Loss 1.830 Val Acc 30.800
# Epoch 13 Loss 1.739 Val Acc 31.000
# Epoch 14 Loss 1.717 Val Acc 31.180
# Epoch 15 Loss 1.686 Val Acc 32.460
# Epoch 16 Loss 1.638 Val Acc 33.660
# Epoch 17 Loss 1.630 Val Acc 33.920
# Epoch 18 Loss 1.644 Val Acc 35.120
# Epoch 19 Loss 1.538 Val Acc 34.840
# Epoch 20 Loss 1.508 Val Acc 33.620
# Epoch 21 Loss 1.498 Val Acc 36.520
# Epoch 22 Loss 1.394 Val Acc 35.100
# Epoch 23 Loss 1.373 Val Acc 36.620
# Epoch 24 Loss 1.389 Val Acc 35.160
# Epoch 25 Loss 1.371 Val Acc 37.020
# Epoch 26 Loss 1.296 Val Acc 35.620
# Epoch 27 Loss 1.255 Val Acc 37.180
# Epoch 28 Loss 1.268 Val Acc 37.520
# Epoch 29 Loss 1.187 Val Acc 38.400
# Epoch 30 Loss 1.137 Val Acc 37.420
# Epoch 31 Loss 1.105 Val Acc 36.020
# Epoch 32 Loss 1.162 Val Acc 36.220
# Epoch 33 Loss 1.034 Val Acc 36.500
# Epoch 34 Loss 0.953 Val Acc 37.060
# Epoch 35 Loss 1.035 Val Acc 37.840
# Epoch 36 Loss 0.910 Val Acc 35.820
# Epoch 37 Loss 0.948 Val Acc 38.160
# Epoch 38 Loss 0.834 Val Acc 37.840
# Epoch 39 Loss 0.859 Val Acc 37.380
# Epoch 40 Loss 0.859 Val Acc 37.400
# Epoch 41 Loss 0.758 Val Acc 37.900
# ==> Saving model ...
# Epoch 42 Loss 0.751 Val Acc 40.420
# Epoch 43 Loss 0.719 Val Acc 38.040
# Epoch 44 Loss 0.806 Val Acc 36.320
# Epoch 45 Loss 0.671 Val Acc 38.940
# Epoch 46 Loss 0.652 Val Acc 39.600
# Epoch 47 Loss 0.554 Val Acc 38.400
# Epoch 48 Loss 0.541 Val Acc 40.080
# Epoch 49 Loss 0.662 Val Acc 37.700
# Epoch 50 Loss 0.520 Val Acc 39.100
# Epoch 51 Loss 0.531 Val Acc 39.500
# Epoch 52 Loss 0.513 Val Acc 39.840
# Epoch 53 Loss 0.526 Val Acc 40.420
# ==> Saving model ...
# Epoch 54 Loss 0.394 Val Acc 41.360
# Epoch 55 Loss 0.336 Val Acc 39.840
# Epoch 56 Loss 0.333 Val Acc 40.060
# Epoch 57 Loss 0.427 Val Acc 39.660
# Epoch 58 Loss 0.338 Val Acc 39.980
# Epoch 59 Loss 0.409 Val Acc 40.500
# Epoch 60 Loss 0.478 Val Acc 38.820
# Epoch 61 Loss 0.250 Val Acc 39.040
# Epoch 62 Loss 0.346 Val Acc 40.480
# Epoch 63 Loss 0.259 Val Acc 41.200
# Epoch 64 Loss 0.339 Val Acc 40.880
# Epoch 65 Loss 0.391 Val Acc 39.980
# Epoch 66 Loss 0.284 Val Acc 41.280
# Epoch 67 Loss 0.286 Val Acc 39.500
# Epoch 68 Loss 0.233 Val Acc 38.060
# ==> Saving model ...
# Epoch 69 Loss 0.268 Val Acc 41.420
# Epoch 70 Loss 0.251 Val Acc 40.440
# Epoch 71 Loss 0.306 Val Acc 40.780
# Epoch 72 Loss 0.183 Val Acc 40.520
# ==> Saving model ...
# Epoch 73 Loss 0.169 Val Acc 42.140
# Epoch 74 Loss 0.119 Val Acc 41.760
# Epoch 75 Loss 0.148 Val Acc 39.400
# ==> Saving model ...
# Epoch 76 Loss 0.153 Val Acc 42.280
# ==> Saving model ...
# Epoch 77 Loss 0.100 Val Acc 42.300
# Epoch 78 Loss 0.108 Val Acc 41.480
# ==> Saving model ...
# Epoch 79 Loss 0.181 Val Acc 43.380
# Epoch 80 Loss 0.123 Val Acc 42.860
# Epoch 81 Loss 0.080 Val Acc 41.720
# Epoch 82 Loss 0.160 Val Acc 41.180
# Epoch 83 Loss 0.159 Val Acc 40.520
# Epoch 84 Loss 0.099 Val Acc 42.100
# Epoch 85 Loss 0.162 Val Acc 42.300
# Epoch 86 Loss 0.141 Val Acc 42.800
# Epoch 87 Loss 0.096 Val Acc 41.540
# Epoch 88 Loss 0.099 Val Acc 40.940
# Epoch 89 Loss 0.106 Val Acc 42.880
# Epoch 90 Loss 0.154 Val Acc 42.580
# Epoch 91 Loss 0.135 Val Acc 41.220
# Epoch 92 Loss 0.144 Val Acc 41.500
# ==> Saving model ...
# Epoch 93 Loss 0.141 Val Acc 43.400
# Epoch 94 Loss 0.119 Val Acc 43.240
# Epoch 95 Loss 0.135 Val Acc 41.940
# Epoch 96 Loss 0.141 Val Acc 41.640
# Epoch 97 Loss 0.059 Val Acc 41.220
# Epoch 98 Loss 0.124 Val Acc 41.700
# Epoch 99 Loss 0.129 Val Acc 42.900
# Epoch 100 Loss 0.121 Val Acc 42.640
# Epoch 101 Loss 0.060 Val Acc 42.960
# Epoch 102 Loss 0.075 Val Acc 42.920
# Epoch 103 Loss 0.099 Val Acc 42.560
# Epoch 104 Loss 0.073 Val Acc 42.780
# Epoch 105 Loss 0.108 Val Acc 42.120
# Epoch 106 Loss 0.074 Val Acc 41.960
# ==> Saving model ...
# Epoch 107 Loss 0.072 Val Acc 43.740
# ==> Saving model ...
# Epoch 108 Loss 0.047 Val Acc 43.960
# Epoch 109 Loss 0.070 Val Acc 42.480
# Epoch 110 Loss 0.043 Val Acc 43.660
# Epoch 111 Loss 0.062 Val Acc 43.100
# Epoch 112 Loss 0.064 Val Acc 42.820
# Epoch 113 Loss 0.083 Val Acc 42.920
# Epoch 114 Loss 0.062 Val Acc 43.940
# Epoch 115 Loss 0.084 Val Acc 43.620
# Epoch 116 Loss 0.062 Val Acc 42.500
# ==> Saving model ...
# Epoch 117 Loss 0.072 Val Acc 44.020
# Epoch 118 Loss 0.049 Val Acc 43.860
# Epoch 119 Loss 0.031 Val Acc 43.960
# Epoch 120 Loss 0.046 Val Acc 43.780
# Epoch 121 Loss 0.065 Val Acc 43.620
# Epoch 122 Loss 0.027 Val Acc 43.540
# Epoch 123 Loss 0.042 Val Acc 43.020
# Epoch 124 Loss 0.042 Val Acc 43.120
# Epoch 125 Loss 0.041 Val Acc 43.740
# Epoch 126 Loss 0.013 Val Acc 43.460
# Epoch 127 Loss 0.048 Val Acc 43.700
# ==> Saving model ...
# Epoch 128 Loss 0.012 Val Acc 44.160
# ==> Saving model ...
# Epoch 129 Loss 0.061 Val Acc 44.360
# Epoch 130 Loss 0.059 Val Acc 43.900
# Epoch 131 Loss 0.027 Val Acc 43.560
# Epoch 132 Loss 0.029 Val Acc 43.680
# Epoch 133 Loss 0.023 Val Acc 43.800
# Epoch 134 Loss 0.035 Val Acc 43.640
# Epoch 135 Loss 0.027 Val Acc 42.960
# Epoch 136 Loss 0.016 Val Acc 42.920
# Epoch 137 Loss 0.035 Val Acc 43.040
# Epoch 138 Loss 0.015 Val Acc 43.300
# Epoch 139 Loss 0.029 Val Acc 43.900
# Epoch 140 Loss 0.042 Val Acc 43.640
# Epoch 141 Loss 0.031 Val Acc 44.100
# Epoch 142 Loss 0.016 Val Acc 44.220
# Epoch 143 Loss 0.039 Val Acc 43.960
# Epoch 144 Loss 0.028 Val Acc 43.560
# Epoch 145 Loss 0.025 Val Acc 43.420
# Epoch 146 Loss 0.019 Val Acc 43.440
# Epoch 147 Loss 0.031 Val Acc 43.640
# Epoch 148 Loss 0.019 Val Acc 43.700
# Epoch 149 Loss 0.025 Val Acc 43.800
# Epoch 150 Loss 0.011 Val Acc 43.840
# Epoch 151 Loss 0.021 Val Acc 43.680
# Epoch 152 Loss 0.012 Val Acc 43.740
# Epoch 153 Loss 0.024 Val Acc 43.560
# Epoch 154 Loss 0.017 Val Acc 43.560
# Epoch 155 Loss 0.029 Val Acc 43.820
# Epoch 156 Loss 0.030 Val Acc 44.020
# Epoch 157 Loss 0.025 Val Acc 43.820
# Epoch 158 Loss 0.035 Val Acc 43.560
# Epoch 159 Loss 0.025 Val Acc 43.560
# Epoch 160 Loss 0.025 Val Acc 43.760
# Epoch 161 Loss 0.022 Val Acc 44.140
# Epoch 162 Loss 0.007 Val Acc 43.880
# Epoch 163 Loss 0.028 Val Acc 43.520
# Epoch 164 Loss 0.004 Val Acc 43.580
# Epoch 165 Loss 0.004 Val Acc 43.620
# Epoch 166 Loss 0.017 Val Acc 44.000
# Epoch 167 Loss 0.008 Val Acc 43.940
# Epoch 168 Loss 0.014 Val Acc 44.100
# Epoch 169 Loss 0.020 Val Acc 44.080
# Epoch 170 Loss 0.008 Val Acc 43.880
# Epoch 171 Loss 0.015 Val Acc 43.980
# Epoch 172 Loss 0.022 Val Acc 44.080
# Epoch 173 Loss 0.007 Val Acc 44.040
# Epoch 174 Loss 0.009 Val Acc 43.940
# Epoch 175 Loss 0.008 Val Acc 43.920
# Epoch 176 Loss 0.016 Val Acc 43.940
# Epoch 177 Loss 0.020 Val Acc 44.080
# Epoch 178 Loss 0.022 Val Acc 44.240
# Epoch 179 Loss 0.014 Val Acc 44.020
# Epoch 180 Loss 0.020 Val Acc 44.160
# Epoch 181 Loss 0.003 Val Acc 44.160
# Epoch 182 Loss 0.031 Val Acc 44.160
# Epoch 183 Loss 0.014 Val Acc 44.040
# Epoch 184 Loss 0.007 Val Acc 43.980
# Epoch 185 Loss 0.008 Val Acc 44.120
# Epoch 186 Loss 0.020 Val Acc 44.060
# Epoch 187 Loss 0.019 Val Acc 44.060
# Epoch 188 Loss 0.020 Val Acc 44.120
# Epoch 189 Loss 0.016 Val Acc 44.040
# Epoch 190 Loss 0.027 Val Acc 44.120
# Epoch 191 Loss 0.019 Val Acc 44.120
# Epoch 192 Loss 0.019 Val Acc 44.120
# Epoch 193 Loss 0.017 Val Acc 44.140
# Epoch 194 Loss 0.018 Val Acc 44.360
# Epoch 195 Loss 0.022 Val Acc 44.160
# Epoch 196 Loss 0.010 Val Acc 44.180
# Epoch 197 Loss 0.010 Val Acc 44.100
# Epoch 198 Loss 0.021 Val Acc 44.360
# Epoch 199 Loss 0.018 Val Acc 44.360

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = ResNet18(scattering_output_channels).to(device)
checkpoint = torch.load(checkpoint_dir / f"{MODEL_NAME}_max_acc.pth", map_location=device)
model.load_state_dict(checkpoint['net'])
model.eval()
total_params, model_size_mb = get_model_summary(ResNet18(scattering_output_channels))
stats['total_params'] = total_params
stats['model_size_mb'] = model_size_mb
stats['train_acc'] = calculate_accuracy(model, trainloader, device)
stats['val_acc'] = calculate_accuracy(model, valloader, device)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=True)
stats['test_acc'] = calculate_accuracy(model, testloader, device)

with open(training_stats_dir / f'{MODEL_NAME}_stats.pkl', 'wb') as file:
    pickle.dump(stats, file)

print(f'Final test accuracy is: {stats['test_acc']}')
# Out:
# Final test accuracy is: 44.43
