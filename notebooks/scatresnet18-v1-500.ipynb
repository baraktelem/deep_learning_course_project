# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms

# !pip install kornia
# !pip install kymatio
from kornia import augmentation as K
from kornia.augmentation import AugmentationSequential
from torch.utils.data import random_split

import numpy as np

import os
import time
from pathlib import Path
import pickle

from torch.utils.data import Subset
from sklearn.model_selection import train_test_split

from kymatio.torch import Scattering2D

DEBUG = False
MODEL_NAME = "ScatResNet18_v1_500"
TRAIN_SIZE = 5000
VALIDATION_SIZE = 5000
env = 'kaggle' # 'kaggle' or 'colab'

if env == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')
    base_dir = Path('/content/drive/MyDrive/dl_pj')    
elif env == 'kaggle':
    base_dir = Path('/kaggle/working/')

checkpoint_dir = base_dir / 'checkpoints'
checkpoint_dir.mkdir(parents=True, exist_ok=True)
training_stats_dir = base_dir / 'stats'
training_stats_dir.mkdir(parents=True, exist_ok=True)
# Out:
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia) (0.1.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from kornia) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->kornia) (3.0.3)
# Collecting kymatio
#   Downloading kymatio-0.3.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting appdirs (from kymatio)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting configparser (from kymatio)
#   Downloading configparser-7.2.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from kymatio) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kymatio) (25.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from kymatio) (1.15.3)
# Downloading kymatio-0.3.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 2.9 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading configparser-7.2.0-py3-none-any.whl (17 kB)
# Installing collected packages: appdirs, configparser, kymatio
# Successfully installed appdirs-1.4.4 configparser-7.2.0 kymatio-0.3.0

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes,kernel_size=1,stride=stride,bias=False),
                nn.BatchNorm2d(planes)
            )


    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out



class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10, L=8):
        super(ResNet, self).__init__()
        self.in_planes = 64
        self.L = L
        self.scat_channels = (1 + L) * 3
        self.conv1 = nn.Conv2d(3, 64 - self.scat_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.scat1 = Scattering2D(J=1, shape=(32, 32), L=L, max_order=2, backend='torch')
        self.deconv1 = nn.ConvTranspose2d(in_channels=self.scat_channels, out_channels=self.scat_channels, groups=self.scat_channels, kernel_size=2, stride=2)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layer = []
        for s in strides:
            layer.append(block(self.in_planes, planes, s))
            self.in_planes = planes
        return nn.Sequential(*layer)

    def forward(self, x):
        out = self.conv1(x)
        scat = self.scat1(x)
        scat = scat.view(scat.size(0), -1, 16,16)
        scat = self.deconv1(scat)
        out = torch.cat((out, scat), dim=1)
        out = F.relu(self.bn1(out))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ScatResNet18(L):
    return ResNet(BasicBlock, [2, 2, 2, 2], L=L)

# %%
def get_model_summary(model):
    num_params = sum(p.numel() for p in model.parameters())
    total_bytes = sum(p.numel() * p.element_size() for p in model.parameters())
    size_mb = total_bytes / (1024 ** 2)
    return num_params, size_mb
for L in range(1,21):
    total_params, model_size_mb = get_model_summary(ScatResNet18(L))
    print(f"Total Parameters: {total_params:,}")
    print(f"Model Size: {model_size_mb:.2f} MB")
# Out:
# Total Parameters: 11,173,830
# Model Size: 42.62 MB
# Total Parameters: 11,173,764
# Model Size: 42.62 MB
# Total Parameters: 11,173,698
# Model Size: 42.62 MB
# Total Parameters: 11,173,632
# Model Size: 42.62 MB
# Total Parameters: 11,173,566
# Model Size: 42.62 MB
# Total Parameters: 11,173,500
# Model Size: 42.62 MB
# Total Parameters: 11,173,434
# Model Size: 42.62 MB
# Total Parameters: 11,173,368
# Model Size: 42.62 MB
# Total Parameters: 11,173,302
# Model Size: 42.62 MB
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# Total Parameters: 11,173,170
# Model Size: 42.62 MB
# Total Parameters: 11,173,104
# Model Size: 42.62 MB
# Total Parameters: 11,173,038
# Model Size: 42.62 MB
# Total Parameters: 11,172,972
# Model Size: 42.62 MB
# Total Parameters: 11,172,906
# Model Size: 42.62 MB
# Total Parameters: 11,172,840
# Model Size: 42.62 MB
# Total Parameters: 11,172,774
# Model Size: 42.62 MB
# Total Parameters: 11,172,708
# Model Size: 42.62 MB
# Total Parameters: 11,172,642
# Model Size: 42.62 MB
# Total Parameters: 11,172,576
# Model Size: 42.62 MB

# %%
def calculate_accuracy(model, dataloader, device):
    model.eval() # put in evaluation mode,  turn off Dropout, BatchNorm uses learned statistics
    total_correct = 0
    total_images = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            images = normalize(images)
            outputs = model(images)
            predictions = torch.argmax(outputs, dim=-1)
            total_images += labels.size(0)
            total_correct += (predictions == labels).sum().item()

    model_accuracy = total_correct / total_images * 100
    return model_accuracy

# %% [markdown]
# Split data set into train-validation-test.
# We are using 80% train, 20% validation split

# %%
transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor()]
)

# 80/20% split
train_val_set = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform
)


targets = np.array(train_val_set.targets)

indices = np.arange(len(targets))
train_indices, remaining_indices = train_test_split(
    indices,
    train_size=TRAIN_SIZE,
    stratify=targets,
    random_state=42
)

validation_indices, _ = train_test_split(
    remaining_indices,
    train_size=VALIDATION_SIZE,
    stratify=targets[remaining_indices],
    random_state=42
)

trainset = Subset(train_val_set, train_indices)
valset = Subset(train_val_set, validation_indices)
print(f"Original size: {len(train_val_set)}")
print(f"Train size: {len(trainset)}")
print(f"Val size: {len(valset)}")

from collections import Counter 
subset_labels = [targets[i] for i in train_indices]
print("Samples per class", Counter(subset_labels))
subset_labels = [targets[i] for i in validation_indices]
print("Samples per class", Counter(subset_labels))

testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform
)
# Out:
# 100%|██████████| 170M/170M [00:02<00:00, 80.5MB/s]
# Original size: 50000
# Train size: 5000
# Val size: 5000
# Samples per class Counter({np.int64(4): 500, np.int64(7): 500, np.int64(3): 500, np.int64(1): 500, np.int64(2): 500, np.int64(8): 500, np.int64(5): 500, np.int64(0): 500, np.int64(9): 500, np.int64(6): 500})
# Samples per class Counter({np.int64(5): 500, np.int64(8): 500, np.int64(2): 500, np.int64(9): 500, np.int64(1): 500, np.int64(3): 500, np.int64(0): 500, np.int64(6): 500, np.int64(7): 500, np.int64(4): 500})

# %%
# Hyperparamters
batch_size = 128

lr = 0.1
momentum = 0.9
weight_decay = 5e-4

T_max = 200

n_epochs = 1 if DEBUG else 200

print_progress_every = 1
val_accuracy_storing_threshold = 40

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
mean = torch.tensor([0.4914, 0.4822, 0.4465]).to(device)
std = torch.tensor([0.2023, 0.1994, 0.2010]).to(device)
normalize = K.Normalize(mean=mean, std=std)
# define a sequence of augmentations
aug_list = AugmentationSequential(
    K.RandomHorizontalFlip(p=0.5),
    K.ColorJitter(0.1, 0.1, 0.1, 0.1, p=0.2),
    K.RandomResizedCrop(size=(32,32), scale=(0.7, 1.0), p=0.5),
    normalize,
    same_on_batch=False
).to(device)


trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=True)
stats_list = []
for L in range(1, 21):
    model = ScatResNet18(L).to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)
    
    stats = {
        'total_training_time': 0,
        'loss': [],
        'time_per_epoch': [],
        'total_time_per_epoch': [],
        'val_accuracy': [],
        'max_val_accuracy': 0,
        'allocated_memory': [], # Memory currently used by Tensors
        'reserved_memory': [], # Memory held by the PyTorch caching allocator
    }
    
    start_time = time.time()
    for epoch in range(n_epochs):
        model.train()
        iteration_losses = []
        epoch_start_time = time.time()
        for inputs, targets in trainloader:
            inputs = inputs.to(device)
            targets = targets.to(device)
    
            inputs = aug_list(inputs)
    
            outputs = model(inputs)
    
            optimizer.zero_grad()
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            iteration_losses.append(loss.item())
    
        scheduler.step()
        epoch_end_time = time.time()
    
        model.eval()
        val_accuracy = calculate_accuracy(model, valloader, device)
    
        # Track stats
        if (epoch % 1) == 0:
            stats['loss'].append(
                np.mean(iteration_losses)
            )
            stats['val_accuracy'].append(
                val_accuracy
            )
            stats['allocated_memory'].append(torch.cuda.memory_allocated())
            stats['reserved_memory'].append(torch.cuda.memory_reserved())
            stats['time_per_epoch'].append(epoch_end_time - epoch_start_time)
            stats['total_time_per_epoch'].append(time.time() - start_time)
    
        # Store best model
        if (val_accuracy > stats['max_val_accuracy']):
            if (val_accuracy > val_accuracy_storing_threshold):
                stats['max_val_accuracy'] = val_accuracy
                print('==> Saving model ...')
                state = {
                    'net': model.state_dict(),
                    'epoch': epoch,
                    'acc':val_accuracy
                }
                save_path = checkpoint_dir / f"{MODEL_NAME}_L{L}_max_acc.pth"
                torch.save(state, save_path)
    
        if DEBUG:
            print('==> Saving model ... DEBUG')
            state = {
                'net': model.state_dict(),
                'epoch': epoch,
                'acc':val_accuracy
            }
            save_path = checkpoint_dir / f"{MODEL_NAME}_L{L}_max_acc.pth"
            torch.save(state, save_path)
            
        # Print progress
        if (epoch % print_progress_every) == 0:
            print(f"L {L} Epoch {epoch} Loss {stats['loss'][-1]:.3f} Val Acc {stats['val_accuracy'][-1]:.3f}")
    stats_list.append(stats)
# Out:
# L 1 Epoch 0 Loss 3.186 Val Acc 17.940
# L 1 Epoch 1 Loss 2.121 Val Acc 24.860
# L 1 Epoch 2 Loss 1.961 Val Acc 30.920
# L 1 Epoch 3 Loss 1.856 Val Acc 20.440
# L 1 Epoch 4 Loss 1.865 Val Acc 34.960
# L 1 Epoch 5 Loss 1.777 Val Acc 29.680
# ==> Saving model ...
# L 1 Epoch 6 Loss 1.733 Val Acc 40.380
# L 1 Epoch 7 Loss 1.688 Val Acc 35.580
# L 1 Epoch 8 Loss 1.635 Val Acc 39.840
# ==> Saving model ...
# L 1 Epoch 9 Loss 1.619 Val Acc 40.420
# ==> Saving model ...
# L 1 Epoch 10 Loss 1.569 Val Acc 41.560
# ==> Saving model ...
# L 1 Epoch 11 Loss 1.564 Val Acc 42.480
# ==> Saving model ...
# L 1 Epoch 12 Loss 1.483 Val Acc 46.320
# L 1 Epoch 13 Loss 1.441 Val Acc 45.300
# L 1 Epoch 14 Loss 1.431 Val Acc 46.280
# L 1 Epoch 15 Loss 1.424 Val Acc 43.800
# ==> Saving model ...
# L 1 Epoch 16 Loss 1.453 Val Acc 49.200
# ==> Saving model ...
# L 1 Epoch 17 Loss 1.399 Val Acc 49.440
# L 1 Epoch 18 Loss 1.322 Val Acc 47.920
# L 1 Epoch 19 Loss 1.373 Val Acc 48.300
# L 1 Epoch 20 Loss 1.340 Val Acc 48.560
# ==> Saving model ...
# L 1 Epoch 21 Loss 1.255 Val Acc 50.080
# ==> Saving model ...
# L 1 Epoch 22 Loss 1.238 Val Acc 53.480
# L 1 Epoch 23 Loss 1.146 Val Acc 51.520
# L 1 Epoch 24 Loss 1.137 Val Acc 52.080
# L 1 Epoch 25 Loss 1.196 Val Acc 49.680
# ==> Saving model ...
# L 1 Epoch 26 Loss 1.146 Val Acc 53.600
# ==> Saving model ...
# L 1 Epoch 27 Loss 1.157 Val Acc 57.380
# L 1 Epoch 28 Loss 1.097 Val Acc 56.140
# L 1 Epoch 29 Loss 1.058 Val Acc 55.820
# ==> Saving model ...
# L 1 Epoch 30 Loss 1.016 Val Acc 58.340
# L 1 Epoch 31 Loss 1.000 Val Acc 57.380
# L 1 Epoch 32 Loss 0.999 Val Acc 58.000
# ==> Saving model ...
# L 1 Epoch 33 Loss 1.032 Val Acc 58.520
# L 1 Epoch 34 Loss 0.968 Val Acc 58.520
# ==> Saving model ...
# L 1 Epoch 35 Loss 0.921 Val Acc 59.980
# L 1 Epoch 36 Loss 0.952 Val Acc 53.580
# L 1 Epoch 37 Loss 0.949 Val Acc 59.040
# L 1 Epoch 38 Loss 0.900 Val Acc 58.900
# L 1 Epoch 39 Loss 0.888 Val Acc 59.120
# L 1 Epoch 40 Loss 0.821 Val Acc 57.920
# ==> Saving model ...
# L 1 Epoch 41 Loss 0.780 Val Acc 61.780
# L 1 Epoch 42 Loss 0.791 Val Acc 60.760
# ==> Saving model ...
# L 1 Epoch 43 Loss 0.751 Val Acc 64.120
# L 1 Epoch 44 Loss 0.702 Val Acc 62.760
# ==> Saving model ...
# L 1 Epoch 45 Loss 0.607 Val Acc 64.700
# L 1 Epoch 46 Loss 0.645 Val Acc 54.460
# L 1 Epoch 47 Loss 0.790 Val Acc 63.320
# L 1 Epoch 48 Loss 0.605 Val Acc 63.760
# L 1 Epoch 49 Loss 0.605 Val Acc 63.540
# L 1 Epoch 50 Loss 0.647 Val Acc 62.140
# L 1 Epoch 51 Loss 0.655 Val Acc 63.040
# ==> Saving model ...
# L 1 Epoch 52 Loss 0.494 Val Acc 65.060
# L 1 Epoch 53 Loss 0.611 Val Acc 63.660
# L 1 Epoch 54 Loss 0.535 Val Acc 64.740
# ==> Saving model ...
# L 1 Epoch 55 Loss 0.475 Val Acc 65.360
# L 1 Epoch 56 Loss 0.487 Val Acc 60.100
# L 1 Epoch 57 Loss 0.616 Val Acc 64.160
# L 1 Epoch 58 Loss 0.546 Val Acc 62.880
# ==> Saving model ...
# L 1 Epoch 59 Loss 0.353 Val Acc 66.060
# L 1 Epoch 60 Loss 0.390 Val Acc 63.880
# L 1 Epoch 61 Loss 0.549 Val Acc 62.560
# ==> Saving model ...
# L 1 Epoch 62 Loss 0.413 Val Acc 67.400
# L 1 Epoch 63 Loss 0.378 Val Acc 67.260
# L 1 Epoch 64 Loss 0.283 Val Acc 65.900
# L 1 Epoch 65 Loss 0.290 Val Acc 64.760
# ==> Saving model ...
# L 1 Epoch 66 Loss 0.262 Val Acc 68.480
# L 1 Epoch 67 Loss 0.301 Val Acc 65.660
# L 1 Epoch 68 Loss 0.241 Val Acc 64.780
# L 1 Epoch 69 Loss 0.588 Val Acc 61.440
# L 1 Epoch 70 Loss 0.568 Val Acc 63.180
# L 1 Epoch 71 Loss 0.409 Val Acc 65.780
# ==> Saving model ...
# L 1 Epoch 72 Loss 0.190 Val Acc 68.900
# L 1 Epoch 73 Loss 0.245 Val Acc 67.040
# L 1 Epoch 74 Loss 0.296 Val Acc 65.620
# L 1 Epoch 75 Loss 0.202 Val Acc 67.800
# L 1 Epoch 76 Loss 0.288 Val Acc 67.360
# L 1 Epoch 77 Loss 0.240 Val Acc 65.740
# L 1 Epoch 78 Loss 0.401 Val Acc 65.480
# L 1 Epoch 79 Loss 0.198 Val Acc 68.660
# L 1 Epoch 80 Loss 0.239 Val Acc 65.780
# L 1 Epoch 81 Loss 0.299 Val Acc 67.600
# L 1 Epoch 82 Loss 0.272 Val Acc 68.780
# L 1 Epoch 83 Loss 0.220 Val Acc 67.480
# L 1 Epoch 84 Loss 0.187 Val Acc 67.680
# L 1 Epoch 85 Loss 0.202 Val Acc 67.360
# L 1 Epoch 86 Loss 0.166 Val Acc 67.020
# L 1 Epoch 87 Loss 0.174 Val Acc 66.180
# L 1 Epoch 88 Loss 0.504 Val Acc 64.620
# L 1 Epoch 89 Loss 0.407 Val Acc 67.100
# L 1 Epoch 90 Loss 0.228 Val Acc 66.780
# L 1 Epoch 91 Loss 0.296 Val Acc 67.660
# ==> Saving model ...
# L 1 Epoch 92 Loss 0.152 Val Acc 69.920
# L 1 Epoch 93 Loss 0.196 Val Acc 67.940
# L 1 Epoch 94 Loss 0.137 Val Acc 69.000
# L 1 Epoch 95 Loss 0.212 Val Acc 69.340
# ==> Saving model ...
# L 1 Epoch 96 Loss 0.182 Val Acc 70.320
# L 1 Epoch 97 Loss 0.118 Val Acc 69.460
# L 1 Epoch 98 Loss 0.162 Val Acc 69.100
# L 1 Epoch 99 Loss 0.185 Val Acc 70.040
# L 1 Epoch 100 Loss 0.134 Val Acc 69.380
# L 1 Epoch 101 Loss 0.142 Val Acc 68.680
# L 1 Epoch 102 Loss 0.146 Val Acc 68.660
# L 1 Epoch 103 Loss 0.102 Val Acc 69.000
# L 1 Epoch 104 Loss 0.116 Val Acc 67.240
# L 1 Epoch 105 Loss 0.252 Val Acc 64.600
# L 1 Epoch 106 Loss 0.490 Val Acc 67.120
# L 1 Epoch 107 Loss 0.251 Val Acc 68.140
# L 1 Epoch 108 Loss 0.387 Val Acc 66.900
# L 1 Epoch 109 Loss 0.207 Val Acc 68.460
# L 1 Epoch 110 Loss 0.157 Val Acc 68.780
# L 1 Epoch 111 Loss 0.166 Val Acc 69.660
# L 1 Epoch 112 Loss 0.094 Val Acc 70.080
# L 1 Epoch 113 Loss 0.152 Val Acc 69.500
# ==> Saving model ...
# L 1 Epoch 114 Loss 0.115 Val Acc 70.440
# L 1 Epoch 115 Loss 0.119 Val Acc 69.000
# L 1 Epoch 116 Loss 0.185 Val Acc 68.420
# L 1 Epoch 117 Loss 0.163 Val Acc 69.500
# L 1 Epoch 118 Loss 0.213 Val Acc 69.280
# L 1 Epoch 119 Loss 0.279 Val Acc 68.860
# L 1 Epoch 120 Loss 0.160 Val Acc 69.320
# L 1 Epoch 121 Loss 0.163 Val Acc 66.920
# L 1 Epoch 122 Loss 0.186 Val Acc 69.300
# ==> Saving model ...
# L 1 Epoch 123 Loss 0.134 Val Acc 70.540
# ==> Saving model ...
# L 1 Epoch 124 Loss 0.078 Val Acc 71.920
# L 1 Epoch 125 Loss 0.075 Val Acc 70.640
# L 1 Epoch 126 Loss 0.061 Val Acc 69.960
# L 1 Epoch 127 Loss 0.050 Val Acc 71.500
# L 1 Epoch 128 Loss 0.077 Val Acc 70.500
# L 1 Epoch 129 Loss 0.120 Val Acc 70.900
# L 1 Epoch 130 Loss 0.075 Val Acc 71.100
# L 1 Epoch 131 Loss 0.150 Val Acc 71.180
# L 1 Epoch 132 Loss 0.087 Val Acc 71.280
# L 1 Epoch 133 Loss 0.064 Val Acc 71.240
# L 1 Epoch 134 Loss 0.073 Val Acc 70.700
# L 1 Epoch 135 Loss 0.065 Val Acc 70.780
# ==> Saving model ...
# L 1 Epoch 136 Loss 0.044 Val Acc 72.540
# ==> Saving model ...
# L 1 Epoch 137 Loss 0.038 Val Acc 73.080
# L 1 Epoch 138 Loss 0.062 Val Acc 70.480
# L 1 Epoch 139 Loss 0.056 Val Acc 72.240
# L 1 Epoch 140 Loss 0.078 Val Acc 71.440
# L 1 Epoch 141 Loss 0.093 Val Acc 70.100
# L 1 Epoch 142 Loss 0.107 Val Acc 70.240
# L 1 Epoch 143 Loss 0.090 Val Acc 71.780
# L 1 Epoch 144 Loss 0.054 Val Acc 70.800
# L 1 Epoch 145 Loss 0.039 Val Acc 72.080
# L 1 Epoch 146 Loss 0.083 Val Acc 70.500
# L 1 Epoch 147 Loss 0.056 Val Acc 71.100
# L 1 Epoch 148 Loss 0.061 Val Acc 71.980
# L 1 Epoch 149 Loss 0.047 Val Acc 72.100
# L 1 Epoch 150 Loss 0.045 Val Acc 72.320
# L 1 Epoch 151 Loss 0.033 Val Acc 72.200
# L 1 Epoch 152 Loss 0.046 Val Acc 72.220
# L 1 Epoch 153 Loss 0.053 Val Acc 72.040
# L 1 Epoch 154 Loss 0.054 Val Acc 72.460
# L 1 Epoch 155 Loss 0.033 Val Acc 71.920
# L 1 Epoch 156 Loss 0.031 Val Acc 72.420
# L 1 Epoch 157 Loss 0.038 Val Acc 72.160
# L 1 Epoch 158 Loss 0.056 Val Acc 72.080
# L 1 Epoch 159 Loss 0.044 Val Acc 71.880
# L 1 Epoch 160 Loss 0.033 Val Acc 71.820
# L 1 Epoch 161 Loss 0.028 Val Acc 72.780
# L 1 Epoch 162 Loss 0.036 Val Acc 72.300
# L 1 Epoch 163 Loss 0.040 Val Acc 71.980
# L 1 Epoch 164 Loss 0.065 Val Acc 71.980
# L 1 Epoch 165 Loss 0.048 Val Acc 72.540
# L 1 Epoch 166 Loss 0.037 Val Acc 72.380
# L 1 Epoch 167 Loss 0.020 Val Acc 72.380
# ==> Saving model ...
# L 1 Epoch 168 Loss 0.015 Val Acc 73.320
# L 1 Epoch 169 Loss 0.021 Val Acc 73.060
# L 1 Epoch 170 Loss 0.017 Val Acc 72.820
# L 1 Epoch 171 Loss 0.024 Val Acc 71.840
# L 1 Epoch 172 Loss 0.025 Val Acc 73.120
# L 1 Epoch 173 Loss 0.030 Val Acc 71.460
# L 1 Epoch 174 Loss 0.020 Val Acc 71.620
# L 1 Epoch 175 Loss 0.027 Val Acc 72.580
# L 1 Epoch 176 Loss 0.026 Val Acc 72.000
# L 1 Epoch 177 Loss 0.018 Val Acc 72.600
# L 1 Epoch 178 Loss 0.021 Val Acc 72.560
# L 1 Epoch 179 Loss 0.022 Val Acc 72.620
# L 1 Epoch 180 Loss 0.028 Val Acc 72.480
# L 1 Epoch 181 Loss 0.034 Val Acc 72.900
# ==> Saving model ...
# L 1 Epoch 182 Loss 0.015 Val Acc 73.420
# ==> Saving model ...
# L 1 Epoch 183 Loss 0.014 Val Acc 73.680
# L 1 Epoch 184 Loss 0.027 Val Acc 72.720
# L 1 Epoch 185 Loss 0.017 Val Acc 72.700
# L 1 Epoch 186 Loss 0.031 Val Acc 72.320
# L 1 Epoch 187 Loss 0.023 Val Acc 71.980
# L 1 Epoch 188 Loss 0.033 Val Acc 72.260
# L 1 Epoch 189 Loss 0.017 Val Acc 73.140
# L 1 Epoch 190 Loss 0.024 Val Acc 73.580
# L 1 Epoch 191 Loss 0.020 Val Acc 72.820
# L 1 Epoch 192 Loss 0.024 Val Acc 72.260
# L 1 Epoch 193 Loss 0.015 Val Acc 72.720
# L 1 Epoch 194 Loss 0.023 Val Acc 72.480
# L 1 Epoch 195 Loss 0.019 Val Acc 73.040
# L 1 Epoch 196 Loss 0.016 Val Acc 72.500
# L 1 Epoch 197 Loss 0.010 Val Acc 73.000
# L 1 Epoch 198 Loss 0.025 Val Acc 73.000
# L 1 Epoch 199 Loss 0.019 Val Acc 72.660
# L 2 Epoch 0 Loss 2.523 Val Acc 10.900
# L 2 Epoch 1 Loss 2.004 Val Acc 23.080
# L 2 Epoch 2 Loss 1.794 Val Acc 35.040
# L 2 Epoch 3 Loss 1.677 Val Acc 36.620
# ==> Saving model ...
# L 2 Epoch 4 Loss 1.594 Val Acc 41.060
# L 2 Epoch 5 Loss 1.507 Val Acc 39.240
# L 2 Epoch 6 Loss 1.511 Val Acc 36.420
# ==> Saving model ...
# L 2 Epoch 7 Loss 1.547 Val Acc 43.900
# ==> Saving model ...
# L 2 Epoch 8 Loss 1.544 Val Acc 47.260
# L 2 Epoch 9 Loss 1.374 Val Acc 42.400
# ==> Saving model ...
# L 2 Epoch 10 Loss 1.431 Val Acc 51.660
# L 2 Epoch 11 Loss 1.347 Val Acc 47.520
# ==> Saving model ...
# L 2 Epoch 12 Loss 1.377 Val Acc 54.320
# L 2 Epoch 13 Loss 1.317 Val Acc 52.920
# L 2 Epoch 14 Loss 1.304 Val Acc 51.560
# ==> Saving model ...
# L 2 Epoch 15 Loss 1.211 Val Acc 55.740
# L 2 Epoch 16 Loss 1.128 Val Acc 55.720
# ==> Saving model ...
# L 2 Epoch 17 Loss 1.108 Val Acc 56.800
# L 2 Epoch 18 Loss 1.126 Val Acc 56.540
# ==> Saving model ...
# L 2 Epoch 19 Loss 1.227 Val Acc 59.560
# L 2 Epoch 20 Loss 1.089 Val Acc 59.460
# L 2 Epoch 21 Loss 0.996 Val Acc 59.200
# ==> Saving model ...
# L 2 Epoch 22 Loss 0.980 Val Acc 60.860
# L 2 Epoch 23 Loss 0.956 Val Acc 59.420
# L 2 Epoch 24 Loss 0.968 Val Acc 60.860
# ==> Saving model ...
# L 2 Epoch 25 Loss 1.011 Val Acc 62.060
# ==> Saving model ...
# L 2 Epoch 26 Loss 0.918 Val Acc 62.440
# ==> Saving model ...
# L 2 Epoch 27 Loss 0.975 Val Acc 62.820
# L 2 Epoch 28 Loss 0.946 Val Acc 62.400
# L 2 Epoch 29 Loss 0.798 Val Acc 59.480
# L 2 Epoch 30 Loss 0.839 Val Acc 55.860
# L 2 Epoch 31 Loss 0.852 Val Acc 61.560
# L 2 Epoch 32 Loss 0.786 Val Acc 61.400
# ==> Saving model ...
# L 2 Epoch 33 Loss 0.773 Val Acc 65.880
# L 2 Epoch 34 Loss 0.738 Val Acc 61.860
# L 2 Epoch 35 Loss 0.750 Val Acc 61.560
# L 2 Epoch 36 Loss 0.732 Val Acc 63.280
# L 2 Epoch 37 Loss 0.697 Val Acc 62.860
# L 2 Epoch 38 Loss 0.866 Val Acc 62.240
# L 2 Epoch 39 Loss 0.664 Val Acc 58.160
# L 2 Epoch 40 Loss 0.764 Val Acc 63.540
# L 2 Epoch 41 Loss 0.678 Val Acc 65.780
# ==> Saving model ...
# L 2 Epoch 42 Loss 0.624 Val Acc 66.440
# L 2 Epoch 43 Loss 0.487 Val Acc 64.660
# ==> Saving model ...
# L 2 Epoch 44 Loss 0.508 Val Acc 66.940
# L 2 Epoch 45 Loss 0.608 Val Acc 66.180
# L 2 Epoch 46 Loss 0.454 Val Acc 65.680
# ==> Saving model ...
# L 2 Epoch 47 Loss 0.482 Val Acc 67.000
# L 2 Epoch 48 Loss 0.498 Val Acc 64.700
# ==> Saving model ...
# L 2 Epoch 49 Loss 0.536 Val Acc 67.980
# ==> Saving model ...
# L 2 Epoch 50 Loss 0.394 Val Acc 68.360
# L 2 Epoch 51 Loss 0.389 Val Acc 66.480
# L 2 Epoch 52 Loss 0.419 Val Acc 68.040
# L 2 Epoch 53 Loss 0.548 Val Acc 67.840
# ==> Saving model ...
# L 2 Epoch 54 Loss 0.411 Val Acc 68.580
# L 2 Epoch 55 Loss 0.519 Val Acc 67.940
# L 2 Epoch 56 Loss 0.445 Val Acc 65.000
# L 2 Epoch 57 Loss 0.546 Val Acc 64.160
# L 2 Epoch 58 Loss 0.469 Val Acc 62.520
# L 2 Epoch 59 Loss 0.586 Val Acc 61.680
# L 2 Epoch 60 Loss 0.499 Val Acc 63.400
# L 2 Epoch 61 Loss 0.376 Val Acc 66.980
# L 2 Epoch 62 Loss 0.241 Val Acc 68.240
# ==> Saving model ...
# L 2 Epoch 63 Loss 0.280 Val Acc 69.660
# L 2 Epoch 64 Loss 0.248 Val Acc 69.520
# L 2 Epoch 65 Loss 0.238 Val Acc 68.680
# L 2 Epoch 66 Loss 0.216 Val Acc 69.180
# L 2 Epoch 67 Loss 0.330 Val Acc 67.080
# L 2 Epoch 68 Loss 0.276 Val Acc 69.540
# L 2 Epoch 69 Loss 0.272 Val Acc 64.320
# L 2 Epoch 70 Loss 0.312 Val Acc 67.260
# L 2 Epoch 71 Loss 0.340 Val Acc 63.460
# L 2 Epoch 72 Loss 0.456 Val Acc 66.240
# L 2 Epoch 73 Loss 0.333 Val Acc 67.700
# L 2 Epoch 74 Loss 0.374 Val Acc 64.240
# L 2 Epoch 75 Loss 0.337 Val Acc 65.820
# L 2 Epoch 76 Loss 0.368 Val Acc 69.460
# L 2 Epoch 77 Loss 0.283 Val Acc 66.440
# L 2 Epoch 78 Loss 0.281 Val Acc 64.660
# L 2 Epoch 79 Loss 0.191 Val Acc 68.400
# L 2 Epoch 80 Loss 0.259 Val Acc 68.120
# L 2 Epoch 81 Loss 0.254 Val Acc 67.580
# ==> Saving model ...
# L 2 Epoch 82 Loss 0.292 Val Acc 69.740
# L 2 Epoch 83 Loss 0.197 Val Acc 69.480
# L 2 Epoch 84 Loss 0.271 Val Acc 68.260
# L 2 Epoch 85 Loss 0.272 Val Acc 68.620
# ==> Saving model ...
# L 2 Epoch 86 Loss 0.288 Val Acc 70.220
# L 2 Epoch 87 Loss 0.170 Val Acc 69.880
# ==> Saving model ...
# L 2 Epoch 88 Loss 0.142 Val Acc 70.980
# ==> Saving model ...
# L 2 Epoch 89 Loss 0.158 Val Acc 71.700
# L 2 Epoch 90 Loss 0.217 Val Acc 67.120
# L 2 Epoch 91 Loss 0.356 Val Acc 68.060
# L 2 Epoch 92 Loss 0.218 Val Acc 70.780
# L 2 Epoch 93 Loss 0.164 Val Acc 70.260
# L 2 Epoch 94 Loss 0.180 Val Acc 71.560
# L 2 Epoch 95 Loss 0.128 Val Acc 69.680
# L 2 Epoch 96 Loss 0.180 Val Acc 69.020
# L 2 Epoch 97 Loss 0.304 Val Acc 68.560
# L 2 Epoch 98 Loss 0.261 Val Acc 67.280
# L 2 Epoch 99 Loss 0.273 Val Acc 68.760
# L 2 Epoch 100 Loss 0.216 Val Acc 69.440
# L 2 Epoch 101 Loss 0.215 Val Acc 67.720
# L 2 Epoch 102 Loss 0.254 Val Acc 68.100
# L 2 Epoch 103 Loss 0.201 Val Acc 69.760
# L 2 Epoch 104 Loss 0.203 Val Acc 70.320
# L 2 Epoch 105 Loss 0.126 Val Acc 70.500
# L 2 Epoch 106 Loss 0.136 Val Acc 70.980
# ==> Saving model ...
# L 2 Epoch 107 Loss 0.127 Val Acc 71.940
# L 2 Epoch 108 Loss 0.169 Val Acc 71.400
# L 2 Epoch 109 Loss 0.139 Val Acc 69.040
# L 2 Epoch 110 Loss 0.245 Val Acc 68.740
# L 2 Epoch 111 Loss 0.254 Val Acc 70.120
# L 2 Epoch 112 Loss 0.142 Val Acc 70.980
# L 2 Epoch 113 Loss 0.159 Val Acc 71.540
# ==> Saving model ...
# L 2 Epoch 114 Loss 0.137 Val Acc 72.680
# ==> Saving model ...
# L 2 Epoch 115 Loss 0.094 Val Acc 73.280
# L 2 Epoch 116 Loss 0.114 Val Acc 71.320
# L 2 Epoch 117 Loss 0.054 Val Acc 73.000
# L 2 Epoch 118 Loss 0.068 Val Acc 72.500
# L 2 Epoch 119 Loss 0.100 Val Acc 71.320
# L 2 Epoch 120 Loss 0.087 Val Acc 72.000
# L 2 Epoch 121 Loss 0.163 Val Acc 72.440
# L 2 Epoch 122 Loss 0.167 Val Acc 66.660
# L 2 Epoch 123 Loss 0.242 Val Acc 67.560
# L 2 Epoch 124 Loss 0.148 Val Acc 70.960
# L 2 Epoch 125 Loss 0.075 Val Acc 71.220
# L 2 Epoch 126 Loss 0.080 Val Acc 70.600
# L 2 Epoch 127 Loss 0.074 Val Acc 72.040
# L 2 Epoch 128 Loss 0.092 Val Acc 72.120
# L 2 Epoch 129 Loss 0.065 Val Acc 72.760
# L 2 Epoch 130 Loss 0.112 Val Acc 70.880
# L 2 Epoch 131 Loss 0.103 Val Acc 71.080
# L 2 Epoch 132 Loss 0.082 Val Acc 73.280
# L 2 Epoch 133 Loss 0.118 Val Acc 70.700
# L 2 Epoch 134 Loss 0.101 Val Acc 72.500
# L 2 Epoch 135 Loss 0.059 Val Acc 71.620
# L 2 Epoch 136 Loss 0.066 Val Acc 71.540
# L 2 Epoch 137 Loss 0.072 Val Acc 72.860
# ==> Saving model ...
# L 2 Epoch 138 Loss 0.042 Val Acc 73.400
# L 2 Epoch 139 Loss 0.056 Val Acc 72.700
# L 2 Epoch 140 Loss 0.064 Val Acc 71.920
# L 2 Epoch 141 Loss 0.068 Val Acc 72.240
# L 2 Epoch 142 Loss 0.055 Val Acc 73.100
# ==> Saving model ...
# L 2 Epoch 143 Loss 0.039 Val Acc 73.480
# L 2 Epoch 144 Loss 0.061 Val Acc 70.840
# L 2 Epoch 145 Loss 0.098 Val Acc 71.980
# L 2 Epoch 146 Loss 0.047 Val Acc 73.380
# L 2 Epoch 147 Loss 0.055 Val Acc 72.880
# L 2 Epoch 148 Loss 0.046 Val Acc 73.360
# ==> Saving model ...
# L 2 Epoch 149 Loss 0.029 Val Acc 73.880
# L 2 Epoch 150 Loss 0.031 Val Acc 72.480
# L 2 Epoch 151 Loss 0.035 Val Acc 73.640
# L 2 Epoch 152 Loss 0.034 Val Acc 73.480
# L 2 Epoch 153 Loss 0.037 Val Acc 72.480
# L 2 Epoch 154 Loss 0.027 Val Acc 73.020
# L 2 Epoch 155 Loss 0.022 Val Acc 73.760
# L 2 Epoch 156 Loss 0.032 Val Acc 72.980
# ==> Saving model ...
# L 2 Epoch 157 Loss 0.038 Val Acc 73.940
# L 2 Epoch 158 Loss 0.035 Val Acc 72.780
# L 2 Epoch 159 Loss 0.036 Val Acc 73.840
# L 2 Epoch 160 Loss 0.026 Val Acc 73.640
# L 2 Epoch 161 Loss 0.028 Val Acc 73.140
# ==> Saving model ...
# L 2 Epoch 162 Loss 0.018 Val Acc 74.160
# L 2 Epoch 163 Loss 0.011 Val Acc 73.660
# L 2 Epoch 164 Loss 0.020 Val Acc 71.800
# L 2 Epoch 165 Loss 0.028 Val Acc 73.840
# L 2 Epoch 166 Loss 0.043 Val Acc 72.540
# L 2 Epoch 167 Loss 0.027 Val Acc 73.500
# L 2 Epoch 168 Loss 0.026 Val Acc 73.500
# ==> Saving model ...
# L 2 Epoch 169 Loss 0.025 Val Acc 74.260
# L 2 Epoch 170 Loss 0.031 Val Acc 73.260
# L 2 Epoch 171 Loss 0.020 Val Acc 73.460
# L 2 Epoch 172 Loss 0.028 Val Acc 73.600
# L 2 Epoch 173 Loss 0.027 Val Acc 73.460
# L 2 Epoch 174 Loss 0.023 Val Acc 72.960
# L 2 Epoch 175 Loss 0.024 Val Acc 73.480
# L 2 Epoch 176 Loss 0.023 Val Acc 74.160
# L 2 Epoch 177 Loss 0.029 Val Acc 73.620
# ==> Saving model ...
# L 2 Epoch 178 Loss 0.021 Val Acc 74.360
# ==> Saving model ...
# L 2 Epoch 179 Loss 0.017 Val Acc 74.720
# L 2 Epoch 180 Loss 0.019 Val Acc 74.500
# L 2 Epoch 181 Loss 0.021 Val Acc 72.920
# L 2 Epoch 182 Loss 0.015 Val Acc 73.720
# L 2 Epoch 183 Loss 0.026 Val Acc 74.380
# L 2 Epoch 184 Loss 0.027 Val Acc 74.300
# ==> Saving model ...
# L 2 Epoch 185 Loss 0.030 Val Acc 74.780
# L 2 Epoch 186 Loss 0.020 Val Acc 73.960
# L 2 Epoch 187 Loss 0.016 Val Acc 74.020
# L 2 Epoch 188 Loss 0.020 Val Acc 73.500
# L 2 Epoch 189 Loss 0.016 Val Acc 74.380
# L 2 Epoch 190 Loss 0.016 Val Acc 74.220
# L 2 Epoch 191 Loss 0.025 Val Acc 74.220
# L 2 Epoch 192 Loss 0.021 Val Acc 73.080
# L 2 Epoch 193 Loss 0.016 Val Acc 74.040
# L 2 Epoch 194 Loss 0.022 Val Acc 74.560
# L 2 Epoch 195 Loss 0.018 Val Acc 74.500
# L 2 Epoch 196 Loss 0.016 Val Acc 72.740
# L 2 Epoch 197 Loss 0.014 Val Acc 74.660
# L 2 Epoch 198 Loss 0.019 Val Acc 74.740
# L 2 Epoch 199 Loss 0.031 Val Acc 74.120
# L 3 Epoch 0 Loss 3.707 Val Acc 13.900
# L 3 Epoch 1 Loss 2.186 Val Acc 21.260
# L 3 Epoch 2 Loss 2.088 Val Acc 18.260
# L 3 Epoch 3 Loss 2.058 Val Acc 16.160
# L 3 Epoch 4 Loss 1.994 Val Acc 25.200
# L 3 Epoch 5 Loss 1.909 Val Acc 24.240
# L 3 Epoch 6 Loss 1.865 Val Acc 27.920
# L 3 Epoch 7 Loss 1.802 Val Acc 32.480
# L 3 Epoch 8 Loss 1.729 Val Acc 34.160
# L 3 Epoch 9 Loss 1.709 Val Acc 39.220
# L 3 Epoch 10 Loss 1.678 Val Acc 37.880
# ==> Saving model ...
# L 3 Epoch 11 Loss 1.621 Val Acc 41.120
# ==> Saving model ...
# L 3 Epoch 12 Loss 1.542 Val Acc 44.580
# ==> Saving model ...
# L 3 Epoch 13 Loss 1.558 Val Acc 45.600
# L 3 Epoch 14 Loss 1.512 Val Acc 43.440
# L 3 Epoch 15 Loss 1.496 Val Acc 44.480
# ==> Saving model ...
# L 3 Epoch 16 Loss 1.462 Val Acc 48.220
# L 3 Epoch 17 Loss 1.435 Val Acc 45.880
# L 3 Epoch 18 Loss 1.415 Val Acc 46.300
# ==> Saving model ...
# L 3 Epoch 19 Loss 1.329 Val Acc 51.700
# ==> Saving model ...
# L 3 Epoch 20 Loss 1.270 Val Acc 52.680
# L 3 Epoch 21 Loss 1.281 Val Acc 50.960
# L 3 Epoch 22 Loss 1.237 Val Acc 52.500
# ==> Saving model ...
# L 3 Epoch 23 Loss 1.240 Val Acc 55.440
# L 3 Epoch 24 Loss 1.211 Val Acc 54.800
# L 3 Epoch 25 Loss 1.222 Val Acc 52.760
# ==> Saving model ...
# L 3 Epoch 26 Loss 1.141 Val Acc 55.700
# L 3 Epoch 27 Loss 1.122 Val Acc 53.420
# ==> Saving model ...
# L 3 Epoch 28 Loss 1.075 Val Acc 56.960
# L 3 Epoch 29 Loss 1.032 Val Acc 56.960
# ==> Saving model ...
# L 3 Epoch 30 Loss 1.052 Val Acc 61.340
# L 3 Epoch 31 Loss 0.993 Val Acc 55.920
# L 3 Epoch 32 Loss 0.979 Val Acc 58.400
# L 3 Epoch 33 Loss 1.067 Val Acc 53.640
# L 3 Epoch 34 Loss 0.956 Val Acc 61.340
# L 3 Epoch 35 Loss 0.905 Val Acc 61.160
# ==> Saving model ...
# L 3 Epoch 36 Loss 0.818 Val Acc 64.880
# L 3 Epoch 37 Loss 0.868 Val Acc 61.940
# L 3 Epoch 38 Loss 0.852 Val Acc 61.840
# ==> Saving model ...
# L 3 Epoch 39 Loss 0.803 Val Acc 65.740
# ==> Saving model ...
# L 3 Epoch 40 Loss 0.676 Val Acc 65.920
# L 3 Epoch 41 Loss 0.713 Val Acc 64.820
# L 3 Epoch 42 Loss 0.716 Val Acc 64.120
# L 3 Epoch 43 Loss 0.652 Val Acc 63.600
# L 3 Epoch 44 Loss 0.604 Val Acc 63.080
# L 3 Epoch 45 Loss 0.727 Val Acc 64.440
# ==> Saving model ...
# L 3 Epoch 46 Loss 0.591 Val Acc 67.100
# L 3 Epoch 47 Loss 0.549 Val Acc 66.500
# L 3 Epoch 48 Loss 0.541 Val Acc 64.240
# ==> Saving model ...
# L 3 Epoch 49 Loss 0.575 Val Acc 67.740
# L 3 Epoch 50 Loss 0.495 Val Acc 65.520
# L 3 Epoch 51 Loss 0.538 Val Acc 66.820
# ==> Saving model ...
# L 3 Epoch 52 Loss 0.485 Val Acc 67.920
# L 3 Epoch 53 Loss 0.519 Val Acc 62.040
# ==> Saving model ...
# L 3 Epoch 54 Loss 0.623 Val Acc 68.220
# L 3 Epoch 55 Loss 0.489 Val Acc 67.120
# ==> Saving model ...
# L 3 Epoch 56 Loss 0.463 Val Acc 68.620
# L 3 Epoch 57 Loss 0.337 Val Acc 67.080
# ==> Saving model ...
# L 3 Epoch 58 Loss 0.297 Val Acc 68.980
# L 3 Epoch 59 Loss 0.306 Val Acc 68.440
# L 3 Epoch 60 Loss 0.528 Val Acc 66.360
# L 3 Epoch 61 Loss 0.496 Val Acc 67.760
# ==> Saving model ...
# L 3 Epoch 62 Loss 0.413 Val Acc 69.100
# L 3 Epoch 63 Loss 0.323 Val Acc 69.080
# ==> Saving model ...
# L 3 Epoch 64 Loss 0.359 Val Acc 69.200
# ==> Saving model ...
# L 3 Epoch 65 Loss 0.343 Val Acc 70.000
# L 3 Epoch 66 Loss 0.344 Val Acc 69.900
# L 3 Epoch 67 Loss 0.461 Val Acc 66.880
# ==> Saving model ...
# L 3 Epoch 68 Loss 0.418 Val Acc 70.340
# L 3 Epoch 69 Loss 0.508 Val Acc 69.120
# ==> Saving model ...
# L 3 Epoch 70 Loss 0.433 Val Acc 72.220
# L 3 Epoch 71 Loss 0.273 Val Acc 71.340
# L 3 Epoch 72 Loss 0.265 Val Acc 70.480
# L 3 Epoch 73 Loss 0.217 Val Acc 72.200
# L 3 Epoch 74 Loss 0.193 Val Acc 71.100
# L 3 Epoch 75 Loss 0.288 Val Acc 70.940
# L 3 Epoch 76 Loss 0.319 Val Acc 67.240
# L 3 Epoch 77 Loss 0.332 Val Acc 69.840
# L 3 Epoch 78 Loss 0.346 Val Acc 69.180
# L 3 Epoch 79 Loss 0.302 Val Acc 71.120
# ==> Saving model ...
# L 3 Epoch 80 Loss 0.329 Val Acc 72.840
# L 3 Epoch 81 Loss 0.260 Val Acc 69.660
# ==> Saving model ...
# L 3 Epoch 82 Loss 0.236 Val Acc 72.980
# ==> Saving model ...
# L 3 Epoch 83 Loss 0.172 Val Acc 73.020
# L 3 Epoch 84 Loss 0.233 Val Acc 71.520
# L 3 Epoch 85 Loss 0.215 Val Acc 71.940
# L 3 Epoch 86 Loss 0.302 Val Acc 71.280
# ==> Saving model ...
# L 3 Epoch 87 Loss 0.172 Val Acc 73.100
# L 3 Epoch 88 Loss 0.143 Val Acc 71.880
# L 3 Epoch 89 Loss 0.279 Val Acc 72.480
# L 3 Epoch 90 Loss 0.243 Val Acc 72.520
# ==> Saving model ...
# L 3 Epoch 91 Loss 0.151 Val Acc 73.740
# L 3 Epoch 92 Loss 0.133 Val Acc 73.100
# L 3 Epoch 93 Loss 0.146 Val Acc 72.940
# L 3 Epoch 94 Loss 0.236 Val Acc 69.920
# L 3 Epoch 95 Loss 0.136 Val Acc 72.300
# L 3 Epoch 96 Loss 0.156 Val Acc 73.120
# L 3 Epoch 97 Loss 0.165 Val Acc 72.600
# L 3 Epoch 98 Loss 0.106 Val Acc 73.360
# L 3 Epoch 99 Loss 0.164 Val Acc 73.240
# L 3 Epoch 100 Loss 0.123 Val Acc 71.980
# L 3 Epoch 101 Loss 0.168 Val Acc 72.860
# L 3 Epoch 102 Loss 0.116 Val Acc 72.960
# L 3 Epoch 103 Loss 0.138 Val Acc 72.720
# L 3 Epoch 104 Loss 0.145 Val Acc 72.280
# L 3 Epoch 105 Loss 0.231 Val Acc 70.820
# L 3 Epoch 106 Loss 0.243 Val Acc 71.740
# L 3 Epoch 107 Loss 0.272 Val Acc 71.240
# L 3 Epoch 108 Loss 0.145 Val Acc 72.740
# L 3 Epoch 109 Loss 0.102 Val Acc 73.700
# ==> Saving model ...
# L 3 Epoch 110 Loss 0.098 Val Acc 74.780
# L 3 Epoch 111 Loss 0.071 Val Acc 74.480
# L 3 Epoch 112 Loss 0.089 Val Acc 72.580
# L 3 Epoch 113 Loss 0.142 Val Acc 72.480
# L 3 Epoch 114 Loss 0.221 Val Acc 69.840
# L 3 Epoch 115 Loss 0.480 Val Acc 69.040
# L 3 Epoch 116 Loss 0.248 Val Acc 71.200
# L 3 Epoch 117 Loss 0.163 Val Acc 72.820
# L 3 Epoch 118 Loss 0.085 Val Acc 74.480
# L 3 Epoch 119 Loss 0.119 Val Acc 72.960
# L 3 Epoch 120 Loss 0.138 Val Acc 73.700
# L 3 Epoch 121 Loss 0.126 Val Acc 74.000
# L 3 Epoch 122 Loss 0.094 Val Acc 74.100
# L 3 Epoch 123 Loss 0.096 Val Acc 74.480
# L 3 Epoch 124 Loss 0.067 Val Acc 74.700
# ==> Saving model ...
# L 3 Epoch 125 Loss 0.067 Val Acc 75.360
# L 3 Epoch 126 Loss 0.107 Val Acc 74.060
# L 3 Epoch 127 Loss 0.116 Val Acc 74.420
# L 3 Epoch 128 Loss 0.093 Val Acc 74.120
# L 3 Epoch 129 Loss 0.172 Val Acc 73.280
# L 3 Epoch 130 Loss 0.086 Val Acc 74.220
# L 3 Epoch 131 Loss 0.063 Val Acc 74.760
# L 3 Epoch 132 Loss 0.087 Val Acc 73.820
# L 3 Epoch 133 Loss 0.131 Val Acc 73.840
# L 3 Epoch 134 Loss 0.127 Val Acc 73.700
# L 3 Epoch 135 Loss 0.075 Val Acc 74.800
# L 3 Epoch 136 Loss 0.072 Val Acc 74.900
# L 3 Epoch 137 Loss 0.092 Val Acc 73.960
# L 3 Epoch 138 Loss 0.088 Val Acc 75.060
# L 3 Epoch 139 Loss 0.063 Val Acc 75.340
# ==> Saving model ...
# L 3 Epoch 140 Loss 0.041 Val Acc 75.680
# L 3 Epoch 141 Loss 0.049 Val Acc 75.480
# ==> Saving model ...
# L 3 Epoch 142 Loss 0.035 Val Acc 75.900
# L 3 Epoch 143 Loss 0.047 Val Acc 74.680
# ==> Saving model ...
# L 3 Epoch 144 Loss 0.034 Val Acc 76.080
# L 3 Epoch 145 Loss 0.033 Val Acc 75.820
# L 3 Epoch 146 Loss 0.047 Val Acc 75.380
# L 3 Epoch 147 Loss 0.075 Val Acc 75.160
# L 3 Epoch 148 Loss 0.044 Val Acc 74.580
# L 3 Epoch 149 Loss 0.058 Val Acc 74.980
# L 3 Epoch 150 Loss 0.062 Val Acc 74.700
# L 3 Epoch 151 Loss 0.066 Val Acc 75.020
# L 3 Epoch 152 Loss 0.060 Val Acc 74.080
# L 3 Epoch 153 Loss 0.072 Val Acc 74.640
# L 3 Epoch 154 Loss 0.091 Val Acc 74.420
# L 3 Epoch 155 Loss 0.055 Val Acc 74.360
# L 3 Epoch 156 Loss 0.036 Val Acc 75.580
# L 3 Epoch 157 Loss 0.044 Val Acc 74.860
# L 3 Epoch 158 Loss 0.046 Val Acc 74.420
# L 3 Epoch 159 Loss 0.032 Val Acc 75.700
# L 3 Epoch 160 Loss 0.019 Val Acc 75.920
# L 3 Epoch 161 Loss 0.030 Val Acc 75.620
# L 3 Epoch 162 Loss 0.052 Val Acc 75.480
# L 3 Epoch 163 Loss 0.078 Val Acc 74.500
# L 3 Epoch 164 Loss 0.042 Val Acc 74.360
# L 3 Epoch 165 Loss 0.044 Val Acc 74.540
# L 3 Epoch 166 Loss 0.030 Val Acc 74.780
# L 3 Epoch 167 Loss 0.033 Val Acc 74.240
# L 3 Epoch 168 Loss 0.023 Val Acc 74.940
# L 3 Epoch 169 Loss 0.032 Val Acc 74.680
# L 3 Epoch 170 Loss 0.039 Val Acc 75.020
# L 3 Epoch 171 Loss 0.030 Val Acc 74.680
# L 3 Epoch 172 Loss 0.036 Val Acc 75.340
# L 3 Epoch 173 Loss 0.027 Val Acc 75.600
# L 3 Epoch 174 Loss 0.031 Val Acc 75.760
# L 3 Epoch 175 Loss 0.024 Val Acc 75.860
# L 3 Epoch 176 Loss 0.024 Val Acc 75.340
# L 3 Epoch 177 Loss 0.022 Val Acc 75.600
# L 3 Epoch 178 Loss 0.018 Val Acc 75.860
# ==> Saving model ...
# L 3 Epoch 179 Loss 0.018 Val Acc 76.120
# L 3 Epoch 180 Loss 0.024 Val Acc 75.900
# L 3 Epoch 181 Loss 0.021 Val Acc 75.780
# ==> Saving model ...
# L 3 Epoch 182 Loss 0.024 Val Acc 76.200
# L 3 Epoch 183 Loss 0.017 Val Acc 75.840
# L 3 Epoch 184 Loss 0.022 Val Acc 76.100
# ==> Saving model ...
# L 3 Epoch 185 Loss 0.015 Val Acc 76.440
# L 3 Epoch 186 Loss 0.023 Val Acc 76.140
# L 3 Epoch 187 Loss 0.024 Val Acc 75.980
# L 3 Epoch 188 Loss 0.032 Val Acc 75.960
# L 3 Epoch 189 Loss 0.028 Val Acc 76.180
# L 3 Epoch 190 Loss 0.019 Val Acc 75.540
# L 3 Epoch 191 Loss 0.021 Val Acc 75.920
# ==> Saving model ...
# L 3 Epoch 192 Loss 0.020 Val Acc 76.640
# L 3 Epoch 193 Loss 0.017 Val Acc 76.560
# L 3 Epoch 194 Loss 0.016 Val Acc 76.560
# L 3 Epoch 195 Loss 0.026 Val Acc 76.540
# L 3 Epoch 196 Loss 0.031 Val Acc 76.300
# L 3 Epoch 197 Loss 0.030 Val Acc 75.760
# L 3 Epoch 198 Loss 0.025 Val Acc 76.100
# L 3 Epoch 199 Loss 0.025 Val Acc 76.080
# L 4 Epoch 0 Loss 3.478 Val Acc 13.600
# L 4 Epoch 1 Loss 2.270 Val Acc 18.660
# L 4 Epoch 2 Loss 2.116 Val Acc 17.600
# L 4 Epoch 3 Loss 2.004 Val Acc 24.020
# L 4 Epoch 4 Loss 1.900 Val Acc 24.320
# L 4 Epoch 5 Loss 1.823 Val Acc 28.780
# L 4 Epoch 6 Loss 1.783 Val Acc 31.600
# L 4 Epoch 7 Loss 1.709 Val Acc 35.100
# L 4 Epoch 8 Loss 1.688 Val Acc 36.900
# L 4 Epoch 9 Loss 1.679 Val Acc 37.100
# L 4 Epoch 10 Loss 1.687 Val Acc 38.960
# ==> Saving model ...
# L 4 Epoch 11 Loss 1.622 Val Acc 41.680
# ==> Saving model ...
# L 4 Epoch 12 Loss 1.562 Val Acc 43.660
# L 4 Epoch 13 Loss 1.553 Val Acc 36.960
# L 4 Epoch 14 Loss 1.588 Val Acc 40.360
# ==> Saving model ...
# L 4 Epoch 15 Loss 1.499 Val Acc 44.340
# L 4 Epoch 16 Loss 1.481 Val Acc 43.920
# ==> Saving model ...
# L 4 Epoch 17 Loss 1.419 Val Acc 45.740
# ==> Saving model ...
# L 4 Epoch 18 Loss 1.391 Val Acc 48.000
# ==> Saving model ...
# L 4 Epoch 19 Loss 1.391 Val Acc 50.900
# L 4 Epoch 20 Loss 1.325 Val Acc 49.940
# ==> Saving model ...
# L 4 Epoch 21 Loss 1.296 Val Acc 50.960
# L 4 Epoch 22 Loss 1.251 Val Acc 50.480
# ==> Saving model ...
# L 4 Epoch 23 Loss 1.236 Val Acc 55.860
# L 4 Epoch 24 Loss 1.143 Val Acc 53.180
# L 4 Epoch 25 Loss 1.166 Val Acc 54.880
# L 4 Epoch 26 Loss 1.118 Val Acc 52.900
# ==> Saving model ...
# L 4 Epoch 27 Loss 1.075 Val Acc 57.240
# ==> Saving model ...
# L 4 Epoch 28 Loss 1.064 Val Acc 58.060
# ==> Saving model ...
# L 4 Epoch 29 Loss 1.056 Val Acc 61.080
# L 4 Epoch 30 Loss 0.959 Val Acc 60.040
# L 4 Epoch 31 Loss 0.929 Val Acc 59.400
# ==> Saving model ...
# L 4 Epoch 32 Loss 0.911 Val Acc 62.580
# L 4 Epoch 33 Loss 0.851 Val Acc 62.460
# L 4 Epoch 34 Loss 0.903 Val Acc 62.040
# L 4 Epoch 35 Loss 0.909 Val Acc 51.680
# ==> Saving model ...
# L 4 Epoch 36 Loss 0.924 Val Acc 64.200
# L 4 Epoch 37 Loss 0.843 Val Acc 62.140
# L 4 Epoch 38 Loss 0.767 Val Acc 61.480
# ==> Saving model ...
# L 4 Epoch 39 Loss 0.750 Val Acc 65.460
# L 4 Epoch 40 Loss 0.816 Val Acc 63.920
# ==> Saving model ...
# L 4 Epoch 41 Loss 0.727 Val Acc 66.820
# L 4 Epoch 42 Loss 0.753 Val Acc 62.140
# L 4 Epoch 43 Loss 0.736 Val Acc 65.360
# ==> Saving model ...
# L 4 Epoch 44 Loss 0.783 Val Acc 67.300
# ==> Saving model ...
# L 4 Epoch 45 Loss 0.634 Val Acc 68.820
# ==> Saving model ...
# L 4 Epoch 46 Loss 0.538 Val Acc 69.040
# L 4 Epoch 47 Loss 0.565 Val Acc 66.500
# L 4 Epoch 48 Loss 0.684 Val Acc 60.880
# ==> Saving model ...
# L 4 Epoch 49 Loss 0.631 Val Acc 69.060
# ==> Saving model ...
# L 4 Epoch 50 Loss 0.667 Val Acc 69.560
# ==> Saving model ...
# L 4 Epoch 51 Loss 0.577 Val Acc 70.080
# ==> Saving model ...
# L 4 Epoch 52 Loss 0.518 Val Acc 70.940
# L 4 Epoch 53 Loss 0.487 Val Acc 68.860
# L 4 Epoch 54 Loss 0.514 Val Acc 70.300
# ==> Saving model ...
# L 4 Epoch 55 Loss 0.442 Val Acc 71.060
# L 4 Epoch 56 Loss 0.386 Val Acc 70.080
# ==> Saving model ...
# L 4 Epoch 57 Loss 0.391 Val Acc 71.600
# ==> Saving model ...
# L 4 Epoch 58 Loss 0.361 Val Acc 71.940
# L 4 Epoch 59 Loss 0.335 Val Acc 71.360
# L 4 Epoch 60 Loss 0.392 Val Acc 70.080
# L 4 Epoch 61 Loss 0.355 Val Acc 63.420
# L 4 Epoch 62 Loss 0.453 Val Acc 62.520
# L 4 Epoch 63 Loss 0.412 Val Acc 71.380
# L 4 Epoch 64 Loss 0.335 Val Acc 71.400
# L 4 Epoch 65 Loss 0.413 Val Acc 68.920
# ==> Saving model ...
# L 4 Epoch 66 Loss 0.349 Val Acc 74.180
# L 4 Epoch 67 Loss 0.253 Val Acc 72.340
# L 4 Epoch 68 Loss 0.293 Val Acc 72.180
# L 4 Epoch 69 Loss 0.206 Val Acc 72.560
# L 4 Epoch 70 Loss 0.208 Val Acc 72.820
# L 4 Epoch 71 Loss 0.322 Val Acc 71.040
# L 4 Epoch 72 Loss 0.282 Val Acc 73.720
# L 4 Epoch 73 Loss 0.207 Val Acc 73.180
# L 4 Epoch 74 Loss 0.297 Val Acc 72.240
# L 4 Epoch 75 Loss 0.216 Val Acc 71.860
# L 4 Epoch 76 Loss 0.330 Val Acc 69.160
# L 4 Epoch 77 Loss 0.230 Val Acc 71.280
# L 4 Epoch 78 Loss 0.282 Val Acc 72.440
# L 4 Epoch 79 Loss 0.219 Val Acc 72.100
# L 4 Epoch 80 Loss 0.240 Val Acc 73.840
# L 4 Epoch 81 Loss 0.254 Val Acc 69.200
# L 4 Epoch 82 Loss 0.350 Val Acc 70.860
# L 4 Epoch 83 Loss 0.301 Val Acc 72.440
# ==> Saving model ...
# L 4 Epoch 84 Loss 0.211 Val Acc 74.840
# L 4 Epoch 85 Loss 0.224 Val Acc 69.500
# L 4 Epoch 86 Loss 0.162 Val Acc 74.060
# L 4 Epoch 87 Loss 0.141 Val Acc 73.140
# L 4 Epoch 88 Loss 0.192 Val Acc 73.360
# ==> Saving model ...
# L 4 Epoch 89 Loss 0.238 Val Acc 75.680
# L 4 Epoch 90 Loss 0.166 Val Acc 74.100
# L 4 Epoch 91 Loss 0.227 Val Acc 71.920
# L 4 Epoch 92 Loss 0.280 Val Acc 72.360
# L 4 Epoch 93 Loss 0.214 Val Acc 72.180
# L 4 Epoch 94 Loss 0.153 Val Acc 74.740
# L 4 Epoch 95 Loss 0.185 Val Acc 74.320
# L 4 Epoch 96 Loss 0.163 Val Acc 74.340
# L 4 Epoch 97 Loss 0.185 Val Acc 73.400
# L 4 Epoch 98 Loss 0.200 Val Acc 70.620
# L 4 Epoch 99 Loss 0.265 Val Acc 72.980
# L 4 Epoch 100 Loss 0.289 Val Acc 71.700
# L 4 Epoch 101 Loss 0.177 Val Acc 75.160
# L 4 Epoch 102 Loss 0.088 Val Acc 75.580
# L 4 Epoch 103 Loss 0.091 Val Acc 75.200
# L 4 Epoch 104 Loss 0.111 Val Acc 72.680
# L 4 Epoch 105 Loss 0.256 Val Acc 74.160
# L 4 Epoch 106 Loss 0.327 Val Acc 73.380
# L 4 Epoch 107 Loss 0.149 Val Acc 74.780
# ==> Saving model ...
# L 4 Epoch 108 Loss 0.103 Val Acc 76.320
# L 4 Epoch 109 Loss 0.095 Val Acc 76.220
# L 4 Epoch 110 Loss 0.108 Val Acc 74.320
# L 4 Epoch 111 Loss 0.108 Val Acc 74.800
# L 4 Epoch 112 Loss 0.136 Val Acc 74.540
# L 4 Epoch 113 Loss 0.141 Val Acc 75.180
# L 4 Epoch 114 Loss 0.118 Val Acc 75.160
# L 4 Epoch 115 Loss 0.097 Val Acc 75.540
# L 4 Epoch 116 Loss 0.084 Val Acc 75.720
# L 4 Epoch 117 Loss 0.081 Val Acc 75.420
# ==> Saving model ...
# L 4 Epoch 118 Loss 0.057 Val Acc 76.700
# L 4 Epoch 119 Loss 0.059 Val Acc 75.340
# L 4 Epoch 120 Loss 0.088 Val Acc 74.600
# L 4 Epoch 121 Loss 0.108 Val Acc 75.860
# L 4 Epoch 122 Loss 0.098 Val Acc 76.260
# L 4 Epoch 123 Loss 0.053 Val Acc 75.240
# L 4 Epoch 124 Loss 0.062 Val Acc 75.080
# L 4 Epoch 125 Loss 0.081 Val Acc 75.260
# L 4 Epoch 126 Loss 0.068 Val Acc 76.060
# L 4 Epoch 127 Loss 0.060 Val Acc 76.240
# L 4 Epoch 128 Loss 0.047 Val Acc 75.780
# L 4 Epoch 129 Loss 0.091 Val Acc 75.080
# L 4 Epoch 130 Loss 0.082 Val Acc 76.040
# L 4 Epoch 131 Loss 0.057 Val Acc 76.180
# ==> Saving model ...
# L 4 Epoch 132 Loss 0.055 Val Acc 77.060
# L 4 Epoch 133 Loss 0.064 Val Acc 76.400
# L 4 Epoch 134 Loss 0.059 Val Acc 76.580
# L 4 Epoch 135 Loss 0.048 Val Acc 76.920
# L 4 Epoch 136 Loss 0.034 Val Acc 76.980
# L 4 Epoch 137 Loss 0.035 Val Acc 76.360
# L 4 Epoch 138 Loss 0.045 Val Acc 76.740
# L 4 Epoch 139 Loss 0.083 Val Acc 76.320
# L 4 Epoch 140 Loss 0.063 Val Acc 76.240
# L 4 Epoch 141 Loss 0.079 Val Acc 76.960
# L 4 Epoch 142 Loss 0.088 Val Acc 76.200
# L 4 Epoch 143 Loss 0.121 Val Acc 75.280
# L 4 Epoch 144 Loss 0.099 Val Acc 75.220
# L 4 Epoch 145 Loss 0.057 Val Acc 76.500
# L 4 Epoch 146 Loss 0.097 Val Acc 76.260
# L 4 Epoch 147 Loss 0.056 Val Acc 76.460
# L 4 Epoch 148 Loss 0.049 Val Acc 76.980
# L 4 Epoch 149 Loss 0.035 Val Acc 77.060
# L 4 Epoch 150 Loss 0.032 Val Acc 77.060
# ==> Saving model ...
# L 4 Epoch 151 Loss 0.032 Val Acc 77.320
# L 4 Epoch 152 Loss 0.047 Val Acc 76.960
# L 4 Epoch 153 Loss 0.047 Val Acc 77.140
# L 4 Epoch 154 Loss 0.032 Val Acc 76.960
# L 4 Epoch 155 Loss 0.026 Val Acc 76.960
# ==> Saving model ...
# L 4 Epoch 156 Loss 0.023 Val Acc 77.480
# L 4 Epoch 157 Loss 0.051 Val Acc 77.400
# L 4 Epoch 158 Loss 0.045 Val Acc 77.400
# L 4 Epoch 159 Loss 0.042 Val Acc 77.260
# L 4 Epoch 160 Loss 0.054 Val Acc 77.280
# ==> Saving model ...
# L 4 Epoch 161 Loss 0.033 Val Acc 77.860
# L 4 Epoch 162 Loss 0.027 Val Acc 77.700
# ==> Saving model ...
# L 4 Epoch 163 Loss 0.031 Val Acc 78.020
# L 4 Epoch 164 Loss 0.029 Val Acc 77.620
# L 4 Epoch 165 Loss 0.050 Val Acc 76.640
# L 4 Epoch 166 Loss 0.039 Val Acc 76.640
# L 4 Epoch 167 Loss 0.022 Val Acc 77.160
# L 4 Epoch 168 Loss 0.018 Val Acc 77.620
# L 4 Epoch 169 Loss 0.018 Val Acc 78.000
# L 4 Epoch 170 Loss 0.017 Val Acc 77.680
# ==> Saving model ...
# L 4 Epoch 171 Loss 0.030 Val Acc 78.340
# L 4 Epoch 172 Loss 0.022 Val Acc 77.720
# L 4 Epoch 173 Loss 0.024 Val Acc 78.140
# L 4 Epoch 174 Loss 0.024 Val Acc 77.440
# L 4 Epoch 175 Loss 0.030 Val Acc 77.140
# L 4 Epoch 176 Loss 0.025 Val Acc 77.560
# L 4 Epoch 177 Loss 0.018 Val Acc 78.160
# L 4 Epoch 178 Loss 0.018 Val Acc 78.320
# L 4 Epoch 179 Loss 0.014 Val Acc 78.320
# ==> Saving model ...
# L 4 Epoch 180 Loss 0.028 Val Acc 78.500
# L 4 Epoch 181 Loss 0.023 Val Acc 78.200
# L 4 Epoch 182 Loss 0.018 Val Acc 78.000
# L 4 Epoch 183 Loss 0.025 Val Acc 78.240
# L 4 Epoch 184 Loss 0.014 Val Acc 78.060
# L 4 Epoch 185 Loss 0.012 Val Acc 78.140
# L 4 Epoch 186 Loss 0.023 Val Acc 78.160
# L 4 Epoch 187 Loss 0.015 Val Acc 78.280
# L 4 Epoch 188 Loss 0.018 Val Acc 77.880
# L 4 Epoch 189 Loss 0.017 Val Acc 78.380
# L 4 Epoch 190 Loss 0.025 Val Acc 78.300
# L 4 Epoch 191 Loss 0.038 Val Acc 78.120
# L 4 Epoch 192 Loss 0.028 Val Acc 77.960
# L 4 Epoch 193 Loss 0.016 Val Acc 78.460
# L 4 Epoch 194 Loss 0.017 Val Acc 78.200
# L 4 Epoch 195 Loss 0.014 Val Acc 78.200
# L 4 Epoch 196 Loss 0.017 Val Acc 78.160
# L 4 Epoch 197 Loss 0.014 Val Acc 78.360
# L 4 Epoch 198 Loss 0.015 Val Acc 78.220
# L 4 Epoch 199 Loss 0.025 Val Acc 78.000
# L 5 Epoch 0 Loss 2.894 Val Acc 11.020
# L 5 Epoch 1 Loss 2.001 Val Acc 29.420
# L 5 Epoch 2 Loss 1.863 Val Acc 27.960
# L 5 Epoch 3 Loss 1.792 Val Acc 32.920
# L 5 Epoch 4 Loss 1.719 Val Acc 38.160
# ==> Saving model ...
# L 5 Epoch 5 Loss 1.674 Val Acc 41.740
# ==> Saving model ...
# L 5 Epoch 6 Loss 1.559 Val Acc 45.920
# L 5 Epoch 7 Loss 1.467 Val Acc 45.860
# ==> Saving model ...
# L 5 Epoch 8 Loss 1.446 Val Acc 49.740
# L 5 Epoch 9 Loss 1.396 Val Acc 42.920
# L 5 Epoch 10 Loss 1.428 Val Acc 47.020
# ==> Saving model ...
# L 5 Epoch 11 Loss 1.345 Val Acc 53.180
# L 5 Epoch 12 Loss 1.278 Val Acc 47.040
# L 5 Epoch 13 Loss 1.479 Val Acc 48.780
# ==> Saving model ...
# L 5 Epoch 14 Loss 1.311 Val Acc 55.660
# ==> Saving model ...
# L 5 Epoch 15 Loss 1.238 Val Acc 56.060
# ==> Saving model ...
# L 5 Epoch 16 Loss 1.124 Val Acc 58.640
# ==> Saving model ...
# L 5 Epoch 17 Loss 1.110 Val Acc 60.420
# L 5 Epoch 18 Loss 1.092 Val Acc 57.660
# L 5 Epoch 19 Loss 1.033 Val Acc 59.800
# L 5 Epoch 20 Loss 0.956 Val Acc 45.060
# L 5 Epoch 21 Loss 1.131 Val Acc 59.760
# ==> Saving model ...
# L 5 Epoch 22 Loss 1.054 Val Acc 61.040
# ==> Saving model ...
# L 5 Epoch 23 Loss 0.904 Val Acc 64.620
# L 5 Epoch 24 Loss 0.871 Val Acc 63.660
# ==> Saving model ...
# L 5 Epoch 25 Loss 0.873 Val Acc 66.140
# L 5 Epoch 26 Loss 0.739 Val Acc 63.600
# L 5 Epoch 27 Loss 0.837 Val Acc 61.220
# ==> Saving model ...
# L 5 Epoch 28 Loss 0.824 Val Acc 67.260
# L 5 Epoch 29 Loss 0.731 Val Acc 64.000
# L 5 Epoch 30 Loss 0.770 Val Acc 63.480
# ==> Saving model ...
# L 5 Epoch 31 Loss 0.798 Val Acc 68.800
# L 5 Epoch 32 Loss 0.701 Val Acc 65.540
# L 5 Epoch 33 Loss 0.640 Val Acc 66.600
# ==> Saving model ...
# L 5 Epoch 34 Loss 0.612 Val Acc 69.540
# L 5 Epoch 35 Loss 0.528 Val Acc 69.140
# L 5 Epoch 36 Loss 0.653 Val Acc 65.640
# L 5 Epoch 37 Loss 0.740 Val Acc 69.220
# ==> Saving model ...
# L 5 Epoch 38 Loss 0.538 Val Acc 69.600
# L 5 Epoch 39 Loss 0.551 Val Acc 68.200
# ==> Saving model ...
# L 5 Epoch 40 Loss 0.597 Val Acc 71.060
# ==> Saving model ...
# L 5 Epoch 41 Loss 0.493 Val Acc 72.080
# L 5 Epoch 42 Loss 0.403 Val Acc 69.940
# L 5 Epoch 43 Loss 0.403 Val Acc 70.160
# L 5 Epoch 44 Loss 0.537 Val Acc 70.060
# L 5 Epoch 45 Loss 0.445 Val Acc 68.140
# L 5 Epoch 46 Loss 0.507 Val Acc 65.980
# L 5 Epoch 47 Loss 0.506 Val Acc 71.080
# L 5 Epoch 48 Loss 0.431 Val Acc 67.620
# L 5 Epoch 49 Loss 0.489 Val Acc 70.620
# L 5 Epoch 50 Loss 0.361 Val Acc 71.860
# L 5 Epoch 51 Loss 0.318 Val Acc 70.360
# L 5 Epoch 52 Loss 0.339 Val Acc 70.680
# L 5 Epoch 53 Loss 0.385 Val Acc 71.300
# L 5 Epoch 54 Loss 0.360 Val Acc 71.060
# L 5 Epoch 55 Loss 0.431 Val Acc 71.240
# L 5 Epoch 56 Loss 0.361 Val Acc 72.060
# ==> Saving model ...
# L 5 Epoch 57 Loss 0.394 Val Acc 72.140
# L 5 Epoch 58 Loss 0.320 Val Acc 72.100
# L 5 Epoch 59 Loss 0.338 Val Acc 70.800
# ==> Saving model ...
# L 5 Epoch 60 Loss 0.385 Val Acc 72.400
# L 5 Epoch 61 Loss 0.367 Val Acc 69.580
# L 5 Epoch 62 Loss 0.267 Val Acc 70.020
# L 5 Epoch 63 Loss 0.268 Val Acc 71.660
# ==> Saving model ...
# L 5 Epoch 64 Loss 0.304 Val Acc 73.460
# L 5 Epoch 65 Loss 0.146 Val Acc 73.340
# L 5 Epoch 66 Loss 0.149 Val Acc 72.800
# L 5 Epoch 67 Loss 0.157 Val Acc 72.840
# ==> Saving model ...
# L 5 Epoch 68 Loss 0.156 Val Acc 73.980
# L 5 Epoch 69 Loss 0.221 Val Acc 72.020
# L 5 Epoch 70 Loss 0.274 Val Acc 69.680
# L 5 Epoch 71 Loss 0.245 Val Acc 70.980
# L 5 Epoch 72 Loss 0.240 Val Acc 70.060
# L 5 Epoch 73 Loss 0.156 Val Acc 71.960
# L 5 Epoch 74 Loss 0.371 Val Acc 69.300
# L 5 Epoch 75 Loss 0.407 Val Acc 71.280
# L 5 Epoch 76 Loss 0.240 Val Acc 71.760
# L 5 Epoch 77 Loss 0.223 Val Acc 71.880
# L 5 Epoch 78 Loss 0.276 Val Acc 71.580
# L 5 Epoch 79 Loss 0.201 Val Acc 73.680
# L 5 Epoch 80 Loss 0.184 Val Acc 73.240
# L 5 Epoch 81 Loss 0.236 Val Acc 71.880
# L 5 Epoch 82 Loss 0.212 Val Acc 72.320
# L 5 Epoch 83 Loss 0.221 Val Acc 72.240
# L 5 Epoch 84 Loss 0.188 Val Acc 71.640
# ==> Saving model ...
# L 5 Epoch 85 Loss 0.241 Val Acc 74.500
# L 5 Epoch 86 Loss 0.160 Val Acc 72.560
# L 5 Epoch 87 Loss 0.240 Val Acc 72.800
# L 5 Epoch 88 Loss 0.214 Val Acc 71.760
# L 5 Epoch 89 Loss 0.163 Val Acc 73.780
# L 5 Epoch 90 Loss 0.140 Val Acc 74.280
# L 5 Epoch 91 Loss 0.141 Val Acc 73.700
# L 5 Epoch 92 Loss 0.171 Val Acc 69.180
# L 5 Epoch 93 Loss 0.283 Val Acc 71.680
# L 5 Epoch 94 Loss 0.235 Val Acc 72.740
# L 5 Epoch 95 Loss 0.177 Val Acc 71.800
# L 5 Epoch 96 Loss 0.150 Val Acc 72.460
# L 5 Epoch 97 Loss 0.210 Val Acc 72.200
# L 5 Epoch 98 Loss 0.153 Val Acc 73.780
# L 5 Epoch 99 Loss 0.289 Val Acc 73.100
# L 5 Epoch 100 Loss 0.170 Val Acc 74.000
# L 5 Epoch 101 Loss 0.233 Val Acc 73.560
# L 5 Epoch 102 Loss 0.180 Val Acc 73.340
# L 5 Epoch 103 Loss 0.204 Val Acc 73.320
# L 5 Epoch 104 Loss 0.185 Val Acc 73.620
# L 5 Epoch 105 Loss 0.144 Val Acc 73.840
# ==> Saving model ...
# L 5 Epoch 106 Loss 0.112 Val Acc 75.220
# ==> Saving model ...
# L 5 Epoch 107 Loss 0.098 Val Acc 75.440
# L 5 Epoch 108 Loss 0.104 Val Acc 74.740
# L 5 Epoch 109 Loss 0.137 Val Acc 74.940
# L 5 Epoch 110 Loss 0.075 Val Acc 75.240
# L 5 Epoch 111 Loss 0.069 Val Acc 75.400
# L 5 Epoch 112 Loss 0.071 Val Acc 74.160
# L 5 Epoch 113 Loss 0.106 Val Acc 73.940
# L 5 Epoch 114 Loss 0.096 Val Acc 74.380
# L 5 Epoch 115 Loss 0.086 Val Acc 74.420
# L 5 Epoch 116 Loss 0.124 Val Acc 74.000
# L 5 Epoch 117 Loss 0.126 Val Acc 73.880
# L 5 Epoch 118 Loss 0.095 Val Acc 75.140
# L 5 Epoch 119 Loss 0.078 Val Acc 75.220
# L 5 Epoch 120 Loss 0.069 Val Acc 74.100
# L 5 Epoch 121 Loss 0.134 Val Acc 73.860
# L 5 Epoch 122 Loss 0.091 Val Acc 74.700
# L 5 Epoch 123 Loss 0.150 Val Acc 73.860
# L 5 Epoch 124 Loss 0.067 Val Acc 74.520
# L 5 Epoch 125 Loss 0.070 Val Acc 73.060
# L 5 Epoch 126 Loss 0.140 Val Acc 73.320
# L 5 Epoch 127 Loss 0.146 Val Acc 73.040
# L 5 Epoch 128 Loss 0.117 Val Acc 74.460
# L 5 Epoch 129 Loss 0.155 Val Acc 73.820
# L 5 Epoch 130 Loss 0.098 Val Acc 74.160
# L 5 Epoch 131 Loss 0.071 Val Acc 75.400
# L 5 Epoch 132 Loss 0.096 Val Acc 74.680
# L 5 Epoch 133 Loss 0.146 Val Acc 74.860
# L 5 Epoch 134 Loss 0.109 Val Acc 74.240
# L 5 Epoch 135 Loss 0.126 Val Acc 75.400
# L 5 Epoch 136 Loss 0.074 Val Acc 75.240
# ==> Saving model ...
# L 5 Epoch 137 Loss 0.038 Val Acc 76.420
# L 5 Epoch 138 Loss 0.048 Val Acc 76.360
# ==> Saving model ...
# L 5 Epoch 139 Loss 0.042 Val Acc 76.860
# L 5 Epoch 140 Loss 0.066 Val Acc 76.060
# L 5 Epoch 141 Loss 0.045 Val Acc 75.740
# L 5 Epoch 142 Loss 0.077 Val Acc 76.420
# L 5 Epoch 143 Loss 0.088 Val Acc 75.560
# L 5 Epoch 144 Loss 0.067 Val Acc 75.620
# L 5 Epoch 145 Loss 0.052 Val Acc 76.120
# L 5 Epoch 146 Loss 0.054 Val Acc 76.260
# L 5 Epoch 147 Loss 0.040 Val Acc 76.040
# L 5 Epoch 148 Loss 0.055 Val Acc 75.760
# L 5 Epoch 149 Loss 0.073 Val Acc 75.360
# L 5 Epoch 150 Loss 0.031 Val Acc 76.620
# L 5 Epoch 151 Loss 0.039 Val Acc 76.380
# L 5 Epoch 152 Loss 0.043 Val Acc 75.800
# L 5 Epoch 153 Loss 0.051 Val Acc 76.400
# L 5 Epoch 154 Loss 0.040 Val Acc 76.400
# L 5 Epoch 155 Loss 0.027 Val Acc 76.720
# L 5 Epoch 156 Loss 0.062 Val Acc 76.380
# L 5 Epoch 157 Loss 0.067 Val Acc 76.140
# L 5 Epoch 158 Loss 0.040 Val Acc 76.600
# L 5 Epoch 159 Loss 0.052 Val Acc 75.500
# L 5 Epoch 160 Loss 0.063 Val Acc 76.340
# L 5 Epoch 161 Loss 0.040 Val Acc 76.660
# L 5 Epoch 162 Loss 0.041 Val Acc 76.220
# L 5 Epoch 163 Loss 0.049 Val Acc 76.140
# L 5 Epoch 164 Loss 0.044 Val Acc 76.760
# L 5 Epoch 165 Loss 0.032 Val Acc 76.500
# ==> Saving model ...
# L 5 Epoch 166 Loss 0.045 Val Acc 76.900
# L 5 Epoch 167 Loss 0.034 Val Acc 76.420
# L 5 Epoch 168 Loss 0.031 Val Acc 76.800
# ==> Saving model ...
# L 5 Epoch 169 Loss 0.029 Val Acc 77.440
# L 5 Epoch 170 Loss 0.025 Val Acc 76.840
# L 5 Epoch 171 Loss 0.024 Val Acc 77.040
# ==> Saving model ...
# L 5 Epoch 172 Loss 0.021 Val Acc 77.560
# L 5 Epoch 173 Loss 0.025 Val Acc 77.260
# L 5 Epoch 174 Loss 0.030 Val Acc 77.180
# ==> Saving model ...
# L 5 Epoch 175 Loss 0.021 Val Acc 77.580
# L 5 Epoch 176 Loss 0.024 Val Acc 77.400
# ==> Saving model ...
# L 5 Epoch 177 Loss 0.023 Val Acc 77.600
# ==> Saving model ...
# L 5 Epoch 178 Loss 0.025 Val Acc 77.700
# L 5 Epoch 179 Loss 0.021 Val Acc 77.640
# ==> Saving model ...
# L 5 Epoch 180 Loss 0.029 Val Acc 77.780
# ==> Saving model ...
# L 5 Epoch 181 Loss 0.023 Val Acc 77.980
# L 5 Epoch 182 Loss 0.018 Val Acc 77.840
# L 5 Epoch 183 Loss 0.025 Val Acc 77.280
# L 5 Epoch 184 Loss 0.024 Val Acc 77.880
# ==> Saving model ...
# L 5 Epoch 185 Loss 0.013 Val Acc 78.140
# L 5 Epoch 186 Loss 0.018 Val Acc 78.000
# ==> Saving model ...
# L 5 Epoch 187 Loss 0.022 Val Acc 78.300
# L 5 Epoch 188 Loss 0.023 Val Acc 77.920
# L 5 Epoch 189 Loss 0.016 Val Acc 78.080
# L 5 Epoch 190 Loss 0.034 Val Acc 78.120
# L 5 Epoch 191 Loss 0.030 Val Acc 77.420
# L 5 Epoch 192 Loss 0.022 Val Acc 78.000
# L 5 Epoch 193 Loss 0.022 Val Acc 77.800
# L 5 Epoch 194 Loss 0.018 Val Acc 78.060
# L 5 Epoch 195 Loss 0.018 Val Acc 77.920
# L 5 Epoch 196 Loss 0.013 Val Acc 78.040
# L 5 Epoch 197 Loss 0.027 Val Acc 77.380
# L 5 Epoch 198 Loss 0.025 Val Acc 77.980
# L 5 Epoch 199 Loss 0.012 Val Acc 78.120
# L 6 Epoch 0 Loss 4.068 Val Acc 11.120
# L 6 Epoch 1 Loss 2.217 Val Acc 23.620
# L 6 Epoch 2 Loss 1.894 Val Acc 30.120
# L 6 Epoch 3 Loss 1.760 Val Acc 30.680
# L 6 Epoch 4 Loss 1.743 Val Acc 32.820
# L 6 Epoch 5 Loss 1.736 Val Acc 35.320
# L 6 Epoch 6 Loss 1.715 Val Acc 35.580
# L 6 Epoch 7 Loss 1.618 Val Acc 39.080
# ==> Saving model ...
# L 6 Epoch 8 Loss 1.559 Val Acc 43.060
# ==> Saving model ...
# L 6 Epoch 9 Loss 1.545 Val Acc 44.060
# ==> Saving model ...
# L 6 Epoch 10 Loss 1.461 Val Acc 45.200
# L 6 Epoch 11 Loss 1.469 Val Acc 42.420
# L 6 Epoch 12 Loss 1.544 Val Acc 45.000
# ==> Saving model ...
# L 6 Epoch 13 Loss 1.436 Val Acc 45.980
# ==> Saving model ...
# L 6 Epoch 14 Loss 1.370 Val Acc 48.720
# ==> Saving model ...
# L 6 Epoch 15 Loss 1.311 Val Acc 50.520
# L 6 Epoch 16 Loss 1.270 Val Acc 48.260
# ==> Saving model ...
# L 6 Epoch 17 Loss 1.257 Val Acc 54.520
# L 6 Epoch 18 Loss 1.154 Val Acc 54.380
# L 6 Epoch 19 Loss 1.142 Val Acc 54.500
# ==> Saving model ...
# L 6 Epoch 20 Loss 1.203 Val Acc 54.960
# L 6 Epoch 21 Loss 1.062 Val Acc 54.920
# ==> Saving model ...
# L 6 Epoch 22 Loss 1.154 Val Acc 57.300
# ==> Saving model ...
# L 6 Epoch 23 Loss 1.060 Val Acc 59.400
# L 6 Epoch 24 Loss 1.087 Val Acc 56.120
# L 6 Epoch 25 Loss 1.014 Val Acc 57.760
# L 6 Epoch 26 Loss 0.972 Val Acc 57.220
# ==> Saving model ...
# L 6 Epoch 27 Loss 0.936 Val Acc 59.740
# ==> Saving model ...
# L 6 Epoch 28 Loss 0.961 Val Acc 62.160
# L 6 Epoch 29 Loss 0.912 Val Acc 60.780
# L 6 Epoch 30 Loss 0.896 Val Acc 60.800
# ==> Saving model ...
# L 6 Epoch 31 Loss 0.844 Val Acc 62.320
# ==> Saving model ...
# L 6 Epoch 32 Loss 0.842 Val Acc 62.900
# ==> Saving model ...
# L 6 Epoch 33 Loss 0.741 Val Acc 66.980
# L 6 Epoch 34 Loss 0.683 Val Acc 58.820
# L 6 Epoch 35 Loss 0.731 Val Acc 63.340
# L 6 Epoch 36 Loss 0.751 Val Acc 57.580
# L 6 Epoch 37 Loss 0.724 Val Acc 66.140
# L 6 Epoch 38 Loss 0.665 Val Acc 63.960
# L 6 Epoch 39 Loss 0.775 Val Acc 66.040
# L 6 Epoch 40 Loss 0.572 Val Acc 66.180
# L 6 Epoch 41 Loss 0.596 Val Acc 64.600
# L 6 Epoch 42 Loss 0.627 Val Acc 65.240
# L 6 Epoch 43 Loss 0.590 Val Acc 65.980
# ==> Saving model ...
# L 6 Epoch 44 Loss 0.547 Val Acc 68.140
# L 6 Epoch 45 Loss 0.391 Val Acc 65.660
# L 6 Epoch 46 Loss 0.579 Val Acc 65.700
# L 6 Epoch 47 Loss 0.410 Val Acc 65.700
# L 6 Epoch 48 Loss 0.632 Val Acc 67.500
# L 6 Epoch 49 Loss 0.440 Val Acc 66.020
# ==> Saving model ...
# L 6 Epoch 50 Loss 0.447 Val Acc 69.020
# ==> Saving model ...
# L 6 Epoch 51 Loss 0.380 Val Acc 69.420
# L 6 Epoch 52 Loss 0.328 Val Acc 65.700
# ==> Saving model ...
# L 6 Epoch 53 Loss 0.515 Val Acc 69.860
# L 6 Epoch 54 Loss 0.355 Val Acc 68.720
# L 6 Epoch 55 Loss 0.332 Val Acc 68.340
# ==> Saving model ...
# L 6 Epoch 56 Loss 0.317 Val Acc 71.140
# L 6 Epoch 57 Loss 0.371 Val Acc 70.160
# L 6 Epoch 58 Loss 0.254 Val Acc 70.580
# L 6 Epoch 59 Loss 0.256 Val Acc 70.080
# L 6 Epoch 60 Loss 0.251 Val Acc 69.400
# L 6 Epoch 61 Loss 0.286 Val Acc 69.940
# L 6 Epoch 62 Loss 0.357 Val Acc 70.020
# L 6 Epoch 63 Loss 0.414 Val Acc 68.540
# L 6 Epoch 64 Loss 0.268 Val Acc 69.180
# ==> Saving model ...
# L 6 Epoch 65 Loss 0.296 Val Acc 72.040
# L 6 Epoch 66 Loss 0.225 Val Acc 69.600
# L 6 Epoch 67 Loss 0.290 Val Acc 68.980
# L 6 Epoch 68 Loss 0.283 Val Acc 71.540
# ==> Saving model ...
# L 6 Epoch 69 Loss 0.191 Val Acc 72.120
# ==> Saving model ...
# L 6 Epoch 70 Loss 0.214 Val Acc 72.400
# L 6 Epoch 71 Loss 0.207 Val Acc 70.260
# L 6 Epoch 72 Loss 0.306 Val Acc 70.700
# L 6 Epoch 73 Loss 0.283 Val Acc 71.460
# L 6 Epoch 74 Loss 0.190 Val Acc 71.900
# L 6 Epoch 75 Loss 0.197 Val Acc 70.520
# L 6 Epoch 76 Loss 0.244 Val Acc 70.560
# L 6 Epoch 77 Loss 0.197 Val Acc 70.100
# L 6 Epoch 78 Loss 0.492 Val Acc 69.020
# L 6 Epoch 79 Loss 0.260 Val Acc 71.440
# L 6 Epoch 80 Loss 0.286 Val Acc 70.140
# L 6 Epoch 81 Loss 0.204 Val Acc 72.300
# ==> Saving model ...
# L 6 Epoch 82 Loss 0.099 Val Acc 74.160
# L 6 Epoch 83 Loss 0.117 Val Acc 72.400
# ==> Saving model ...
# L 6 Epoch 84 Loss 0.123 Val Acc 74.720
# L 6 Epoch 85 Loss 0.106 Val Acc 72.260
# L 6 Epoch 86 Loss 0.189 Val Acc 70.440
# L 6 Epoch 87 Loss 0.151 Val Acc 72.320
# L 6 Epoch 88 Loss 0.216 Val Acc 58.960
# L 6 Epoch 89 Loss 0.342 Val Acc 70.540
# L 6 Epoch 90 Loss 0.200 Val Acc 72.740
# L 6 Epoch 91 Loss 0.185 Val Acc 73.040
# L 6 Epoch 92 Loss 0.305 Val Acc 71.280
# L 6 Epoch 93 Loss 0.361 Val Acc 71.720
# L 6 Epoch 94 Loss 0.303 Val Acc 71.700
# L 6 Epoch 95 Loss 0.219 Val Acc 73.120
# L 6 Epoch 96 Loss 0.168 Val Acc 73.640
# L 6 Epoch 97 Loss 0.115 Val Acc 72.120
# L 6 Epoch 98 Loss 0.208 Val Acc 72.720
# L 6 Epoch 99 Loss 0.125 Val Acc 73.540
# L 6 Epoch 100 Loss 0.146 Val Acc 74.460
# L 6 Epoch 101 Loss 0.098 Val Acc 73.940
# L 6 Epoch 102 Loss 0.087 Val Acc 73.200
# L 6 Epoch 103 Loss 0.106 Val Acc 73.340
# L 6 Epoch 104 Loss 0.174 Val Acc 72.480
# L 6 Epoch 105 Loss 0.189 Val Acc 71.580
# L 6 Epoch 106 Loss 0.101 Val Acc 74.500
# L 6 Epoch 107 Loss 0.107 Val Acc 73.300
# ...
# ==> Saving model ...
# L 19 Epoch 33 Loss 0.863 Val Acc 62.860
# ==> Saving model ...
# L 19 Epoch 34 Loss 0.827 Val Acc 62.940
# ==> Saving model ...
# L 19 Epoch 35 Loss 0.838 Val Acc 63.620
# L 19 Epoch 36 Loss 0.825 Val Acc 61.920
# ==> Saving model ...
# L 19 Epoch 37 Loss 0.837 Val Acc 64.800
# L 19 Epoch 38 Loss 0.869 Val Acc 62.640
# L 19 Epoch 39 Loss 0.891 Val Acc 64.040
# ==> Saving model ...
# L 19 Epoch 40 Loss 0.743 Val Acc 64.820
# L 19 Epoch 41 Loss 0.744 Val Acc 62.760
# L 19 Epoch 42 Loss 0.695 Val Acc 64.740
# ==> Saving model ...
# L 19 Epoch 43 Loss 0.641 Val Acc 66.400
# ==> Saving model ...
# L 19 Epoch 44 Loss 0.644 Val Acc 66.820
# L 19 Epoch 45 Loss 0.648 Val Acc 63.740
# L 19 Epoch 46 Loss 0.624 Val Acc 64.960
# L 19 Epoch 47 Loss 0.573 Val Acc 64.200
# L 19 Epoch 48 Loss 0.666 Val Acc 62.940
# L 19 Epoch 49 Loss 0.664 Val Acc 65.420
# L 19 Epoch 50 Loss 0.551 Val Acc 66.680
# L 19 Epoch 51 Loss 0.507 Val Acc 66.720
# L 19 Epoch 52 Loss 0.449 Val Acc 66.760
# L 19 Epoch 53 Loss 0.412 Val Acc 65.760
# L 19 Epoch 54 Loss 0.463 Val Acc 66.800
# L 19 Epoch 55 Loss 0.422 Val Acc 66.800
# L 19 Epoch 56 Loss 0.488 Val Acc 65.200
# L 19 Epoch 57 Loss 0.569 Val Acc 66.120
# ==> Saving model ...
# L 19 Epoch 58 Loss 0.458 Val Acc 66.920
# ==> Saving model ...
# L 19 Epoch 59 Loss 0.418 Val Acc 67.360
# L 19 Epoch 60 Loss 0.339 Val Acc 63.380
# L 19 Epoch 61 Loss 0.465 Val Acc 67.060
# L 19 Epoch 62 Loss 0.456 Val Acc 64.400
# L 19 Epoch 63 Loss 0.520 Val Acc 65.000
# ==> Saving model ...
# L 19 Epoch 64 Loss 0.357 Val Acc 69.060
# L 19 Epoch 65 Loss 0.256 Val Acc 67.000
# L 19 Epoch 66 Loss 0.330 Val Acc 67.600
# L 19 Epoch 67 Loss 0.310 Val Acc 67.660
# L 19 Epoch 68 Loss 0.355 Val Acc 68.960
# L 19 Epoch 69 Loss 0.246 Val Acc 66.900
# L 19 Epoch 70 Loss 0.312 Val Acc 67.280
# ==> Saving model ...
# L 19 Epoch 71 Loss 0.304 Val Acc 69.500
# L 19 Epoch 72 Loss 0.303 Val Acc 67.920
# L 19 Epoch 73 Loss 0.289 Val Acc 67.100
# L 19 Epoch 74 Loss 0.191 Val Acc 67.360
# L 19 Epoch 75 Loss 0.233 Val Acc 69.140
# L 19 Epoch 76 Loss 0.247 Val Acc 67.800
# L 19 Epoch 77 Loss 0.375 Val Acc 65.300
# L 19 Epoch 78 Loss 0.358 Val Acc 68.080
# L 19 Epoch 79 Loss 0.198 Val Acc 68.360
# L 19 Epoch 80 Loss 0.252 Val Acc 68.920
# ==> Saving model ...
# L 19 Epoch 81 Loss 0.203 Val Acc 69.820
# ==> Saving model ...
# L 19 Epoch 82 Loss 0.192 Val Acc 70.120
# L 19 Epoch 83 Loss 0.252 Val Acc 67.720
# L 19 Epoch 84 Loss 0.285 Val Acc 68.440
# L 19 Epoch 85 Loss 0.253 Val Acc 68.500
# L 19 Epoch 86 Loss 0.198 Val Acc 68.260
# L 19 Epoch 87 Loss 0.425 Val Acc 65.640
# L 19 Epoch 88 Loss 0.348 Val Acc 69.080
# L 19 Epoch 89 Loss 0.215 Val Acc 68.960
# L 19 Epoch 90 Loss 0.264 Val Acc 69.080
# L 19 Epoch 91 Loss 0.174 Val Acc 70.080
# L 19 Epoch 92 Loss 0.173 Val Acc 68.860
# ==> Saving model ...
# L 19 Epoch 93 Loss 0.167 Val Acc 70.140
# L 19 Epoch 94 Loss 0.148 Val Acc 69.060
# L 19 Epoch 95 Loss 0.213 Val Acc 68.380
# L 19 Epoch 96 Loss 0.419 Val Acc 66.180
# ==> Saving model ...
# L 19 Epoch 97 Loss 0.232 Val Acc 70.900
# ==> Saving model ...
# L 19 Epoch 98 Loss 0.102 Val Acc 72.220
# L 19 Epoch 99 Loss 0.123 Val Acc 70.580
# L 19 Epoch 100 Loss 0.183 Val Acc 70.640
# L 19 Epoch 101 Loss 0.174 Val Acc 71.060
# L 19 Epoch 102 Loss 0.155 Val Acc 69.640
# L 19 Epoch 103 Loss 0.156 Val Acc 70.940
# L 19 Epoch 104 Loss 0.137 Val Acc 71.160
# L 19 Epoch 105 Loss 0.159 Val Acc 70.060
# L 19 Epoch 106 Loss 0.137 Val Acc 70.820
# L 19 Epoch 107 Loss 0.128 Val Acc 70.780
# L 19 Epoch 108 Loss 0.104 Val Acc 71.560
# L 19 Epoch 109 Loss 0.145 Val Acc 69.640
# L 19 Epoch 110 Loss 0.115 Val Acc 71.800
# L 19 Epoch 111 Loss 0.127 Val Acc 69.360
# L 19 Epoch 112 Loss 0.167 Val Acc 69.660
# L 19 Epoch 113 Loss 0.165 Val Acc 70.920
# L 19 Epoch 114 Loss 0.155 Val Acc 69.820
# L 19 Epoch 115 Loss 0.220 Val Acc 70.020
# L 19 Epoch 116 Loss 0.144 Val Acc 71.540
# L 19 Epoch 117 Loss 0.087 Val Acc 71.560
# L 19 Epoch 118 Loss 0.088 Val Acc 71.160
# L 19 Epoch 119 Loss 0.132 Val Acc 69.960
# L 19 Epoch 120 Loss 0.243 Val Acc 70.420
# L 19 Epoch 121 Loss 0.175 Val Acc 70.960
# L 19 Epoch 122 Loss 0.151 Val Acc 71.740
# L 19 Epoch 123 Loss 0.150 Val Acc 70.820
# L 19 Epoch 124 Loss 0.112 Val Acc 70.760
# L 19 Epoch 125 Loss 0.101 Val Acc 70.400
# L 19 Epoch 126 Loss 0.098 Val Acc 71.000
# ==> Saving model ...
# L 19 Epoch 127 Loss 0.095 Val Acc 72.360
# L 19 Epoch 128 Loss 0.078 Val Acc 71.860
# ==> Saving model ...
# L 19 Epoch 129 Loss 0.079 Val Acc 72.760
# L 19 Epoch 130 Loss 0.135 Val Acc 71.320
# L 19 Epoch 131 Loss 0.094 Val Acc 71.180
# L 19 Epoch 132 Loss 0.055 Val Acc 72.300
# L 19 Epoch 133 Loss 0.080 Val Acc 72.540
# ==> Saving model ...
# L 19 Epoch 134 Loss 0.061 Val Acc 73.160
# L 19 Epoch 135 Loss 0.069 Val Acc 72.420
# L 19 Epoch 136 Loss 0.085 Val Acc 71.880
# L 19 Epoch 137 Loss 0.077 Val Acc 71.820
# L 19 Epoch 138 Loss 0.048 Val Acc 73.040
# L 19 Epoch 139 Loss 0.095 Val Acc 72.600
# L 19 Epoch 140 Loss 0.096 Val Acc 71.840
# L 19 Epoch 141 Loss 0.049 Val Acc 73.120
# L 19 Epoch 142 Loss 0.083 Val Acc 72.480
# L 19 Epoch 143 Loss 0.061 Val Acc 72.720
# ==> Saving model ...
# L 19 Epoch 144 Loss 0.048 Val Acc 73.220
# L 19 Epoch 145 Loss 0.039 Val Acc 73.120
# L 19 Epoch 146 Loss 0.051 Val Acc 72.220
# L 19 Epoch 147 Loss 0.099 Val Acc 71.400
# L 19 Epoch 148 Loss 0.063 Val Acc 71.360
# L 19 Epoch 149 Loss 0.060 Val Acc 72.120
# L 19 Epoch 150 Loss 0.050 Val Acc 72.220
# L 19 Epoch 151 Loss 0.052 Val Acc 72.220
# L 19 Epoch 152 Loss 0.048 Val Acc 72.920
# L 19 Epoch 153 Loss 0.051 Val Acc 72.100
# L 19 Epoch 154 Loss 0.054 Val Acc 72.400
# L 19 Epoch 155 Loss 0.085 Val Acc 72.940
# L 19 Epoch 156 Loss 0.085 Val Acc 72.520
# L 19 Epoch 157 Loss 0.031 Val Acc 72.880
# ==> Saving model ...
# L 19 Epoch 158 Loss 0.034 Val Acc 73.700
# L 19 Epoch 159 Loss 0.050 Val Acc 73.500
# L 19 Epoch 160 Loss 0.042 Val Acc 72.920
# L 19 Epoch 161 Loss 0.043 Val Acc 73.380
# L 19 Epoch 162 Loss 0.031 Val Acc 72.980
# L 19 Epoch 163 Loss 0.031 Val Acc 73.280
# ==> Saving model ...
# L 19 Epoch 164 Loss 0.022 Val Acc 73.760
# L 19 Epoch 165 Loss 0.035 Val Acc 73.140
# ==> Saving model ...
# L 19 Epoch 166 Loss 0.022 Val Acc 73.920
# L 19 Epoch 167 Loss 0.030 Val Acc 73.660
# L 19 Epoch 168 Loss 0.033 Val Acc 73.480
# L 19 Epoch 169 Loss 0.024 Val Acc 73.600
# L 19 Epoch 170 Loss 0.027 Val Acc 73.520
# L 19 Epoch 171 Loss 0.020 Val Acc 73.800
# L 19 Epoch 172 Loss 0.032 Val Acc 73.340
# L 19 Epoch 173 Loss 0.028 Val Acc 73.620
# L 19 Epoch 174 Loss 0.020 Val Acc 73.120
# L 19 Epoch 175 Loss 0.029 Val Acc 73.180
# L 19 Epoch 176 Loss 0.021 Val Acc 73.540
# L 19 Epoch 177 Loss 0.021 Val Acc 73.360
# L 19 Epoch 178 Loss 0.020 Val Acc 73.140
# L 19 Epoch 179 Loss 0.015 Val Acc 73.400
# L 19 Epoch 180 Loss 0.017 Val Acc 73.500
# L 19 Epoch 181 Loss 0.016 Val Acc 73.860
# L 19 Epoch 182 Loss 0.016 Val Acc 73.580
# L 19 Epoch 183 Loss 0.025 Val Acc 73.760
# L 19 Epoch 184 Loss 0.020 Val Acc 73.520
# ==> Saving model ...
# L 19 Epoch 185 Loss 0.020 Val Acc 74.000
# L 19 Epoch 186 Loss 0.017 Val Acc 73.520
# L 19 Epoch 187 Loss 0.018 Val Acc 73.800
# L 19 Epoch 188 Loss 0.019 Val Acc 73.560
# ==> Saving model ...
# L 19 Epoch 189 Loss 0.013 Val Acc 74.380
# L 19 Epoch 190 Loss 0.014 Val Acc 73.860
# L 19 Epoch 191 Loss 0.021 Val Acc 74.080
# L 19 Epoch 192 Loss 0.024 Val Acc 73.900
# L 19 Epoch 193 Loss 0.022 Val Acc 73.660
# L 19 Epoch 194 Loss 0.016 Val Acc 73.940
# L 19 Epoch 195 Loss 0.027 Val Acc 73.900
# L 19 Epoch 196 Loss 0.010 Val Acc 73.900
# L 19 Epoch 197 Loss 0.023 Val Acc 74.160
# L 19 Epoch 198 Loss 0.017 Val Acc 73.960
# L 19 Epoch 199 Loss 0.017 Val Acc 74.080
# L 20 Epoch 0 Loss 3.416 Val Acc 10.240
# L 20 Epoch 1 Loss 1.982 Val Acc 30.980
# L 20 Epoch 2 Loss 1.875 Val Acc 29.740
# L 20 Epoch 3 Loss 1.862 Val Acc 31.800
# L 20 Epoch 4 Loss 1.861 Val Acc 25.900
# L 20 Epoch 5 Loss 1.797 Val Acc 34.420
# L 20 Epoch 6 Loss 1.702 Val Acc 35.860
# L 20 Epoch 7 Loss 1.672 Val Acc 37.540
# ==> Saving model ...
# L 20 Epoch 8 Loss 1.603 Val Acc 40.740
# L 20 Epoch 9 Loss 1.529 Val Acc 35.280
# ==> Saving model ...
# L 20 Epoch 10 Loss 1.540 Val Acc 41.600
# ==> Saving model ...
# L 20 Epoch 11 Loss 1.450 Val Acc 45.400
# L 20 Epoch 12 Loss 1.401 Val Acc 44.180
# ==> Saving model ...
# L 20 Epoch 13 Loss 1.388 Val Acc 49.300
# L 20 Epoch 14 Loss 1.305 Val Acc 45.560
# ==> Saving model ...
# L 20 Epoch 15 Loss 1.322 Val Acc 51.000
# L 20 Epoch 16 Loss 1.334 Val Acc 48.680
# ==> Saving model ...
# L 20 Epoch 17 Loss 1.343 Val Acc 52.380
# ==> Saving model ...
# L 20 Epoch 18 Loss 1.224 Val Acc 54.640
# L 20 Epoch 19 Loss 1.233 Val Acc 50.980
# L 20 Epoch 20 Loss 1.232 Val Acc 51.080
# ==> Saving model ...
# L 20 Epoch 21 Loss 1.204 Val Acc 55.480
# L 20 Epoch 22 Loss 1.202 Val Acc 52.900
# L 20 Epoch 23 Loss 1.176 Val Acc 54.560
# ==> Saving model ...
# L 20 Epoch 24 Loss 1.101 Val Acc 60.540
# L 20 Epoch 25 Loss 1.001 Val Acc 58.220
# L 20 Epoch 26 Loss 1.047 Val Acc 60.160
# L 20 Epoch 27 Loss 1.062 Val Acc 60.040
# L 20 Epoch 28 Loss 1.011 Val Acc 60.380
# ==> Saving model ...
# L 20 Epoch 29 Loss 0.933 Val Acc 61.160
# ==> Saving model ...
# L 20 Epoch 30 Loss 0.871 Val Acc 62.920
# ==> Saving model ...
# L 20 Epoch 31 Loss 0.826 Val Acc 63.060
# L 20 Epoch 32 Loss 0.842 Val Acc 58.740
# L 20 Epoch 33 Loss 0.823 Val Acc 59.320
# L 20 Epoch 34 Loss 0.873 Val Acc 60.720
# L 20 Epoch 35 Loss 0.830 Val Acc 62.480
# L 20 Epoch 36 Loss 0.897 Val Acc 62.020
# L 20 Epoch 37 Loss 0.770 Val Acc 62.120
# ==> Saving model ...
# L 20 Epoch 38 Loss 0.719 Val Acc 64.020
# L 20 Epoch 39 Loss 0.796 Val Acc 57.560
# L 20 Epoch 40 Loss 0.869 Val Acc 63.260
# ==> Saving model ...
# L 20 Epoch 41 Loss 0.675 Val Acc 66.240
# L 20 Epoch 42 Loss 0.614 Val Acc 65.400
# L 20 Epoch 43 Loss 0.637 Val Acc 64.060
# L 20 Epoch 44 Loss 0.584 Val Acc 59.680
# L 20 Epoch 45 Loss 0.649 Val Acc 65.380
# L 20 Epoch 46 Loss 0.548 Val Acc 61.720
# L 20 Epoch 47 Loss 0.610 Val Acc 63.000
# ==> Saving model ...
# L 20 Epoch 48 Loss 0.700 Val Acc 67.200
# L 20 Epoch 49 Loss 0.579 Val Acc 66.960
# L 20 Epoch 50 Loss 0.529 Val Acc 66.540
# L 20 Epoch 51 Loss 0.458 Val Acc 65.500
# L 20 Epoch 52 Loss 0.446 Val Acc 67.080
# L 20 Epoch 53 Loss 0.471 Val Acc 65.600
# L 20 Epoch 54 Loss 0.448 Val Acc 67.140
# L 20 Epoch 55 Loss 0.490 Val Acc 64.820
# L 20 Epoch 56 Loss 0.441 Val Acc 67.100
# ==> Saving model ...
# L 20 Epoch 57 Loss 0.443 Val Acc 67.380
# L 20 Epoch 58 Loss 0.462 Val Acc 65.400
# ==> Saving model ...
# L 20 Epoch 59 Loss 0.434 Val Acc 68.880
# L 20 Epoch 60 Loss 0.504 Val Acc 68.640
# L 20 Epoch 61 Loss 0.392 Val Acc 68.140
# L 20 Epoch 62 Loss 0.360 Val Acc 68.200
# L 20 Epoch 63 Loss 0.290 Val Acc 68.620
# L 20 Epoch 64 Loss 0.278 Val Acc 66.760
# L 20 Epoch 65 Loss 0.560 Val Acc 67.560
# L 20 Epoch 66 Loss 0.414 Val Acc 65.540
# L 20 Epoch 67 Loss 0.402 Val Acc 65.980
# ==> Saving model ...
# L 20 Epoch 68 Loss 0.301 Val Acc 69.420
# L 20 Epoch 69 Loss 0.253 Val Acc 68.780
# L 20 Epoch 70 Loss 0.316 Val Acc 68.420
# L 20 Epoch 71 Loss 0.346 Val Acc 65.220
# L 20 Epoch 72 Loss 0.358 Val Acc 66.020
# L 20 Epoch 73 Loss 0.341 Val Acc 63.600
# L 20 Epoch 74 Loss 0.272 Val Acc 69.380
# L 20 Epoch 75 Loss 0.281 Val Acc 69.100
# L 20 Epoch 76 Loss 0.191 Val Acc 68.700
# L 20 Epoch 77 Loss 0.264 Val Acc 68.900
# L 20 Epoch 78 Loss 0.264 Val Acc 68.940
# L 20 Epoch 79 Loss 0.226 Val Acc 68.840
# L 20 Epoch 80 Loss 0.272 Val Acc 68.440
# ==> Saving model ...
# L 20 Epoch 81 Loss 0.191 Val Acc 69.560
# L 20 Epoch 82 Loss 0.214 Val Acc 67.180
# L 20 Epoch 83 Loss 0.218 Val Acc 69.440
# L 20 Epoch 84 Loss 0.206 Val Acc 68.560
# L 20 Epoch 85 Loss 0.183 Val Acc 68.240
# L 20 Epoch 86 Loss 0.291 Val Acc 68.040
# L 20 Epoch 87 Loss 0.297 Val Acc 68.580
# ==> Saving model ...
# L 20 Epoch 88 Loss 0.223 Val Acc 70.540
# ==> Saving model ...
# L 20 Epoch 89 Loss 0.172 Val Acc 72.200
# L 20 Epoch 90 Loss 0.116 Val Acc 70.620
# L 20 Epoch 91 Loss 0.183 Val Acc 68.420
# L 20 Epoch 92 Loss 0.261 Val Acc 64.660
# L 20 Epoch 93 Loss 0.342 Val Acc 68.600
# L 20 Epoch 94 Loss 0.143 Val Acc 70.580
# L 20 Epoch 95 Loss 0.133 Val Acc 70.220
# L 20 Epoch 96 Loss 0.137 Val Acc 70.220
# L 20 Epoch 97 Loss 0.216 Val Acc 69.160
# L 20 Epoch 98 Loss 0.192 Val Acc 67.260
# L 20 Epoch 99 Loss 0.144 Val Acc 69.140
# L 20 Epoch 100 Loss 0.155 Val Acc 70.000
# L 20 Epoch 101 Loss 0.154 Val Acc 67.400
# L 20 Epoch 102 Loss 0.207 Val Acc 69.900
# L 20 Epoch 103 Loss 0.146 Val Acc 69.780
# L 20 Epoch 104 Loss 0.168 Val Acc 70.520
# L 20 Epoch 105 Loss 0.156 Val Acc 68.720
# L 20 Epoch 106 Loss 0.157 Val Acc 70.660
# L 20 Epoch 107 Loss 0.114 Val Acc 71.700
# L 20 Epoch 108 Loss 0.193 Val Acc 70.440
# L 20 Epoch 109 Loss 0.141 Val Acc 70.500
# L 20 Epoch 110 Loss 0.134 Val Acc 70.480
# L 20 Epoch 111 Loss 0.166 Val Acc 69.920
# L 20 Epoch 112 Loss 0.211 Val Acc 69.660
# L 20 Epoch 113 Loss 0.193 Val Acc 70.160
# L 20 Epoch 114 Loss 0.146 Val Acc 71.060
# L 20 Epoch 115 Loss 0.160 Val Acc 70.920
# L 20 Epoch 116 Loss 0.133 Val Acc 71.080
# L 20 Epoch 117 Loss 0.080 Val Acc 71.500
# L 20 Epoch 118 Loss 0.110 Val Acc 71.020
# L 20 Epoch 119 Loss 0.131 Val Acc 71.720
# L 20 Epoch 120 Loss 0.066 Val Acc 71.660
# L 20 Epoch 121 Loss 0.077 Val Acc 71.060
# L 20 Epoch 122 Loss 0.077 Val Acc 71.740
# L 20 Epoch 123 Loss 0.070 Val Acc 72.020
# L 20 Epoch 124 Loss 0.142 Val Acc 71.040
# L 20 Epoch 125 Loss 0.128 Val Acc 70.120
# L 20 Epoch 126 Loss 0.170 Val Acc 68.820
# L 20 Epoch 127 Loss 0.116 Val Acc 70.560
# L 20 Epoch 128 Loss 0.079 Val Acc 71.260
# L 20 Epoch 129 Loss 0.140 Val Acc 71.120
# L 20 Epoch 130 Loss 0.122 Val Acc 70.500
# L 20 Epoch 131 Loss 0.111 Val Acc 70.840
# ==> Saving model ...
# L 20 Epoch 132 Loss 0.073 Val Acc 72.520
# L 20 Epoch 133 Loss 0.137 Val Acc 70.580
# L 20 Epoch 134 Loss 0.124 Val Acc 71.180
# L 20 Epoch 135 Loss 0.073 Val Acc 71.160
# L 20 Epoch 136 Loss 0.136 Val Acc 70.000
# L 20 Epoch 137 Loss 0.061 Val Acc 71.640
# L 20 Epoch 138 Loss 0.078 Val Acc 72.020
# ==> Saving model ...
# L 20 Epoch 139 Loss 0.067 Val Acc 72.700
# L 20 Epoch 140 Loss 0.058 Val Acc 72.440
# L 20 Epoch 141 Loss 0.099 Val Acc 71.540
# L 20 Epoch 142 Loss 0.075 Val Acc 72.140
# ==> Saving model ...
# L 20 Epoch 143 Loss 0.054 Val Acc 72.740
# L 20 Epoch 144 Loss 0.099 Val Acc 72.040
# ==> Saving model ...
# L 20 Epoch 145 Loss 0.050 Val Acc 73.080
# L 20 Epoch 146 Loss 0.052 Val Acc 72.260
# L 20 Epoch 147 Loss 0.075 Val Acc 72.260
# L 20 Epoch 148 Loss 0.048 Val Acc 72.840
# L 20 Epoch 149 Loss 0.055 Val Acc 72.980
# L 20 Epoch 150 Loss 0.057 Val Acc 72.720
# L 20 Epoch 151 Loss 0.057 Val Acc 72.360
# L 20 Epoch 152 Loss 0.046 Val Acc 72.080
# L 20 Epoch 153 Loss 0.054 Val Acc 72.340
# L 20 Epoch 154 Loss 0.032 Val Acc 73.080
# L 20 Epoch 155 Loss 0.029 Val Acc 72.760
# L 20 Epoch 156 Loss 0.050 Val Acc 72.520
# L 20 Epoch 157 Loss 0.040 Val Acc 72.720
# L 20 Epoch 158 Loss 0.034 Val Acc 73.000
# L 20 Epoch 159 Loss 0.022 Val Acc 72.940
# L 20 Epoch 160 Loss 0.025 Val Acc 72.760
# L 20 Epoch 161 Loss 0.037 Val Acc 73.060
# L 20 Epoch 162 Loss 0.032 Val Acc 72.620
# L 20 Epoch 163 Loss 0.025 Val Acc 72.960
# L 20 Epoch 164 Loss 0.034 Val Acc 72.940
# L 20 Epoch 165 Loss 0.029 Val Acc 73.060
# ==> Saving model ...
# L 20 Epoch 166 Loss 0.018 Val Acc 73.300
# ==> Saving model ...
# L 20 Epoch 167 Loss 0.037 Val Acc 73.440
# L 20 Epoch 168 Loss 0.029 Val Acc 72.900
# L 20 Epoch 169 Loss 0.029 Val Acc 72.900
# ==> Saving model ...
# L 20 Epoch 170 Loss 0.019 Val Acc 73.560
# L 20 Epoch 171 Loss 0.019 Val Acc 73.140
# L 20 Epoch 172 Loss 0.021 Val Acc 73.240
# L 20 Epoch 173 Loss 0.025 Val Acc 73.140
# L 20 Epoch 174 Loss 0.033 Val Acc 72.860
# L 20 Epoch 175 Loss 0.033 Val Acc 72.420
# L 20 Epoch 176 Loss 0.021 Val Acc 72.820
# L 20 Epoch 177 Loss 0.026 Val Acc 72.980
# L 20 Epoch 178 Loss 0.031 Val Acc 72.600
# L 20 Epoch 179 Loss 0.023 Val Acc 72.660
# L 20 Epoch 180 Loss 0.020 Val Acc 73.120
# L 20 Epoch 181 Loss 0.026 Val Acc 73.140
# L 20 Epoch 182 Loss 0.025 Val Acc 72.900
# L 20 Epoch 183 Loss 0.027 Val Acc 72.980
# L 20 Epoch 184 Loss 0.025 Val Acc 72.480
# L 20 Epoch 185 Loss 0.023 Val Acc 72.800
# L 20 Epoch 186 Loss 0.016 Val Acc 72.900
# L 20 Epoch 187 Loss 0.017 Val Acc 72.960
# L 20 Epoch 188 Loss 0.020 Val Acc 72.960
# L 20 Epoch 189 Loss 0.024 Val Acc 72.700
# L 20 Epoch 190 Loss 0.013 Val Acc 72.860
# L 20 Epoch 191 Loss 0.017 Val Acc 73.000
# L 20 Epoch 192 Loss 0.014 Val Acc 73.200
# L 20 Epoch 193 Loss 0.015 Val Acc 72.940
# L 20 Epoch 194 Loss 0.015 Val Acc 73.260
# L 20 Epoch 195 Loss 0.021 Val Acc 73.180
# L 20 Epoch 196 Loss 0.019 Val Acc 73.200
# L 20 Epoch 197 Loss 0.014 Val Acc 72.840
# L 20 Epoch 198 Loss 0.034 Val Acc 73.440
# L 20 Epoch 199 Loss 0.016 Val Acc 72.720

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
for L in range(1, 21):
    model = ScatResNet18(L).to(device)
    checkpoint = torch.load(checkpoint_dir / f"{MODEL_NAME}_L{L}_max_acc.pth", map_location=device)
    model.load_state_dict(checkpoint['net'])
    model.eval()
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=True)
    print(f'Final test accuracy for L {L} is: {calculate_accuracy(model, testloader, device):.3f}')
# Out:
# Final test accuracy for L 1 is: 73.480
# Final test accuracy for L 2 is: 74.090
# Final test accuracy for L 3 is: 76.820
# Final test accuracy for L 4 is: 78.360
# Final test accuracy for L 5 is: 77.980
# Final test accuracy for L 6 is: 76.840
# Final test accuracy for L 7 is: 77.670
# Final test accuracy for L 8 is: 77.810
# Final test accuracy for L 9 is: 77.120
# Final test accuracy for L 10 is: 77.100
# Final test accuracy for L 11 is: 76.470
# Final test accuracy for L 12 is: 76.000
# Final test accuracy for L 13 is: 75.910
# Final test accuracy for L 14 is: 75.250
# Final test accuracy for L 15 is: 74.850
# Final test accuracy for L 16 is: 74.410
# Final test accuracy for L 17 is: 74.640
# Final test accuracy for L 18 is: 74.040
# Final test accuracy for L 19 is: 74.410
# Final test accuracy for L 20 is: 74.030

# %%
for L in range(1,21):
    stats = stats_list[L - 1]
    total_params, model_size_mb = get_model_summary(ScatResNet18(L))
    stats['total_params'] = total_params
    stats['model_size_mb'] = model_size_mb
    stats['train_acc'] = calculate_accuracy(model, trainloader, device)
    stats['val_acc'] = calculate_accuracy(model, valloader, device)
    stats['test_acc'] = calculate_accuracy(model, testloader, device)
    
    with open(training_stats_dir / f'{MODEL_NAME}_L{L}_stats.pkl', 'wb') as file:
        pickle.dump(stats, file)
