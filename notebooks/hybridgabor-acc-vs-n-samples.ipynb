# %%
import sys, os
from pathlib import Path

IS_KAGGLE = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '') != ''

if IS_KAGGLE:
    # Install packages not available on Kaggle
    # %pip install -q kymatio kornia
    
    # Add repo to path (UPDATE 'deep-learning-course-project' to your dataset slug)
    repo_path = Path('/kaggle/input/d/giladnavok/deep-learning-course-project/')
    if repo_path.exists():
        sys.path.insert(0, str(repo_path))
else:
    # Local: add project root to path (assumes notebook is in notebooks/)
    project_root = Path.cwd().parent
    if (project_root / 'src').exists():
        sys.path.insert(0, str(project_root))

from src.utils.config import *
from src.utils.datasets import *
from src.models.architectures.HybridGaborResNet18 import *
from src.utils.training import *
from src.utils.visualization import *

from typing import Dict
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 2.8 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.
# ====================== Hyperparameters =======================
# N_EPOCHS: 200
# T_MAX: 200
# CRITERION: CrossEntropyLoss()
# DEVICE: cuda
# SEED: 42
# BATCH_SIZE: 128
# LR: 0.001
# MOMENTUM: 0.9
# WEIGHT_DECAY: 0.0001
# ================================================================
# Setting seed to 42

# %%
DEBUG = False
SKIP_TRAINING = False
EXP_NAME = "hybridgabor_acc_vs_n_samples"
print(f"Starting experiment {EXP_NAME}. DEBUG={DEBUG}, SKIP_TRAINING={SKIP_TRAINING}")

device = DEVICE

n_samples_per_class_train = [10, 50, 100, 200, 300, 400, 500, 1000, 4000]
# Out:
# Starting experiment hybridgabor_acc_vs_n_samples. DEBUG=False, SKIP_TRAINING=False

# %%
test_accs : dict[int, float] = {}

# Train and save model for each data size
for n_samples in n_samples_per_class_train:
    # Initialize model
    model = MakeHybridGaborResNet18().to(device)
    MODEL_NAME = f"HybridGaborResNet18_{n_samples}"

    total_params, model_size_mb = get_model_summary(model)
    print(f"Total Parameters: {total_params:,}")
    print(f"Model Size: {model_size_mb:.2f} MB")

    # Get data loaders
    trainloader, valloader, testloader, train_set, val_set, test_set = get_cifar10_loaders_and_splits(
    n_samples_per_class_train=n_samples
    )
    optimizer, scheduler = get_optimizer_and_scheduler(model, optimizer_type='sgd-hybrid-gabor')

    # Train model on n_samples
    if not SKIP_TRAINING:
        train_model(
            model=model,
            trainloader=trainloader,
            valloader=valloader,
            optimizer=optimizer,
            scheduler=scheduler,
            device=device,
            experiment_name=EXP_NAME,
            model_name=MODEL_NAME,
            val_accuracy_storing_threshold=0,
            print_progress_every=50,
            DEBUG=DEBUG
        )

        # Save accuracy on test set
        debug_suff = "_DEBUG" if DEBUG else ""
        load_weights(model, experiment_name=EXP_NAME, model_name=(MODEL_NAME+ debug_suff), device=device)
        test_acc = calculate_accuracy(model, testloader, device)
        test_accs[n_samples] = test_acc
        print(f'Final test accuracy is: {test_acc:.3f}')
# Out:
# Total Parameters: 11,173,386
# Model Size: 42.62 MB
# 100%|██████████| 170M/170M [00:10<00:00, 16.1MB/s]
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 100
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(8): 10, np.int64(7): 10, np.int64(4): 10, np.int64(3): 10, np.int64(5): 10, np.int64(6): 10, np.int64(1): 10, np.int64(2): 10, np.int64(0): 10, np.int64(9): 10})
# Samples per class (val): Counter({np.int64(3): 500, np.int64(6): 500, np.int64(7): 500, np.int64(0): 500, np.int64(5): 500, np.int64(1): 500, np.int64(8): 500, np.int64(9): 500, np.int64(4): 500, np.int64(2): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_10.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_10.pkl
#
# === Starting Training: HybridGaborResNet18_10 with 200 epochs ===
#     --> New Best Saved: 10.02%
# Epoch 1/200 | Loss: 2.467 | Val Acc: 10.02%
# Epoch 51/200 | Loss: 0.301 | Val Acc: 22.38%
# Epoch 101/200 | Loss: 0.183 | Val Acc: 27.04%
#     --> New Best Saved: 27.82%
# Epoch 151/200 | Loss: 0.038 | Val Acc: 27.82%
# === Finished HybridGaborResNet18_10. Total Time: 338.0s ===
# Final test accuracy is: 28.530
# Total Parameters: 11,173,386
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 500
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(3): 50, np.int64(0): 50, np.int64(8): 50, np.int64(7): 50, np.int64(2): 50, np.int64(1): 50, np.int64(6): 50, np.int64(4): 50, np.int64(5): 50, np.int64(9): 50})
# Samples per class (val): Counter({np.int64(2): 500, np.int64(4): 500, np.int64(1): 500, np.int64(3): 500, np.int64(6): 500, np.int64(0): 500, np.int64(9): 500, np.int64(5): 500, np.int64(7): 500, np.int64(8): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_50.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_50.pkl
#
# === Starting Training: HybridGaborResNet18_50 with 200 epochs ===
#     --> New Best Saved: 10.04%
# Epoch 1/200 | Loss: 3.965 | Val Acc: 10.04%
#     --> New Best Saved: 43.72%
# Epoch 51/200 | Loss: 0.633 | Val Acc: 43.72%
#     --> New Best Saved: 45.62%
# Epoch 101/200 | Loss: 0.067 | Val Acc: 45.62%
# Epoch 151/200 | Loss: 0.043 | Val Acc: 47.04%
# === Finished HybridGaborResNet18_50. Total Time: 402.8s ===
# Final test accuracy is: 47.620
# Total Parameters: 11,173,386
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 1000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 100, np.int64(1): 100, np.int64(8): 100, np.int64(4): 100, np.int64(3): 100, np.int64(9): 100, np.int64(5): 100, np.int64(0): 100, np.int64(2): 100, np.int64(6): 100})
# Samples per class (val): Counter({np.int64(1): 500, np.int64(9): 500, np.int64(2): 500, np.int64(4): 500, np.int64(6): 500, np.int64(5): 500, np.int64(0): 500, np.int64(3): 500, np.int64(8): 500, np.int64(7): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_100.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_100.pkl
#
# === Starting Training: HybridGaborResNet18_100 with 200 epochs ===
#     --> New Best Saved: 10.00%
# Epoch 1/200 | Loss: 3.740 | Val Acc: 10.00%
# Epoch 51/200 | Loss: 0.419 | Val Acc: 48.76%
# Epoch 101/200 | Loss: 0.046 | Val Acc: 53.52%
# Epoch 151/200 | Loss: 0.012 | Val Acc: 57.02%
# === Finished HybridGaborResNet18_100. Total Time: 486.8s ===
# Final test accuracy is: 58.490
# Total Parameters: 11,173,386
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 2000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(6): 200, np.int64(2): 200, np.int64(8): 200, np.int64(5): 200, np.int64(7): 200, np.int64(4): 200, np.int64(9): 200, np.int64(3): 200, np.int64(1): 200, np.int64(0): 200})
# Samples per class (val): Counter({np.int64(2): 500, np.int64(9): 500, np.int64(5): 500, np.int64(6): 500, np.int64(0): 500, np.int64(7): 500, np.int64(3): 500, np.int64(4): 500, np.int64(8): 500, np.int64(1): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_200.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_200.pkl
#
# === Starting Training: HybridGaborResNet18_200 with 200 epochs ===
#     --> New Best Saved: 9.82%
# Epoch 1/200 | Loss: 3.218 | Val Acc: 9.82%
#     --> New Best Saved: 58.92%
# Epoch 51/200 | Loss: 0.332 | Val Acc: 58.92%
# Epoch 101/200 | Loss: 0.054 | Val Acc: 62.66%
#     --> New Best Saved: 65.64%
# Epoch 151/200 | Loss: 0.015 | Val Acc: 65.64%
# === Finished HybridGaborResNet18_200. Total Time: 657.6s ===
# Final test accuracy is: 66.060
# Total Parameters: 11,173,386
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 3000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 300, np.int64(0): 300, np.int64(6): 300, np.int64(4): 300, np.int64(9): 300, np.int64(3): 300, np.int64(8): 300, np.int64(5): 300, np.int64(1): 300, np.int64(2): 300})
# Samples per class (val): Counter({np.int64(7): 500, np.int64(2): 500, np.int64(5): 500, np.int64(9): 500, np.int64(4): 500, np.int64(0): 500, np.int64(8): 500, np.int64(6): 500, np.int64(3): 500, np.int64(1): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_300.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_300.pkl
#
# === Starting Training: HybridGaborResNet18_300 with 200 epochs ===
#     --> New Best Saved: 17.56%
# Epoch 1/200 | Loss: 3.378 | Val Acc: 17.56%
# Epoch 51/200 | Loss: 0.344 | Val Acc: 65.08%
# Epoch 101/200 | Loss: 0.080 | Val Acc: 66.40%
# Epoch 151/200 | Loss: 0.008 | Val Acc: 70.46%
# === Finished HybridGaborResNet18_300. Total Time: 818.9s ===
# Final test accuracy is: 70.490
# Total Parameters: 11,173,386
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 4000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 400, np.int64(6): 400, np.int64(5): 400, np.int64(0): 400, np.int64(1): 400, np.int64(4): 400, np.int64(8): 400, np.int64(2): 400, np.int64(3): 400, np.int64(9): 400})
# Samples per class (val): Counter({np.int64(4): 500, np.int64(6): 500, np.int64(9): 500, np.int64(5): 500, np.int64(3): 500, np.int64(7): 500, np.int64(0): 500, np.int64(1): 500, np.int64(2): 500, np.int64(8): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_400.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_400.pkl
#
# === Starting Training: HybridGaborResNet18_400 with 200 epochs ===
#     --> New Best Saved: 21.28%
# Epoch 1/200 | Loss: 3.176 | Val Acc: 21.28%
# Epoch 51/200 | Loss: 0.301 | Val Acc: 64.08%
# Epoch 101/200 | Loss: 0.079 | Val Acc: 69.10%
# Epoch 151/200 | Loss: 0.021 | Val Acc: 71.98%
# === Finished HybridGaborResNet18_400. Total Time: 983.4s ===
# Final test accuracy is: 73.130
# Total Parameters: 11,173,386
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 5000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(4): 500, np.int64(7): 500, np.int64(3): 500, np.int64(1): 500, np.int64(2): 500, np.int64(8): 500, np.int64(5): 500, np.int64(0): 500, np.int64(9): 500, np.int64(6): 500})
# Samples per class (val): Counter({np.int64(5): 500, np.int64(8): 500, np.int64(2): 500, np.int64(9): 500, np.int64(1): 500, np.int64(3): 500, np.int64(0): 500, np.int64(6): 500, np.int64(7): 500, np.int64(4): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_500.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_500.pkl
#
# === Starting Training: HybridGaborResNet18_500 with 200 epochs ===
#     --> New Best Saved: 12.82%
# Epoch 1/200 | Loss: 3.052 | Val Acc: 12.82%
# Epoch 51/200 | Loss: 0.507 | Val Acc: 66.56%
#     --> New Best Saved: 72.30%
# Epoch 101/200 | Loss: 0.099 | Val Acc: 72.30%
# Epoch 151/200 | Loss: 0.047 | Val Acc: 72.82%
# === Finished HybridGaborResNet18_500. Total Time: 1148.7s ===
# Final test accuracy is: 74.240
# Total Parameters: 11,173,386
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 10000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(7): 1000, np.int64(2): 1000, np.int64(3): 1000, np.int64(9): 1000, np.int64(6): 1000, np.int64(8): 1000, np.int64(5): 1000, np.int64(0): 1000, np.int64(4): 1000, np.int64(1): 1000})
# Samples per class (val): Counter({np.int64(0): 500, np.int64(2): 500, np.int64(7): 500, np.int64(8): 500, np.int64(3): 500, np.int64(1): 500, np.int64(5): 500, np.int64(4): 500, np.int64(9): 500, np.int64(6): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_1000.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_1000.pkl
#
# === Starting Training: HybridGaborResNet18_1000 with 200 epochs ===
#     --> New Best Saved: 21.52%
# Epoch 1/200 | Loss: 2.806 | Val Acc: 21.52%
# Epoch 51/200 | Loss: 0.304 | Val Acc: 72.36%
# Epoch 101/200 | Loss: 0.127 | Val Acc: 75.02%
# Epoch 151/200 | Loss: 0.016 | Val Acc: 79.16%
# === Finished HybridGaborResNet18_1000. Total Time: 1978.5s ===
# Final test accuracy is: 80.630
# Total Parameters: 11,173,386
# Model Size: 42.62 MB
# Using default 500 samples per class for val.
# Original train-val size: 50000
# Train size: 40000
# Val size: 5000
# Test size: 10000
# Samples per class (train): Counter({np.int64(6): 4000, np.int64(7): 4000, np.int64(8): 4000, np.int64(3): 4000, np.int64(2): 4000, np.int64(1): 4000, np.int64(4): 4000, np.int64(9): 4000, np.int64(0): 4000, np.int64(5): 4000})
# Samples per class (val): Counter({np.int64(3): 500, np.int64(2): 500, np.int64(8): 500, np.int64(4): 500, np.int64(6): 500, np.int64(9): 500, np.int64(7): 500, np.int64(0): 500, np.int64(5): 500, np.int64(1): 500})
# Model weights will be saved to: /kaggle/working/artifacts/checkpoints/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_4000.pth
# Stats will be saved to: /kaggle/working/artifacts/stats/hybridgabor_acc_vs_n_samples_HybridGaborResNet18_4000.pkl
#
# === Starting Training: HybridGaborResNet18_4000 with 200 epochs ===
#     --> New Best Saved: 47.98%
# Epoch 1/200 | Loss: 1.808 | Val Acc: 47.98%
# Epoch 51/200 | Loss: 0.344 | Val Acc: 80.14%
# Epoch 101/200 | Loss: 0.201 | Val Acc: 85.50%
# Epoch 151/200 | Loss: 0.047 | Val Acc: 89.64%
# === Finished HybridGaborResNet18_4000. Total Time: 6983.3s ===
# Final test accuracy is: 92.420

# %%
# Plot accuracy vs data size
plt.figure(figsize=(10, 5))
plt.plot(list(test_accs.keys()), list(test_accs.values()), marker='o', linestyle='-', color='b')
plt.xlabel('Number of Training Samples per Class')
plt.ylabel('Test Accuracy')
plt.title('Accuracy vs Number of Training Samples per Class')
plt.grid(True)
if not SKIP_TRAINING:
    plt.savefig(FIGURES_PATH / 'baseline_acc_vs_n_samples.png')
plt.show()
