# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms

# !pip install kornia
from kornia import augmentation as K
from kornia.augmentation import AugmentationSequential
from torch.utils.data import random_split

import numpy as np

import os
import time
from pathlib import Path
import pickle

from torch.utils.data import Subset
from sklearn.model_selection import train_test_split

DEBUG = False
MODEL_NAME = "baseline_100"
TRAIN_SIZE = 1000
VALIDATION_SIZE = 5000
env = 'kaggle' # 'kaggle' or 'colab'

if env == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')
    base_dir = Path('/content/drive/MyDrive/dl_pj')    
elif env == 'kaggle':
    base_dir = Path('/kaggle/working/')

checkpoint_dir = base_dir / 'checkpoints'
checkpoint_dir.mkdir(parents=True, exist_ok=True)
training_stats_dir = base_dir / 'stats'
training_stats_dir.mkdir(parents=True, exist_ok=True)
# Out:
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia) (0.1.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from kornia) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->kornia) (3.0.3)

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes,kernel_size=1,stride=stride,bias=False),
                nn.BatchNorm2d(planes)
            )


    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out



class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layer = []
        for s in strides:
            layer.append(block(self.in_planes, planes, s))
            self.in_planes = planes
        return nn.Sequential(*layer)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
def get_model_summary(model):
    num_params = sum(p.numel() for p in model.parameters())
    total_bytes = sum(p.numel() * p.element_size() for p in model.parameters())
    size_mb = total_bytes / (1024 ** 2)
    return num_params, size_mb

total_params, model_size_mb = get_model_summary(ResNet18())
print(f"Total Parameters: {total_params:,}")
print(f"Model Size: {model_size_mb:.2f} MB")
# Out:
# Total Parameters: 11,173,962
# Model Size: 42.63 MB

# %%
def calculate_accuracy(model, dataloader, device):
    model.eval() # put in evaluation mode,  turn off Dropout, BatchNorm uses learned statistics
    total_correct = 0
    total_images = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            images = normalize(images)
            outputs = model(images)
            predictions = torch.argmax(outputs, dim=-1)
            total_images += labels.size(0)
            total_correct += (predictions == labels).sum().item()

    model_accuracy = total_correct / total_images * 100
    return model_accuracy

# %% [markdown]
# Split data set into train-validation-test.
# We are using 80% train, 20% validation split

# %%
transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor()]
)

# 80/20% split
train_val_set = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform
)


targets = np.array(train_val_set.targets)

indices = np.arange(len(targets))
train_indices, remaining_indices = train_test_split(
    indices,
    train_size=TRAIN_SIZE,
    stratify=targets,
    random_state=42
)

validation_indices, _ = train_test_split(
    remaining_indices,
    train_size=VALIDATION_SIZE,
    stratify=targets[remaining_indices],
    random_state=42
)

trainset = Subset(train_val_set, train_indices)
valset = Subset(train_val_set, validation_indices)
print(f"Original size: {len(train_val_set)}")
print(f"Train size: {len(trainset)}")
print(f"Val size: {len(valset)}")

from collections import Counter 
subset_labels = [targets[i] for i in train_indices]
print("Samples per class", Counter(subset_labels))
subset_labels = [targets[i] for i in validation_indices]
print("Samples per class", Counter(subset_labels))

testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform
)
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 49.5MB/s]
# Original size: 50000
# Train size: 1000
# Val size: 5000
# Samples per class Counter({np.int64(7): 100, np.int64(1): 100, np.int64(8): 100, np.int64(4): 100, np.int64(3): 100, np.int64(9): 100, np.int64(5): 100, np.int64(0): 100, np.int64(2): 100, np.int64(6): 100})
# Samples per class Counter({np.int64(1): 500, np.int64(9): 500, np.int64(2): 500, np.int64(4): 500, np.int64(6): 500, np.int64(5): 500, np.int64(0): 500, np.int64(3): 500, np.int64(8): 500, np.int64(7): 500})

# %%
# Hyperparamters
batch_size = 128

lr = 0.1
momentum = 0.9
weight_decay = 5e-4

T_max = 200

n_epochs = 1 if DEBUG else 200

print_progress_every = 1
val_accuracy_storing_threshold = 40

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
mean = torch.tensor([0.4914, 0.4822, 0.4465]).to(device)
std = torch.tensor([0.2023, 0.1994, 0.2010]).to(device)
normalize = K.Normalize(mean=mean, std=std)
# define a sequence of augmentations
aug_list = AugmentationSequential(
    K.RandomHorizontalFlip(p=0.5),
    K.ColorJitter(0.1, 0.1, 0.1, 0.1, p=0.2),
    K.RandomResizedCrop(size=(32,32), scale=(0.7, 1.0), p=0.5),
    normalize,
    same_on_batch=False
).to(device)


trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=True)
model = ResNet18().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)

stats = {
    'total_training_time': 0,
    'loss': [],
    'time_per_epoch': [],
    'total_time_per_epoch': [],
    'val_accuracy': [],
    'max_val_accuracy': 0,
    'allocated_memory': [], # Memory currently used by Tensors
    'reserved_memory': [], # Memory held by the PyTorch caching allocator
}

start_time = time.time()
for epoch in range(n_epochs):
    model.train()
    iteration_losses = []
    epoch_start_time = time.time()
    for inputs, targets in trainloader:
        inputs = inputs.to(device)
        targets = targets.to(device)

        inputs = aug_list(inputs)

        outputs = model(inputs)

        optimizer.zero_grad()
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        iteration_losses.append(loss.item())

    scheduler.step()
    epoch_end_time = time.time()

    model.eval()
    val_accuracy = calculate_accuracy(model, valloader, device)

    # Track stats
    if (epoch % 1) == 0:
        stats['loss'].append(
            np.mean(iteration_losses)
        )
        stats['val_accuracy'].append(
            val_accuracy
        )
        stats['allocated_memory'].append(torch.cuda.memory_allocated())
        stats['reserved_memory'].append(torch.cuda.memory_reserved())
        stats['time_per_epoch'].append(epoch_end_time - epoch_start_time)
        stats['total_time_per_epoch'].append(time.time() - start_time)

    # Store best model
    if (val_accuracy > stats['max_val_accuracy']):
        if (val_accuracy > val_accuracy_storing_threshold):
            stats['max_val_accuracy'] = val_accuracy
            print('==> Saving model ...')
            state = {
                'net': model.state_dict(),
                'epoch': epoch,
                'acc':val_accuracy
            }
            save_path = checkpoint_dir / f"{MODEL_NAME}_max_acc.pth"
            torch.save(state, save_path)

    if DEBUG:
        print('==> Saving model ... DEBUG')
        state = {
            'net': model.state_dict(),
            'epoch': epoch,
            'acc':val_accuracy
        }
        save_path = checkpoint_dir / f"{MODEL_NAME}_max_acc.pth"
        torch.save(state, save_path)
        
    # Print progress
    if (epoch % print_progress_every) == 0:
        print(f"Epoch {epoch} Loss {stats['loss'][-1]:.3f} Val Acc {stats['val_accuracy'][-1]:.3f}")
# Out:
# Epoch 0 Loss 4.004 Val Acc 10.000
# Epoch 1 Loss 5.517 Val Acc 10.000
# Epoch 2 Loss 3.187 Val Acc 9.480
# Epoch 3 Loss 2.483 Val Acc 13.000
# Epoch 4 Loss 2.188 Val Acc 17.440
# Epoch 5 Loss 2.133 Val Acc 20.380
# Epoch 6 Loss 2.075 Val Acc 20.460
# Epoch 7 Loss 2.068 Val Acc 23.320
# Epoch 8 Loss 2.022 Val Acc 23.100
# Epoch 9 Loss 1.984 Val Acc 25.300
# Epoch 10 Loss 1.954 Val Acc 24.120
# Epoch 11 Loss 1.947 Val Acc 24.640
# Epoch 12 Loss 1.872 Val Acc 26.560
# Epoch 13 Loss 1.818 Val Acc 29.200
# Epoch 14 Loss 1.799 Val Acc 31.840
# Epoch 15 Loss 1.802 Val Acc 28.940
# Epoch 16 Loss 1.736 Val Acc 32.100
# Epoch 17 Loss 1.729 Val Acc 31.320
# Epoch 18 Loss 1.732 Val Acc 31.740
# Epoch 19 Loss 1.676 Val Acc 34.300
# Epoch 20 Loss 1.613 Val Acc 31.000
# Epoch 21 Loss 1.586 Val Acc 32.960
# Epoch 22 Loss 1.568 Val Acc 33.680
# Epoch 23 Loss 1.487 Val Acc 34.000
# Epoch 24 Loss 1.491 Val Acc 33.260
# Epoch 25 Loss 1.459 Val Acc 33.860
# Epoch 26 Loss 1.528 Val Acc 35.240
# Epoch 27 Loss 1.470 Val Acc 32.140
# Epoch 28 Loss 1.453 Val Acc 31.940
# Epoch 29 Loss 1.377 Val Acc 36.200
# Epoch 30 Loss 1.389 Val Acc 37.140
# Epoch 31 Loss 1.353 Val Acc 36.700
# Epoch 32 Loss 1.336 Val Acc 36.580
# Epoch 33 Loss 1.327 Val Acc 33.980
# Epoch 34 Loss 1.280 Val Acc 33.680
# Epoch 35 Loss 1.270 Val Acc 34.100
# Epoch 36 Loss 1.222 Val Acc 38.780
# Epoch 37 Loss 1.190 Val Acc 37.180
# Epoch 38 Loss 1.114 Val Acc 39.020
# ==> Saving model ...
# Epoch 39 Loss 1.112 Val Acc 40.720
# Epoch 40 Loss 1.034 Val Acc 35.640
# Epoch 41 Loss 1.088 Val Acc 34.780
# ==> Saving model ...
# Epoch 42 Loss 0.934 Val Acc 40.820
# Epoch 43 Loss 0.896 Val Acc 38.240
# Epoch 44 Loss 0.984 Val Acc 37.860
# Epoch 45 Loss 1.040 Val Acc 37.980
# Epoch 46 Loss 0.999 Val Acc 39.660
# Epoch 47 Loss 0.955 Val Acc 39.300
# Epoch 48 Loss 0.836 Val Acc 40.100
# Epoch 49 Loss 0.836 Val Acc 36.800
# Epoch 50 Loss 0.730 Val Acc 37.500
# Epoch 51 Loss 0.679 Val Acc 38.420
# Epoch 52 Loss 0.659 Val Acc 39.320
# Epoch 53 Loss 0.669 Val Acc 39.880
# Epoch 54 Loss 0.752 Val Acc 39.520
# Epoch 55 Loss 0.832 Val Acc 37.340
# Epoch 56 Loss 0.786 Val Acc 39.120
# Epoch 57 Loss 0.599 Val Acc 39.360
# Epoch 58 Loss 0.516 Val Acc 39.040
# ==> Saving model ...
# Epoch 59 Loss 0.564 Val Acc 41.560
# Epoch 60 Loss 0.520 Val Acc 37.720
# Epoch 61 Loss 0.426 Val Acc 39.140
# ==> Saving model ...
# Epoch 62 Loss 0.410 Val Acc 41.640
# Epoch 63 Loss 0.457 Val Acc 38.540
# Epoch 64 Loss 0.413 Val Acc 38.600
# Epoch 65 Loss 0.323 Val Acc 39.320
# Epoch 66 Loss 0.370 Val Acc 41.340
# Epoch 67 Loss 0.319 Val Acc 40.800
# ==> Saving model ...
# Epoch 68 Loss 0.315 Val Acc 41.840
# Epoch 69 Loss 0.326 Val Acc 40.360
# ==> Saving model ...
# Epoch 70 Loss 0.247 Val Acc 42.040
# Epoch 71 Loss 0.301 Val Acc 39.900
# Epoch 72 Loss 0.325 Val Acc 40.860
# Epoch 73 Loss 0.267 Val Acc 40.760
# Epoch 74 Loss 0.376 Val Acc 41.640
# Epoch 75 Loss 0.282 Val Acc 39.280
# Epoch 76 Loss 0.340 Val Acc 40.380
# Epoch 77 Loss 0.303 Val Acc 40.920
# ==> Saving model ...
# Epoch 78 Loss 0.314 Val Acc 42.200
# Epoch 79 Loss 0.196 Val Acc 41.500
# Epoch 80 Loss 0.299 Val Acc 42.020
# ==> Saving model ...
# Epoch 81 Loss 0.202 Val Acc 42.660
# Epoch 82 Loss 0.176 Val Acc 42.180
# Epoch 83 Loss 0.228 Val Acc 40.840
# Epoch 84 Loss 0.257 Val Acc 41.200
# Epoch 85 Loss 0.216 Val Acc 39.340
# Epoch 86 Loss 0.223 Val Acc 41.600
# Epoch 87 Loss 0.225 Val Acc 42.200
# Epoch 88 Loss 0.165 Val Acc 40.820
# ==> Saving model ...
# Epoch 89 Loss 0.192 Val Acc 42.900
# Epoch 90 Loss 0.155 Val Acc 41.900
# Epoch 91 Loss 0.168 Val Acc 42.340
# Epoch 92 Loss 0.080 Val Acc 42.720
# ==> Saving model ...
# Epoch 93 Loss 0.087 Val Acc 43.340
# ==> Saving model ...
# Epoch 94 Loss 0.135 Val Acc 44.440
# Epoch 95 Loss 0.117 Val Acc 41.980
# Epoch 96 Loss 0.125 Val Acc 42.840
# Epoch 97 Loss 0.150 Val Acc 41.420
# Epoch 98 Loss 0.135 Val Acc 42.520
# Epoch 99 Loss 0.146 Val Acc 43.680
# Epoch 100 Loss 0.175 Val Acc 41.800
# Epoch 101 Loss 0.156 Val Acc 42.980
# Epoch 102 Loss 0.117 Val Acc 40.540
# Epoch 103 Loss 0.107 Val Acc 41.960
# Epoch 104 Loss 0.080 Val Acc 43.240
# Epoch 105 Loss 0.137 Val Acc 43.140
# Epoch 106 Loss 0.118 Val Acc 43.420
# Epoch 107 Loss 0.062 Val Acc 43.660
# Epoch 108 Loss 0.094 Val Acc 43.880
# Epoch 109 Loss 0.100 Val Acc 42.960
# Epoch 110 Loss 0.076 Val Acc 43.960
# Epoch 111 Loss 0.096 Val Acc 44.020
# Epoch 112 Loss 0.106 Val Acc 43.340
# Epoch 113 Loss 0.087 Val Acc 42.800
# Epoch 114 Loss 0.113 Val Acc 43.660
# Epoch 115 Loss 0.073 Val Acc 43.000
# Epoch 116 Loss 0.113 Val Acc 43.020
# Epoch 117 Loss 0.063 Val Acc 43.220
# Epoch 118 Loss 0.078 Val Acc 43.480
# Epoch 119 Loss 0.037 Val Acc 43.740
# Epoch 120 Loss 0.063 Val Acc 44.140
# Epoch 121 Loss 0.094 Val Acc 44.440
# Epoch 122 Loss 0.063 Val Acc 43.940
# Epoch 123 Loss 0.057 Val Acc 42.520
# Epoch 124 Loss 0.075 Val Acc 44.000
# Epoch 125 Loss 0.045 Val Acc 44.340
# Epoch 126 Loss 0.072 Val Acc 43.940
# Epoch 127 Loss 0.019 Val Acc 43.500
# Epoch 128 Loss 0.025 Val Acc 44.280
# Epoch 129 Loss 0.032 Val Acc 44.180
# ==> Saving model ...
# Epoch 130 Loss 0.060 Val Acc 44.820
# Epoch 131 Loss 0.050 Val Acc 44.620
# Epoch 132 Loss 0.035 Val Acc 44.240
# Epoch 133 Loss 0.034 Val Acc 44.260
# Epoch 134 Loss 0.041 Val Acc 44.360
# Epoch 135 Loss 0.014 Val Acc 44.360
# Epoch 136 Loss 0.035 Val Acc 44.500
# Epoch 137 Loss 0.039 Val Acc 44.640
# ==> Saving model ...
# Epoch 138 Loss 0.037 Val Acc 45.400
# Epoch 139 Loss 0.049 Val Acc 44.860
# Epoch 140 Loss 0.044 Val Acc 45.240
# Epoch 141 Loss 0.028 Val Acc 45.160
# Epoch 142 Loss 0.048 Val Acc 45.320
# Epoch 143 Loss 0.042 Val Acc 44.840
# Epoch 144 Loss 0.031 Val Acc 44.860
# Epoch 145 Loss 0.027 Val Acc 45.000
# Epoch 146 Loss 0.024 Val Acc 45.040
# Epoch 147 Loss 0.026 Val Acc 45.200
# ==> Saving model ...
# Epoch 148 Loss 0.029 Val Acc 45.420
# ==> Saving model ...
# Epoch 149 Loss 0.024 Val Acc 45.460
# Epoch 150 Loss 0.036 Val Acc 45.160
# Epoch 151 Loss 0.029 Val Acc 45.420
# Epoch 152 Loss 0.016 Val Acc 45.460
# ==> Saving model ...
# Epoch 153 Loss 0.037 Val Acc 45.860
# Epoch 154 Loss 0.023 Val Acc 45.800
# Epoch 155 Loss 0.039 Val Acc 45.780
# Epoch 156 Loss 0.031 Val Acc 45.680
# Epoch 157 Loss 0.023 Val Acc 45.180
# Epoch 158 Loss 0.019 Val Acc 45.200
# Epoch 159 Loss 0.028 Val Acc 45.380
# Epoch 160 Loss 0.013 Val Acc 45.640
# Epoch 161 Loss 0.023 Val Acc 45.480
# ==> Saving model ...
# Epoch 162 Loss 0.010 Val Acc 45.900
# Epoch 163 Loss 0.013 Val Acc 45.760
# ==> Saving model ...
# Epoch 164 Loss 0.020 Val Acc 46.140
# ==> Saving model ...
# Epoch 165 Loss 0.027 Val Acc 46.160
# Epoch 166 Loss 0.031 Val Acc 45.900
# Epoch 167 Loss 0.017 Val Acc 46.020
# Epoch 168 Loss 0.018 Val Acc 46.000
# Epoch 169 Loss 0.028 Val Acc 45.900
# Epoch 170 Loss 0.023 Val Acc 45.840
# Epoch 171 Loss 0.016 Val Acc 45.980
# Epoch 172 Loss 0.011 Val Acc 45.460
# Epoch 173 Loss 0.019 Val Acc 45.580
# Epoch 174 Loss 0.019 Val Acc 45.480
# Epoch 175 Loss 0.013 Val Acc 45.620
# Epoch 176 Loss 0.016 Val Acc 45.660
# Epoch 177 Loss 0.016 Val Acc 45.640
# Epoch 178 Loss 0.017 Val Acc 45.740
# Epoch 179 Loss 0.012 Val Acc 45.780
# Epoch 180 Loss 0.008 Val Acc 45.860
# Epoch 181 Loss 0.013 Val Acc 45.700
# Epoch 182 Loss 0.027 Val Acc 45.720
# Epoch 183 Loss 0.018 Val Acc 45.780
# Epoch 184 Loss 0.032 Val Acc 45.880
# Epoch 185 Loss 0.023 Val Acc 45.880
# Epoch 186 Loss 0.017 Val Acc 45.680
# Epoch 187 Loss 0.027 Val Acc 45.660
# Epoch 188 Loss 0.019 Val Acc 45.600
# Epoch 189 Loss 0.023 Val Acc 45.420
# Epoch 190 Loss 0.031 Val Acc 45.620
# Epoch 191 Loss 0.012 Val Acc 45.780
# Epoch 192 Loss 0.014 Val Acc 45.600
# Epoch 193 Loss 0.033 Val Acc 45.540
# Epoch 194 Loss 0.012 Val Acc 45.580
# Epoch 195 Loss 0.019 Val Acc 45.660
# Epoch 196 Loss 0.023 Val Acc 45.600
# Epoch 197 Loss 0.012 Val Acc 45.680
# Epoch 198 Loss 0.014 Val Acc 45.680
# Epoch 199 Loss 0.011 Val Acc 45.640

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = ResNet18().to(device)
checkpoint = torch.load(checkpoint_dir / f"{MODEL_NAME}_max_acc.pth", map_location=device)
model.load_state_dict(checkpoint['net'])
model.eval()
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=True)
print(f'Final test accuracy is: {calculate_accuracy(model, testloader, device):.3f}')
# Out:
# Final test accuracy is: 46.160

# %%
with open(training_stats_dir / f'{MODEL_NAME}_stats.pkl', 'wb') as file:
    pickle.dump(stats, file)
