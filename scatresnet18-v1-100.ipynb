# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms

# !pip install kornia
# !pip install kymatio
from kornia import augmentation as K
from kornia.augmentation import AugmentationSequential
from torch.utils.data import random_split

import numpy as np

import os
import time
from pathlib import Path
import pickle

from torch.utils.data import Subset
from sklearn.model_selection import train_test_split

from kymatio.torch import Scattering2D

DEBUG = False
MODEL_NAME = "ScatResNet18_v1_100"
TRAIN_SIZE = 1000
VALIDATION_SIZE = 5000
env = 'kaggle' # 'kaggle' or 'colab'

if env == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')
    base_dir = Path('/content/drive/MyDrive/dl_pj')    
elif env == 'kaggle':
    base_dir = Path('/kaggle/working/')

checkpoint_dir = base_dir / 'checkpoints'
checkpoint_dir.mkdir(parents=True, exist_ok=True)
training_stats_dir = base_dir / 'stats'
training_stats_dir.mkdir(parents=True, exist_ok=True)
# Out:
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia) (0.1.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from kornia) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->kornia) (3.0.3)
# Collecting kymatio
#   Downloading kymatio-0.3.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting appdirs (from kymatio)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting configparser (from kymatio)
#   Downloading configparser-7.2.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from kymatio) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kymatio) (25.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from kymatio) (1.15.3)
# Downloading kymatio-0.3.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 4.1 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading configparser-7.2.0-py3-none-any.whl (17 kB)
# Installing collected packages: appdirs, configparser, kymatio
# Successfully installed appdirs-1.4.4 configparser-7.2.0 kymatio-0.3.0

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes,kernel_size=1,stride=stride,bias=False),
                nn.BatchNorm2d(planes)
            )


    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out



class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10, L=8):
        super(ResNet, self).__init__()
        self.in_planes = 64
        self.L = L
        self.scat_channels = (1 + L) * 3
        self.conv1 = nn.Conv2d(3, 64 - self.scat_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.scat1 = Scattering2D(J=1, shape=(32, 32), L=L, max_order=2, backend='torch')
        self.deconv1 = nn.ConvTranspose2d(in_channels=self.scat_channels, out_channels=self.scat_channels, groups=self.scat_channels, kernel_size=2, stride=2)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layer = []
        for s in strides:
            layer.append(block(self.in_planes, planes, s))
            self.in_planes = planes
        return nn.Sequential(*layer)

    def forward(self, x):
        out = self.conv1(x)
        scat = self.scat1(x)
        scat = scat.view(scat.size(0), -1, 16,16)
        scat = self.deconv1(scat)
        out = torch.cat((out, scat), dim=1)
        out = F.relu(self.bn1(out))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ScatResNet18(L):
    return ResNet(BasicBlock, [2, 2, 2, 2], L=L)

# %%
def get_model_summary(model):
    num_params = sum(p.numel() for p in model.parameters())
    total_bytes = sum(p.numel() * p.element_size() for p in model.parameters())
    size_mb = total_bytes / (1024 ** 2)
    return num_params, size_mb
for L in range(1,21):
    total_params, model_size_mb = get_model_summary(ScatResNet18(L))
    print(f"Total Parameters: {total_params:,}")
    print(f"Model Size: {model_size_mb:.2f} MB")
# Out:
# Total Parameters: 11,173,830
# Model Size: 42.62 MB
# Total Parameters: 11,173,764
# Model Size: 42.62 MB
# Total Parameters: 11,173,698
# Model Size: 42.62 MB
# Total Parameters: 11,173,632
# Model Size: 42.62 MB
# Total Parameters: 11,173,566
# Model Size: 42.62 MB
# Total Parameters: 11,173,500
# Model Size: 42.62 MB
# Total Parameters: 11,173,434
# Model Size: 42.62 MB
# Total Parameters: 11,173,368
# Model Size: 42.62 MB
# Total Parameters: 11,173,302
# Model Size: 42.62 MB
# Total Parameters: 11,173,236
# Model Size: 42.62 MB
# Total Parameters: 11,173,170
# Model Size: 42.62 MB
# Total Parameters: 11,173,104
# Model Size: 42.62 MB
# Total Parameters: 11,173,038
# Model Size: 42.62 MB
# Total Parameters: 11,172,972
# Model Size: 42.62 MB
# Total Parameters: 11,172,906
# Model Size: 42.62 MB
# Total Parameters: 11,172,840
# Model Size: 42.62 MB
# Total Parameters: 11,172,774
# Model Size: 42.62 MB
# Total Parameters: 11,172,708
# Model Size: 42.62 MB
# Total Parameters: 11,172,642
# Model Size: 42.62 MB
# Total Parameters: 11,172,576
# Model Size: 42.62 MB

# %%
def calculate_accuracy(model, dataloader, device):
    model.eval() # put in evaluation mode,  turn off Dropout, BatchNorm uses learned statistics
    total_correct = 0
    total_images = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            images = normalize(images)
            outputs = model(images)
            predictions = torch.argmax(outputs, dim=-1)
            total_images += labels.size(0)
            total_correct += (predictions == labels).sum().item()

    model_accuracy = total_correct / total_images * 100
    return model_accuracy

# %% [markdown]
# Split data set into train-validation-test.
# We are using 80% train, 20% validation split

# %%
transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor()]
)

# 80/20% split
train_val_set = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform
)


targets = np.array(train_val_set.targets)

indices = np.arange(len(targets))
train_indices, remaining_indices = train_test_split(
    indices,
    train_size=TRAIN_SIZE,
    stratify=targets,
    random_state=42
)

validation_indices, _ = train_test_split(
    remaining_indices,
    train_size=VALIDATION_SIZE,
    stratify=targets[remaining_indices],
    random_state=42
)

trainset = Subset(train_val_set, train_indices)
valset = Subset(train_val_set, validation_indices)
print(f"Original size: {len(train_val_set)}")
print(f"Train size: {len(trainset)}")
print(f"Val size: {len(valset)}")

from collections import Counter 
subset_labels = [targets[i] for i in train_indices]
print("Samples per class", Counter(subset_labels))
subset_labels = [targets[i] for i in validation_indices]
print("Samples per class", Counter(subset_labels))

testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform
)
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 42.9MB/s]
# Original size: 50000
# Train size: 1000
# Val size: 5000
# Samples per class Counter({np.int64(7): 100, np.int64(1): 100, np.int64(8): 100, np.int64(4): 100, np.int64(3): 100, np.int64(9): 100, np.int64(5): 100, np.int64(0): 100, np.int64(2): 100, np.int64(6): 100})
# Samples per class Counter({np.int64(1): 500, np.int64(9): 500, np.int64(2): 500, np.int64(4): 500, np.int64(6): 500, np.int64(5): 500, np.int64(0): 500, np.int64(3): 500, np.int64(8): 500, np.int64(7): 500})

# %%
# Hyperparamters
batch_size = 128

lr = 0.1
momentum = 0.9
weight_decay = 5e-4

T_max = 200

n_epochs = 1 if DEBUG else 200

print_progress_every = 1
val_accuracy_storing_threshold = 40

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
mean = torch.tensor([0.4914, 0.4822, 0.4465]).to(device)
std = torch.tensor([0.2023, 0.1994, 0.2010]).to(device)
normalize = K.Normalize(mean=mean, std=std)
# define a sequence of augmentations
aug_list = AugmentationSequential(
    K.RandomHorizontalFlip(p=0.5),
    K.ColorJitter(0.1, 0.1, 0.1, 0.1, p=0.2),
    K.RandomResizedCrop(size=(32,32), scale=(0.7, 1.0), p=0.5),
    normalize,
    same_on_batch=False
).to(device)


trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=True)
stats_list = []
for L in range(1, 21):
    model = ScatResNet18(L).to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)
    
    stats = {
        'total_training_time': 0,
        'loss': [],
        'time_per_epoch': [],
        'total_time_per_epoch': [],
        'val_accuracy': [],
        'max_val_accuracy': 0,
        'allocated_memory': [], # Memory currently used by Tensors
        'reserved_memory': [], # Memory held by the PyTorch caching allocator
    }
    
    start_time = time.time()
    for epoch in range(n_epochs):
        model.train()
        iteration_losses = []
        epoch_start_time = time.time()
        for inputs, targets in trainloader:
            inputs = inputs.to(device)
            targets = targets.to(device)
    
            inputs = aug_list(inputs)
    
            outputs = model(inputs)
    
            optimizer.zero_grad()
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            iteration_losses.append(loss.item())
    
        scheduler.step()
        epoch_end_time = time.time()
    
        model.eval()
        val_accuracy = calculate_accuracy(model, valloader, device)
    
        # Track stats
        if (epoch % 1) == 0:
            stats['loss'].append(
                np.mean(iteration_losses)
            )
            stats['val_accuracy'].append(
                val_accuracy
            )
            stats['allocated_memory'].append(torch.cuda.memory_allocated())
            stats['reserved_memory'].append(torch.cuda.memory_reserved())
            stats['time_per_epoch'].append(epoch_end_time - epoch_start_time)
            stats['total_time_per_epoch'].append(time.time() - start_time)
    
        # Store best model
        if (val_accuracy > stats['max_val_accuracy']):
            if (val_accuracy > val_accuracy_storing_threshold):
                stats['max_val_accuracy'] = val_accuracy
                print('==> Saving model ...')
                state = {
                    'net': model.state_dict(),
                    'epoch': epoch,
                    'acc':val_accuracy
                }
                save_path = checkpoint_dir / f"{MODEL_NAME}_L{L}_max_acc.pth"
                torch.save(state, save_path)
    
        if DEBUG:
            print('==> Saving model ... DEBUG')
            state = {
                'net': model.state_dict(),
                'epoch': epoch,
                'acc':val_accuracy
            }
            save_path = checkpoint_dir / f"{MODEL_NAME}_L{L}_max_acc.pth"
            torch.save(state, save_path)
            
        # Print progress
        if (epoch % print_progress_every) == 0:
            print(f"L {L} Epoch {epoch} Loss {stats['loss'][-1]:.3f} Val Acc {stats['val_accuracy'][-1]:.3f}")
    stats_list.append(stats)
# Out:
# L 1 Epoch 0 Loss 4.302 Val Acc 10.000
# L 1 Epoch 1 Loss 3.462 Val Acc 10.120
# L 1 Epoch 2 Loss 2.556 Val Acc 8.860
# L 1 Epoch 3 Loss 2.360 Val Acc 11.260
# L 1 Epoch 4 Loss 2.173 Val Acc 21.660
# L 1 Epoch 5 Loss 2.101 Val Acc 22.740
# L 1 Epoch 6 Loss 2.034 Val Acc 23.520
# L 1 Epoch 7 Loss 1.977 Val Acc 17.140
# L 1 Epoch 8 Loss 1.885 Val Acc 22.100
# L 1 Epoch 9 Loss 1.829 Val Acc 25.440
# L 1 Epoch 10 Loss 1.799 Val Acc 29.900
# L 1 Epoch 11 Loss 1.789 Val Acc 31.900
# L 1 Epoch 12 Loss 1.735 Val Acc 32.480
# L 1 Epoch 13 Loss 1.712 Val Acc 32.900
# L 1 Epoch 14 Loss 1.652 Val Acc 34.960
# L 1 Epoch 15 Loss 1.602 Val Acc 34.500
# L 1 Epoch 16 Loss 1.561 Val Acc 34.800
# L 1 Epoch 17 Loss 1.563 Val Acc 35.040
# L 1 Epoch 18 Loss 1.634 Val Acc 36.840
# L 1 Epoch 19 Loss 1.507 Val Acc 38.440
# L 1 Epoch 20 Loss 1.441 Val Acc 38.460
# L 1 Epoch 21 Loss 1.414 Val Acc 35.060
# L 1 Epoch 22 Loss 1.413 Val Acc 37.700
# L 1 Epoch 23 Loss 1.439 Val Acc 35.780
# L 1 Epoch 24 Loss 1.422 Val Acc 39.960
# L 1 Epoch 25 Loss 1.308 Val Acc 36.240
# L 1 Epoch 26 Loss 1.312 Val Acc 39.200
# L 1 Epoch 27 Loss 1.306 Val Acc 39.960
# L 1 Epoch 28 Loss 1.215 Val Acc 39.920
# ==> Saving model ...
# L 1 Epoch 29 Loss 1.257 Val Acc 40.860
# L 1 Epoch 30 Loss 1.254 Val Acc 39.220
# ==> Saving model ...
# L 1 Epoch 31 Loss 1.229 Val Acc 41.540
# L 1 Epoch 32 Loss 1.206 Val Acc 39.980
# ==> Saving model ...
# L 1 Epoch 33 Loss 1.073 Val Acc 42.680
# L 1 Epoch 34 Loss 1.073 Val Acc 40.120
# ==> Saving model ...
# L 1 Epoch 35 Loss 1.011 Val Acc 43.460
# L 1 Epoch 36 Loss 1.075 Val Acc 42.600
# L 1 Epoch 37 Loss 0.967 Val Acc 42.300
# L 1 Epoch 38 Loss 1.029 Val Acc 41.660
# L 1 Epoch 39 Loss 0.957 Val Acc 37.720
# L 1 Epoch 40 Loss 0.865 Val Acc 42.740
# ==> Saving model ...
# L 1 Epoch 41 Loss 0.808 Val Acc 43.840
# L 1 Epoch 42 Loss 0.719 Val Acc 42.140
# L 1 Epoch 43 Loss 0.770 Val Acc 42.360
# ==> Saving model ...
# L 1 Epoch 44 Loss 0.683 Val Acc 45.000
# L 1 Epoch 45 Loss 0.633 Val Acc 44.920
# ==> Saving model ...
# L 1 Epoch 46 Loss 0.498 Val Acc 45.320
# L 1 Epoch 47 Loss 0.470 Val Acc 44.840
# L 1 Epoch 48 Loss 0.658 Val Acc 44.080
# L 1 Epoch 49 Loss 0.790 Val Acc 40.060
# L 1 Epoch 50 Loss 0.630 Val Acc 42.360
# ==> Saving model ...
# L 1 Epoch 51 Loss 0.497 Val Acc 45.620
# L 1 Epoch 52 Loss 0.415 Val Acc 41.060
# L 1 Epoch 53 Loss 0.492 Val Acc 40.080
# ==> Saving model ...
# L 1 Epoch 54 Loss 0.334 Val Acc 45.880
# L 1 Epoch 55 Loss 0.487 Val Acc 42.880
# L 1 Epoch 56 Loss 0.240 Val Acc 45.720
# L 1 Epoch 57 Loss 0.365 Val Acc 42.280
# L 1 Epoch 58 Loss 0.353 Val Acc 45.840
# L 1 Epoch 59 Loss 0.277 Val Acc 45.460
# L 1 Epoch 60 Loss 0.353 Val Acc 42.400
# L 1 Epoch 61 Loss 0.279 Val Acc 43.580
# L 1 Epoch 62 Loss 0.327 Val Acc 45.100
# L 1 Epoch 63 Loss 0.352 Val Acc 45.120
# L 1 Epoch 64 Loss 0.307 Val Acc 43.700
# L 1 Epoch 65 Loss 0.255 Val Acc 44.540
# L 1 Epoch 66 Loss 0.286 Val Acc 43.700
# ==> Saving model ...
# L 1 Epoch 67 Loss 0.221 Val Acc 46.460
# L 1 Epoch 68 Loss 0.347 Val Acc 45.240
# L 1 Epoch 69 Loss 0.281 Val Acc 46.000
# L 1 Epoch 70 Loss 0.331 Val Acc 43.800
# ==> Saving model ...
# L 1 Epoch 71 Loss 0.129 Val Acc 46.960
# L 1 Epoch 72 Loss 0.162 Val Acc 46.060
# L 1 Epoch 73 Loss 0.182 Val Acc 43.960
# L 1 Epoch 74 Loss 0.226 Val Acc 45.720
# L 1 Epoch 75 Loss 0.137 Val Acc 46.460
# L 1 Epoch 76 Loss 0.133 Val Acc 46.080
# L 1 Epoch 77 Loss 0.147 Val Acc 46.820
# L 1 Epoch 78 Loss 0.206 Val Acc 45.640
# L 1 Epoch 79 Loss 0.082 Val Acc 44.720
# L 1 Epoch 80 Loss 0.187 Val Acc 45.380
# L 1 Epoch 81 Loss 0.105 Val Acc 45.680
# L 1 Epoch 82 Loss 0.102 Val Acc 46.560
# ==> Saving model ...
# L 1 Epoch 83 Loss 0.119 Val Acc 48.100
# L 1 Epoch 84 Loss 0.143 Val Acc 45.260
# L 1 Epoch 85 Loss 0.199 Val Acc 46.520
# L 1 Epoch 86 Loss 0.120 Val Acc 45.360
# L 1 Epoch 87 Loss 0.131 Val Acc 45.420
# L 1 Epoch 88 Loss 0.169 Val Acc 47.740
# L 1 Epoch 89 Loss 0.188 Val Acc 47.220
# L 1 Epoch 90 Loss 0.063 Val Acc 47.380
# L 1 Epoch 91 Loss 0.114 Val Acc 46.420
# ==> Saving model ...
# L 1 Epoch 92 Loss 0.150 Val Acc 48.300
# L 1 Epoch 93 Loss 0.124 Val Acc 47.820
# L 1 Epoch 94 Loss 0.092 Val Acc 46.980
# L 1 Epoch 95 Loss 0.180 Val Acc 46.720
# L 1 Epoch 96 Loss 0.030 Val Acc 47.280
# L 1 Epoch 97 Loss 0.109 Val Acc 47.900
# ==> Saving model ...
# L 1 Epoch 98 Loss 0.044 Val Acc 49.060
# L 1 Epoch 99 Loss 0.093 Val Acc 47.880
# L 1 Epoch 100 Loss 0.082 Val Acc 47.280
# L 1 Epoch 101 Loss 0.050 Val Acc 46.780
# L 1 Epoch 102 Loss 0.081 Val Acc 46.560
# L 1 Epoch 103 Loss 0.090 Val Acc 45.980
# L 1 Epoch 104 Loss 0.078 Val Acc 48.200
# L 1 Epoch 105 Loss 0.089 Val Acc 46.340
# L 1 Epoch 106 Loss 0.084 Val Acc 47.980
# L 1 Epoch 107 Loss 0.054 Val Acc 48.280
# L 1 Epoch 108 Loss 0.053 Val Acc 47.140
# L 1 Epoch 109 Loss 0.052 Val Acc 48.080
# L 1 Epoch 110 Loss 0.085 Val Acc 46.560
# L 1 Epoch 111 Loss 0.050 Val Acc 45.740
# L 1 Epoch 112 Loss 0.053 Val Acc 48.560
# L 1 Epoch 113 Loss 0.089 Val Acc 46.400
# L 1 Epoch 114 Loss 0.079 Val Acc 45.280
# L 1 Epoch 115 Loss 0.074 Val Acc 48.660
# L 1 Epoch 116 Loss 0.050 Val Acc 48.680
# L 1 Epoch 117 Loss 0.067 Val Acc 45.980
# L 1 Epoch 118 Loss 0.029 Val Acc 47.760
# L 1 Epoch 119 Loss 0.068 Val Acc 48.880
# L 1 Epoch 120 Loss 0.065 Val Acc 46.840
# L 1 Epoch 121 Loss 0.047 Val Acc 47.260
# L 1 Epoch 122 Loss 0.035 Val Acc 47.720
# L 1 Epoch 123 Loss 0.043 Val Acc 48.320
# L 1 Epoch 124 Loss 0.043 Val Acc 47.560
# L 1 Epoch 125 Loss 0.053 Val Acc 47.900
# L 1 Epoch 126 Loss 0.034 Val Acc 48.360
# L 1 Epoch 127 Loss 0.026 Val Acc 48.680
# ==> Saving model ...
# L 1 Epoch 128 Loss 0.019 Val Acc 49.080
# L 1 Epoch 129 Loss 0.046 Val Acc 49.000
# L 1 Epoch 130 Loss 0.041 Val Acc 48.040
# L 1 Epoch 131 Loss 0.052 Val Acc 48.000
# L 1 Epoch 132 Loss 0.046 Val Acc 48.600
# L 1 Epoch 133 Loss 0.038 Val Acc 48.260
# L 1 Epoch 134 Loss 0.072 Val Acc 47.020
# L 1 Epoch 135 Loss 0.052 Val Acc 47.660
# L 1 Epoch 136 Loss 0.047 Val Acc 48.120
# L 1 Epoch 137 Loss 0.027 Val Acc 48.760
# L 1 Epoch 138 Loss 0.050 Val Acc 48.060
# L 1 Epoch 139 Loss 0.031 Val Acc 47.820
# L 1 Epoch 140 Loss 0.031 Val Acc 47.900
# L 1 Epoch 141 Loss 0.022 Val Acc 48.420
# L 1 Epoch 142 Loss 0.039 Val Acc 48.080
# L 1 Epoch 143 Loss 0.035 Val Acc 48.780
# L 1 Epoch 144 Loss 0.021 Val Acc 48.620
# L 1 Epoch 145 Loss 0.026 Val Acc 48.900
# L 1 Epoch 146 Loss 0.032 Val Acc 48.300
# L 1 Epoch 147 Loss 0.030 Val Acc 47.700
# L 1 Epoch 148 Loss 0.026 Val Acc 47.600
# L 1 Epoch 149 Loss 0.024 Val Acc 48.440
# L 1 Epoch 150 Loss 0.029 Val Acc 48.980
# ==> Saving model ...
# L 1 Epoch 151 Loss 0.033 Val Acc 49.260
# ==> Saving model ...
# L 1 Epoch 152 Loss 0.014 Val Acc 49.700
# L 1 Epoch 153 Loss 0.027 Val Acc 48.980
# L 1 Epoch 154 Loss 0.017 Val Acc 49.160
# L 1 Epoch 155 Loss 0.016 Val Acc 49.660
# L 1 Epoch 156 Loss 0.023 Val Acc 49.300
# L 1 Epoch 157 Loss 0.040 Val Acc 47.840
# L 1 Epoch 158 Loss 0.022 Val Acc 48.820
# L 1 Epoch 159 Loss 0.031 Val Acc 48.420
# L 1 Epoch 160 Loss 0.032 Val Acc 49.020
# L 1 Epoch 161 Loss 0.023 Val Acc 49.260
# L 1 Epoch 162 Loss 0.015 Val Acc 49.500
# L 1 Epoch 163 Loss 0.017 Val Acc 49.220
# L 1 Epoch 164 Loss 0.021 Val Acc 49.020
# L 1 Epoch 165 Loss 0.013 Val Acc 49.360
# L 1 Epoch 166 Loss 0.019 Val Acc 49.300
# L 1 Epoch 167 Loss 0.014 Val Acc 49.540
# L 1 Epoch 168 Loss 0.013 Val Acc 49.640
# L 1 Epoch 169 Loss 0.019 Val Acc 49.640
# L 1 Epoch 170 Loss 0.021 Val Acc 49.680
# L 1 Epoch 171 Loss 0.016 Val Acc 49.620
# L 1 Epoch 172 Loss 0.007 Val Acc 49.700
# ==> Saving model ...
# L 1 Epoch 173 Loss 0.004 Val Acc 50.460
# L 1 Epoch 174 Loss 0.010 Val Acc 49.880
# L 1 Epoch 175 Loss 0.040 Val Acc 49.360
# L 1 Epoch 176 Loss 0.015 Val Acc 49.420
# L 1 Epoch 177 Loss 0.026 Val Acc 49.320
# L 1 Epoch 178 Loss 0.024 Val Acc 49.860
# L 1 Epoch 179 Loss 0.016 Val Acc 49.380
# L 1 Epoch 180 Loss 0.017 Val Acc 49.820
# L 1 Epoch 181 Loss 0.009 Val Acc 49.780
# L 1 Epoch 182 Loss 0.028 Val Acc 48.840
# L 1 Epoch 183 Loss 0.012 Val Acc 49.300
# L 1 Epoch 184 Loss 0.010 Val Acc 49.860
# L 1 Epoch 185 Loss 0.026 Val Acc 49.220
# L 1 Epoch 186 Loss 0.004 Val Acc 50.040
# L 1 Epoch 187 Loss 0.017 Val Acc 50.180
# L 1 Epoch 188 Loss 0.026 Val Acc 49.520
# L 1 Epoch 189 Loss 0.009 Val Acc 49.980
# L 1 Epoch 190 Loss 0.020 Val Acc 49.920
# L 1 Epoch 191 Loss 0.007 Val Acc 49.820
# L 1 Epoch 192 Loss 0.017 Val Acc 49.780
# L 1 Epoch 193 Loss 0.015 Val Acc 49.700
# L 1 Epoch 194 Loss 0.004 Val Acc 50.040
# L 1 Epoch 195 Loss 0.011 Val Acc 49.780
# L 1 Epoch 196 Loss 0.006 Val Acc 49.820
# L 1 Epoch 197 Loss 0.015 Val Acc 49.820
# L 1 Epoch 198 Loss 0.010 Val Acc 50.060
# L 1 Epoch 199 Loss 0.010 Val Acc 49.940
# L 2 Epoch 0 Loss 4.231 Val Acc 10.000
# L 2 Epoch 1 Loss 3.173 Val Acc 10.000
# L 2 Epoch 2 Loss 3.278 Val Acc 10.000
# L 2 Epoch 3 Loss 2.698 Val Acc 12.800
# L 2 Epoch 4 Loss 2.285 Val Acc 17.580
# L 2 Epoch 5 Loss 2.229 Val Acc 13.800
# L 2 Epoch 6 Loss 2.131 Val Acc 15.600
# L 2 Epoch 7 Loss 2.020 Val Acc 22.040
# L 2 Epoch 8 Loss 1.960 Val Acc 24.180
# L 2 Epoch 9 Loss 1.946 Val Acc 24.600
# L 2 Epoch 10 Loss 1.962 Val Acc 26.000
# L 2 Epoch 11 Loss 1.901 Val Acc 29.200
# L 2 Epoch 12 Loss 1.762 Val Acc 22.680
# L 2 Epoch 13 Loss 1.766 Val Acc 29.880
# L 2 Epoch 14 Loss 1.713 Val Acc 32.720
# L 2 Epoch 15 Loss 1.663 Val Acc 29.720
# L 2 Epoch 16 Loss 1.682 Val Acc 30.740
# L 2 Epoch 17 Loss 1.579 Val Acc 29.780
# L 2 Epoch 18 Loss 1.515 Val Acc 38.480
# L 2 Epoch 19 Loss 1.569 Val Acc 32.680
# L 2 Epoch 20 Loss 1.572 Val Acc 38.000
# L 2 Epoch 21 Loss 1.496 Val Acc 38.720
# ==> Saving model ...
# L 2 Epoch 22 Loss 1.413 Val Acc 40.060
# L 2 Epoch 23 Loss 1.407 Val Acc 39.620
# L 2 Epoch 24 Loss 1.353 Val Acc 38.640
# ==> Saving model ...
# L 2 Epoch 25 Loss 1.348 Val Acc 42.420
# L 2 Epoch 26 Loss 1.324 Val Acc 40.660
# L 2 Epoch 27 Loss 1.331 Val Acc 41.400
# L 2 Epoch 28 Loss 1.216 Val Acc 42.220
# L 2 Epoch 29 Loss 1.184 Val Acc 40.540
# L 2 Epoch 30 Loss 1.278 Val Acc 41.060
# ==> Saving model ...
# L 2 Epoch 31 Loss 1.126 Val Acc 44.740
# L 2 Epoch 32 Loss 1.058 Val Acc 44.600
# L 2 Epoch 33 Loss 1.114 Val Acc 43.720
# L 2 Epoch 34 Loss 1.158 Val Acc 43.160
# L 2 Epoch 35 Loss 0.977 Val Acc 43.440
# L 2 Epoch 36 Loss 0.941 Val Acc 42.820
# ==> Saving model ...
# L 2 Epoch 37 Loss 0.977 Val Acc 47.640
# ==> Saving model ...
# L 2 Epoch 38 Loss 0.936 Val Acc 47.940
# L 2 Epoch 39 Loss 0.717 Val Acc 47.280
# L 2 Epoch 40 Loss 0.881 Val Acc 44.860
# L 2 Epoch 41 Loss 0.912 Val Acc 45.600
# L 2 Epoch 42 Loss 0.788 Val Acc 46.000
# L 2 Epoch 43 Loss 0.775 Val Acc 47.080
# L 2 Epoch 44 Loss 0.644 Val Acc 47.160
# L 2 Epoch 45 Loss 0.792 Val Acc 44.340
# L 2 Epoch 46 Loss 0.625 Val Acc 46.520
# L 2 Epoch 47 Loss 0.559 Val Acc 47.660
# ==> Saving model ...
# L 2 Epoch 48 Loss 0.500 Val Acc 48.320
# L 2 Epoch 49 Loss 0.572 Val Acc 45.800
# L 2 Epoch 50 Loss 0.730 Val Acc 43.460
# L 2 Epoch 51 Loss 0.443 Val Acc 48.320
# ==> Saving model ...
# L 2 Epoch 52 Loss 0.561 Val Acc 48.400
# L 2 Epoch 53 Loss 0.496 Val Acc 47.880
# ==> Saving model ...
# L 2 Epoch 54 Loss 0.451 Val Acc 50.340
# L 2 Epoch 55 Loss 0.391 Val Acc 46.920
# L 2 Epoch 56 Loss 0.371 Val Acc 48.560
# L 2 Epoch 57 Loss 0.350 Val Acc 48.400
# L 2 Epoch 58 Loss 0.395 Val Acc 47.780
# L 2 Epoch 59 Loss 0.446 Val Acc 47.880
# ==> Saving model ...
# L 2 Epoch 60 Loss 0.311 Val Acc 51.080
# L 2 Epoch 61 Loss 0.194 Val Acc 49.440
# L 2 Epoch 62 Loss 0.284 Val Acc 49.260
# L 2 Epoch 63 Loss 0.252 Val Acc 50.660
# L 2 Epoch 64 Loss 0.283 Val Acc 48.840
# ==> Saving model ...
# L 2 Epoch 65 Loss 0.276 Val Acc 51.120
# ==> Saving model ...
# L 2 Epoch 66 Loss 0.177 Val Acc 51.200
# L 2 Epoch 67 Loss 0.239 Val Acc 49.480
# L 2 Epoch 68 Loss 0.205 Val Acc 46.960
# L 2 Epoch 69 Loss 0.229 Val Acc 48.620
# L 2 Epoch 70 Loss 0.215 Val Acc 49.140
# L 2 Epoch 71 Loss 0.224 Val Acc 48.500
# L 2 Epoch 72 Loss 0.229 Val Acc 49.980
# L 2 Epoch 73 Loss 0.185 Val Acc 49.100
# L 2 Epoch 74 Loss 0.216 Val Acc 49.040
# ==> Saving model ...
# L 2 Epoch 75 Loss 0.207 Val Acc 51.340
# L 2 Epoch 76 Loss 0.098 Val Acc 50.440
# ==> Saving model ...
# L 2 Epoch 77 Loss 0.140 Val Acc 51.940
# L 2 Epoch 78 Loss 0.144 Val Acc 50.680
# L 2 Epoch 79 Loss 0.150 Val Acc 51.200
# L 2 Epoch 80 Loss 0.098 Val Acc 51.900
# L 2 Epoch 81 Loss 0.190 Val Acc 49.880
# L 2 Epoch 82 Loss 0.240 Val Acc 49.340
# L 2 Epoch 83 Loss 0.144 Val Acc 48.380
# L 2 Epoch 84 Loss 0.156 Val Acc 51.000
# ==> Saving model ...
# L 2 Epoch 85 Loss 0.094 Val Acc 52.240
# L 2 Epoch 86 Loss 0.115 Val Acc 51.760
# L 2 Epoch 87 Loss 0.067 Val Acc 52.060
# ==> Saving model ...
# L 2 Epoch 88 Loss 0.110 Val Acc 53.100
# L 2 Epoch 89 Loss 0.137 Val Acc 51.540
# L 2 Epoch 90 Loss 0.109 Val Acc 49.740
# L 2 Epoch 91 Loss 0.095 Val Acc 50.440
# L 2 Epoch 92 Loss 0.089 Val Acc 51.300
# L 2 Epoch 93 Loss 0.038 Val Acc 50.840
# L 2 Epoch 94 Loss 0.092 Val Acc 51.580
# L 2 Epoch 95 Loss 0.079 Val Acc 50.920
# L 2 Epoch 96 Loss 0.088 Val Acc 51.800
# L 2 Epoch 97 Loss 0.118 Val Acc 51.860
# L 2 Epoch 98 Loss 0.113 Val Acc 51.880
# L 2 Epoch 99 Loss 0.090 Val Acc 51.520
# L 2 Epoch 100 Loss 0.065 Val Acc 52.100
# L 2 Epoch 101 Loss 0.067 Val Acc 52.360
# ==> Saving model ...
# L 2 Epoch 102 Loss 0.089 Val Acc 53.460
# ==> Saving model ...
# L 2 Epoch 103 Loss 0.098 Val Acc 53.580
# L 2 Epoch 104 Loss 0.036 Val Acc 52.640
# L 2 Epoch 105 Loss 0.053 Val Acc 52.320
# L 2 Epoch 106 Loss 0.059 Val Acc 51.900
# L 2 Epoch 107 Loss 0.048 Val Acc 52.980
# L 2 Epoch 108 Loss 0.057 Val Acc 53.180
# L 2 Epoch 109 Loss 0.073 Val Acc 52.280
# L 2 Epoch 110 Loss 0.042 Val Acc 51.260
# L 2 Epoch 111 Loss 0.056 Val Acc 53.200
# L 2 Epoch 112 Loss 0.049 Val Acc 52.360
# L 2 Epoch 113 Loss 0.055 Val Acc 50.600
# L 2 Epoch 114 Loss 0.048 Val Acc 52.880
# L 2 Epoch 115 Loss 0.044 Val Acc 52.380
# L 2 Epoch 116 Loss 0.049 Val Acc 52.560
# L 2 Epoch 117 Loss 0.066 Val Acc 52.540
# L 2 Epoch 118 Loss 0.045 Val Acc 51.100
# L 2 Epoch 119 Loss 0.038 Val Acc 51.680
# L 2 Epoch 120 Loss 0.031 Val Acc 53.120
# L 2 Epoch 121 Loss 0.039 Val Acc 53.540
# ==> Saving model ...
# L 2 Epoch 122 Loss 0.051 Val Acc 53.740
# L 2 Epoch 123 Loss 0.044 Val Acc 53.540
# L 2 Epoch 124 Loss 0.034 Val Acc 53.340
# L 2 Epoch 125 Loss 0.043 Val Acc 53.420
# L 2 Epoch 126 Loss 0.042 Val Acc 53.420
# L 2 Epoch 127 Loss 0.023 Val Acc 53.220
# L 2 Epoch 128 Loss 0.034 Val Acc 53.200
# L 2 Epoch 129 Loss 0.036 Val Acc 53.460
# L 2 Epoch 130 Loss 0.023 Val Acc 53.580
# ==> Saving model ...
# L 2 Epoch 131 Loss 0.025 Val Acc 54.240
# L 2 Epoch 132 Loss 0.046 Val Acc 54.120
# L 2 Epoch 133 Loss 0.023 Val Acc 53.400
# ==> Saving model ...
# L 2 Epoch 134 Loss 0.015 Val Acc 54.580
# ==> Saving model ...
# L 2 Epoch 135 Loss 0.012 Val Acc 55.160
# L 2 Epoch 136 Loss 0.030 Val Acc 55.080
# L 2 Epoch 137 Loss 0.020 Val Acc 54.920
# L 2 Epoch 138 Loss 0.024 Val Acc 54.920
# L 2 Epoch 139 Loss 0.053 Val Acc 54.440
# L 2 Epoch 140 Loss 0.022 Val Acc 54.480
# L 2 Epoch 141 Loss 0.029 Val Acc 54.000
# L 2 Epoch 142 Loss 0.021 Val Acc 54.220
# L 2 Epoch 143 Loss 0.024 Val Acc 54.180
# L 2 Epoch 144 Loss 0.018 Val Acc 54.360
# L 2 Epoch 145 Loss 0.019 Val Acc 53.940
# L 2 Epoch 146 Loss 0.022 Val Acc 53.280
# L 2 Epoch 147 Loss 0.016 Val Acc 54.280
# L 2 Epoch 148 Loss 0.007 Val Acc 54.880
# L 2 Epoch 149 Loss 0.002 Val Acc 55.060
# L 2 Epoch 150 Loss 0.017 Val Acc 54.680
# L 2 Epoch 151 Loss 0.051 Val Acc 54.260
# L 2 Epoch 152 Loss 0.008 Val Acc 54.860
# L 2 Epoch 153 Loss 0.020 Val Acc 54.320
# L 2 Epoch 154 Loss 0.017 Val Acc 54.540
# L 2 Epoch 155 Loss 0.018 Val Acc 54.340
# L 2 Epoch 156 Loss 0.005 Val Acc 54.940
# ==> Saving model ...
# L 2 Epoch 157 Loss 0.017 Val Acc 55.320
# L 2 Epoch 158 Loss 0.031 Val Acc 55.000
# L 2 Epoch 159 Loss 0.021 Val Acc 54.660
# L 2 Epoch 160 Loss 0.012 Val Acc 55.140
# L 2 Epoch 161 Loss 0.021 Val Acc 54.640
# L 2 Epoch 162 Loss 0.025 Val Acc 54.280
# L 2 Epoch 163 Loss 0.019 Val Acc 53.940
# L 2 Epoch 164 Loss 0.010 Val Acc 54.780
# L 2 Epoch 165 Loss 0.022 Val Acc 54.160
# L 2 Epoch 166 Loss 0.013 Val Acc 54.080
# L 2 Epoch 167 Loss 0.019 Val Acc 54.240
# L 2 Epoch 168 Loss 0.017 Val Acc 54.480
# L 2 Epoch 169 Loss 0.011 Val Acc 54.600
# L 2 Epoch 170 Loss 0.007 Val Acc 55.220
# L 2 Epoch 171 Loss 0.010 Val Acc 54.960
# L 2 Epoch 172 Loss 0.023 Val Acc 54.660
# L 2 Epoch 173 Loss 0.011 Val Acc 54.780
# L 2 Epoch 174 Loss 0.006 Val Acc 54.860
# L 2 Epoch 175 Loss 0.017 Val Acc 54.160
# L 2 Epoch 176 Loss 0.015 Val Acc 54.000
# L 2 Epoch 177 Loss 0.022 Val Acc 54.000
# L 2 Epoch 178 Loss 0.007 Val Acc 54.860
# L 2 Epoch 179 Loss 0.013 Val Acc 55.100
# L 2 Epoch 180 Loss 0.007 Val Acc 54.940
# L 2 Epoch 181 Loss 0.013 Val Acc 54.860
# L 2 Epoch 182 Loss 0.009 Val Acc 54.800
# L 2 Epoch 183 Loss 0.010 Val Acc 54.920
# L 2 Epoch 184 Loss 0.008 Val Acc 54.940
# L 2 Epoch 185 Loss 0.011 Val Acc 54.900
# L 2 Epoch 186 Loss 0.010 Val Acc 55.120
# L 2 Epoch 187 Loss 0.016 Val Acc 54.780
# L 2 Epoch 188 Loss 0.011 Val Acc 54.920
# L 2 Epoch 189 Loss 0.016 Val Acc 54.520
# L 2 Epoch 190 Loss 0.027 Val Acc 54.560
# L 2 Epoch 191 Loss 0.016 Val Acc 54.580
# L 2 Epoch 192 Loss 0.017 Val Acc 54.500
# L 2 Epoch 193 Loss 0.009 Val Acc 54.340
# L 2 Epoch 194 Loss 0.023 Val Acc 54.200
# L 2 Epoch 195 Loss 0.029 Val Acc 54.480
# L 2 Epoch 196 Loss 0.007 Val Acc 55.020
# L 2 Epoch 197 Loss 0.011 Val Acc 54.200
# L 2 Epoch 198 Loss 0.013 Val Acc 54.420
# L 2 Epoch 199 Loss 0.012 Val Acc 55.000
# L 3 Epoch 0 Loss 3.784 Val Acc 10.000
# L 3 Epoch 1 Loss 3.783 Val Acc 9.980
# L 3 Epoch 2 Loss 2.611 Val Acc 11.980
# L 3 Epoch 3 Loss 2.318 Val Acc 16.320
# L 3 Epoch 4 Loss 2.121 Val Acc 19.000
# L 3 Epoch 5 Loss 1.984 Val Acc 23.660
# L 3 Epoch 6 Loss 1.851 Val Acc 26.980
# L 3 Epoch 7 Loss 1.812 Val Acc 30.800
# L 3 Epoch 8 Loss 1.686 Val Acc 30.780
# L 3 Epoch 9 Loss 1.663 Val Acc 33.460
# L 3 Epoch 10 Loss 1.651 Val Acc 34.780
# L 3 Epoch 11 Loss 1.559 Val Acc 36.920
# L 3 Epoch 12 Loss 1.580 Val Acc 36.060
# L 3 Epoch 13 Loss 1.506 Val Acc 37.160
# L 3 Epoch 14 Loss 1.527 Val Acc 37.160
# L 3 Epoch 15 Loss 1.489 Val Acc 36.360
# L 3 Epoch 16 Loss 1.437 Val Acc 37.680
# L 3 Epoch 17 Loss 1.402 Val Acc 37.040
# L 3 Epoch 18 Loss 1.380 Val Acc 37.560
# L 3 Epoch 19 Loss 1.432 Val Acc 32.840
# L 3 Epoch 20 Loss 1.338 Val Acc 37.080
# ==> Saving model ...
# L 3 Epoch 21 Loss 1.258 Val Acc 41.520
# L 3 Epoch 22 Loss 1.251 Val Acc 39.040
# L 3 Epoch 23 Loss 1.231 Val Acc 39.320
# ==> Saving model ...
# L 3 Epoch 24 Loss 1.168 Val Acc 42.080
# ==> Saving model ...
# L 3 Epoch 25 Loss 1.168 Val Acc 42.680
# ==> Saving model ...
# L 3 Epoch 26 Loss 1.085 Val Acc 42.920
# ==> Saving model ...
# L 3 Epoch 27 Loss 1.016 Val Acc 44.840
# L 3 Epoch 28 Loss 1.053 Val Acc 42.960
# L 3 Epoch 29 Loss 0.998 Val Acc 44.360
# L 3 Epoch 30 Loss 0.908 Val Acc 43.760
# L 3 Epoch 31 Loss 0.905 Val Acc 44.060
# ==> Saving model ...
# L 3 Epoch 32 Loss 0.924 Val Acc 45.100
# L 3 Epoch 33 Loss 0.893 Val Acc 42.860
# L 3 Epoch 34 Loss 0.952 Val Acc 42.400
# L 3 Epoch 35 Loss 0.889 Val Acc 42.500
# L 3 Epoch 36 Loss 0.742 Val Acc 42.500
# L 3 Epoch 37 Loss 0.818 Val Acc 40.040
# ==> Saving model ...
# L 3 Epoch 38 Loss 0.830 Val Acc 46.080
# L 3 Epoch 39 Loss 0.833 Val Acc 43.760
# L 3 Epoch 40 Loss 0.886 Val Acc 42.760
# L 3 Epoch 41 Loss 0.797 Val Acc 39.980
# L 3 Epoch 42 Loss 0.815 Val Acc 42.460
# ==> Saving model ...
# L 3 Epoch 43 Loss 0.619 Val Acc 47.280
# L 3 Epoch 44 Loss 0.588 Val Acc 45.740
# L 3 Epoch 45 Loss 0.632 Val Acc 44.020
# L 3 Epoch 46 Loss 0.640 Val Acc 44.120
# L 3 Epoch 47 Loss 0.499 Val Acc 47.200
# ==> Saving model ...
# L 3 Epoch 48 Loss 0.438 Val Acc 47.540
# ==> Saving model ...
# L 3 Epoch 49 Loss 0.324 Val Acc 47.660
# ==> Saving model ...
# L 3 Epoch 50 Loss 0.380 Val Acc 47.820
# L 3 Epoch 51 Loss 0.261 Val Acc 46.100
# ==> Saving model ...
# L 3 Epoch 52 Loss 0.299 Val Acc 48.660
# L 3 Epoch 53 Loss 0.310 Val Acc 48.460
# ==> Saving model ...
# L 3 Epoch 54 Loss 0.336 Val Acc 49.320
# L 3 Epoch 55 Loss 0.378 Val Acc 45.360
# L 3 Epoch 56 Loss 0.418 Val Acc 47.100
# L 3 Epoch 57 Loss 0.367 Val Acc 46.040
# L 3 Epoch 58 Loss 0.259 Val Acc 47.260
# L 3 Epoch 59 Loss 0.291 Val Acc 47.900
# L 3 Epoch 60 Loss 0.289 Val Acc 48.380
# L 3 Epoch 61 Loss 0.215 Val Acc 49.200
# L 3 Epoch 62 Loss 0.266 Val Acc 46.500
# L 3 Epoch 63 Loss 0.239 Val Acc 47.020
# L 3 Epoch 64 Loss 0.298 Val Acc 47.980
# L 3 Epoch 65 Loss 0.175 Val Acc 47.860
# L 3 Epoch 66 Loss 0.231 Val Acc 48.800
# L 3 Epoch 67 Loss 0.252 Val Acc 48.960
# ==> Saving model ...
# L 3 Epoch 68 Loss 0.109 Val Acc 50.780
# L 3 Epoch 69 Loss 0.207 Val Acc 50.100
# L 3 Epoch 70 Loss 0.178 Val Acc 47.720
# L 3 Epoch 71 Loss 0.308 Val Acc 48.620
# L 3 Epoch 72 Loss 0.232 Val Acc 50.540
# L 3 Epoch 73 Loss 0.154 Val Acc 48.680
# L 3 Epoch 74 Loss 0.107 Val Acc 50.080
# L 3 Epoch 75 Loss 0.137 Val Acc 50.600
# ==> Saving model ...
# L 3 Epoch 76 Loss 0.156 Val Acc 50.800
# L 3 Epoch 77 Loss 0.132 Val Acc 47.880
# L 3 Epoch 78 Loss 0.140 Val Acc 50.700
# L 3 Epoch 79 Loss 0.136 Val Acc 49.780
# L 3 Epoch 80 Loss 0.110 Val Acc 50.320
# ==> Saving model ...
# L 3 Epoch 81 Loss 0.142 Val Acc 52.640
# L 3 Epoch 82 Loss 0.141 Val Acc 49.860
# L 3 Epoch 83 Loss 0.131 Val Acc 51.200
# L 3 Epoch 84 Loss 0.186 Val Acc 51.260
# L 3 Epoch 85 Loss 0.094 Val Acc 49.120
# L 3 Epoch 86 Loss 0.122 Val Acc 50.480
# L 3 Epoch 87 Loss 0.110 Val Acc 52.100
# ==> Saving model ...
# L 3 Epoch 88 Loss 0.104 Val Acc 53.500
# L 3 Epoch 89 Loss 0.064 Val Acc 52.360
# L 3 Epoch 90 Loss 0.083 Val Acc 51.620
# L 3 Epoch 91 Loss 0.084 Val Acc 51.540
# L 3 Epoch 92 Loss 0.107 Val Acc 51.160
# L 3 Epoch 93 Loss 0.128 Val Acc 48.420
# L 3 Epoch 94 Loss 0.141 Val Acc 47.540
# L 3 Epoch 95 Loss 0.083 Val Acc 50.780
# L 3 Epoch 96 Loss 0.081 Val Acc 51.360
# L 3 Epoch 97 Loss 0.047 Val Acc 52.400
# L 3 Epoch 98 Loss 0.090 Val Acc 51.240
# L 3 Epoch 99 Loss 0.064 Val Acc 52.840
# L 3 Epoch 100 Loss 0.028 Val Acc 52.940
# L 3 Epoch 101 Loss 0.061 Val Acc 53.040
# L 3 Epoch 102 Loss 0.028 Val Acc 53.080
# L 3 Epoch 103 Loss 0.030 Val Acc 52.060
# L 3 Epoch 104 Loss 0.051 Val Acc 51.520
# L 3 Epoch 105 Loss 0.074 Val Acc 52.420
# L 3 Epoch 106 Loss 0.104 Val Acc 51.380
# L 3 Epoch 107 Loss 0.012 Val Acc 50.200
# L 3 Epoch 108 Loss 0.080 Val Acc 52.480
# L 3 Epoch 109 Loss 0.088 Val Acc 52.400
# L 3 Epoch 110 Loss 0.069 Val Acc 52.300
# L 3 Epoch 111 Loss 0.048 Val Acc 51.560
# L 3 Epoch 112 Loss 0.066 Val Acc 51.380
# L 3 Epoch 113 Loss 0.051 Val Acc 51.780
# L 3 Epoch 114 Loss 0.033 Val Acc 52.360
# L 3 Epoch 115 Loss 0.080 Val Acc 52.500
# L 3 Epoch 116 Loss 0.044 Val Acc 51.880
# L 3 Epoch 117 Loss 0.053 Val Acc 53.380
# ==> Saving model ...
# L 3 Epoch 118 Loss 0.028 Val Acc 53.600
# L 3 Epoch 119 Loss 0.048 Val Acc 52.600
# L 3 Epoch 120 Loss 0.045 Val Acc 53.180
# L 3 Epoch 121 Loss 0.069 Val Acc 52.860
# L 3 Epoch 122 Loss 0.050 Val Acc 53.580
# ==> Saving model ...
# L 3 Epoch 123 Loss 0.026 Val Acc 53.780
# L 3 Epoch 124 Loss 0.052 Val Acc 52.020
# L 3 Epoch 125 Loss 0.056 Val Acc 52.100
# L 3 Epoch 126 Loss 0.024 Val Acc 52.580
# L 3 Epoch 127 Loss 0.026 Val Acc 53.320
# L 3 Epoch 128 Loss 0.031 Val Acc 53.740
# L 3 Epoch 129 Loss 0.027 Val Acc 53.780
# ==> Saving model ...
# L 3 Epoch 130 Loss 0.019 Val Acc 54.180
# L 3 Epoch 131 Loss 0.027 Val Acc 53.580
# L 3 Epoch 132 Loss 0.028 Val Acc 53.280
# L 3 Epoch 133 Loss 0.031 Val Acc 53.180
# L 3 Epoch 134 Loss 0.060 Val Acc 52.320
# L 3 Epoch 135 Loss 0.029 Val Acc 52.580
# L 3 Epoch 136 Loss 0.026 Val Acc 52.240
# L 3 Epoch 137 Loss 0.030 Val Acc 53.700
# ==> Saving model ...
# L 3 Epoch 138 Loss 0.008 Val Acc 54.680
# L 3 Epoch 139 Loss 0.024 Val Acc 54.440
# L 3 Epoch 140 Loss 0.024 Val Acc 54.340
# L 3 Epoch 141 Loss 0.018 Val Acc 54.160
# L 3 Epoch 142 Loss 0.027 Val Acc 53.720
# L 3 Epoch 143 Loss 0.028 Val Acc 51.800
# L 3 Epoch 144 Loss 0.021 Val Acc 52.020
# L 3 Epoch 145 Loss 0.031 Val Acc 52.540
# L 3 Epoch 146 Loss 0.033 Val Acc 52.440
# L 3 Epoch 147 Loss 0.039 Val Acc 53.140
# L 3 Epoch 148 Loss 0.011 Val Acc 53.820
# L 3 Epoch 149 Loss 0.010 Val Acc 54.660
# L 3 Epoch 150 Loss 0.017 Val Acc 54.200
# ==> Saving model ...
# L 3 Epoch 151 Loss 0.009 Val Acc 54.980
# L 3 Epoch 152 Loss 0.020 Val Acc 54.560
# L 3 Epoch 153 Loss 0.023 Val Acc 53.900
# L 3 Epoch 154 Loss 0.004 Val Acc 54.600
# ==> Saving model ...
# L 3 Epoch 155 Loss 0.006 Val Acc 55.200
# L 3 Epoch 156 Loss 0.011 Val Acc 55.140
# L 3 Epoch 157 Loss 0.034 Val Acc 54.200
# L 3 Epoch 158 Loss 0.018 Val Acc 54.640
# L 3 Epoch 159 Loss 0.028 Val Acc 54.160
# ==> Saving model ...
# L 3 Epoch 160 Loss 0.007 Val Acc 55.240
# L 3 Epoch 161 Loss 0.023 Val Acc 54.520
# L 3 Epoch 162 Loss 0.020 Val Acc 53.880
# L 3 Epoch 163 Loss 0.019 Val Acc 54.560
# L 3 Epoch 164 Loss 0.014 Val Acc 54.400
# L 3 Epoch 165 Loss 0.017 Val Acc 53.580
# L 3 Epoch 166 Loss 0.009 Val Acc 54.240
# L 3 Epoch 167 Loss 0.010 Val Acc 54.820
# L 3 Epoch 168 Loss 0.017 Val Acc 54.040
# L 3 Epoch 169 Loss 0.011 Val Acc 54.160
# L 3 Epoch 170 Loss 0.013 Val Acc 54.240
# L 3 Epoch 171 Loss 0.014 Val Acc 54.320
# L 3 Epoch 172 Loss 0.022 Val Acc 54.260
# L 3 Epoch 173 Loss 0.015 Val Acc 53.820
# L 3 Epoch 174 Loss 0.014 Val Acc 54.120
# L 3 Epoch 175 Loss 0.020 Val Acc 53.140
# L 3 Epoch 176 Loss 0.019 Val Acc 53.700
# L 3 Epoch 177 Loss 0.011 Val Acc 53.200
# L 3 Epoch 178 Loss 0.020 Val Acc 52.740
# L 3 Epoch 179 Loss 0.013 Val Acc 52.960
# L 3 Epoch 180 Loss 0.020 Val Acc 52.460
# L 3 Epoch 181 Loss 0.012 Val Acc 54.080
# L 3 Epoch 182 Loss 0.004 Val Acc 54.820
# L 3 Epoch 183 Loss 0.018 Val Acc 54.200
# L 3 Epoch 184 Loss 0.018 Val Acc 54.180
# L 3 Epoch 185 Loss 0.011 Val Acc 53.940
# L 3 Epoch 186 Loss 0.013 Val Acc 54.880
# L 3 Epoch 187 Loss 0.014 Val Acc 54.480
# L 3 Epoch 188 Loss 0.013 Val Acc 54.440
# L 3 Epoch 189 Loss 0.012 Val Acc 54.320
# L 3 Epoch 190 Loss 0.017 Val Acc 53.680
# L 3 Epoch 191 Loss 0.010 Val Acc 53.940
# L 3 Epoch 192 Loss 0.019 Val Acc 54.400
# L 3 Epoch 193 Loss 0.012 Val Acc 53.700
# L 3 Epoch 194 Loss 0.010 Val Acc 54.620
# L 3 Epoch 195 Loss 0.010 Val Acc 54.520
# L 3 Epoch 196 Loss 0.006 Val Acc 55.080
# L 3 Epoch 197 Loss 0.014 Val Acc 54.680
# L 3 Epoch 198 Loss 0.010 Val Acc 54.540
# L 3 Epoch 199 Loss 0.015 Val Acc 53.540
# L 4 Epoch 0 Loss 3.082 Val Acc 10.000
# L 4 Epoch 1 Loss 2.801 Val Acc 9.700
# L 4 Epoch 2 Loss 2.261 Val Acc 12.380
# L 4 Epoch 3 Loss 2.018 Val Acc 14.380
# L 4 Epoch 4 Loss 1.990 Val Acc 26.060
# L 4 Epoch 5 Loss 1.797 Val Acc 29.060
# L 4 Epoch 6 Loss 1.777 Val Acc 30.640
# L 4 Epoch 7 Loss 1.761 Val Acc 30.640
# L 4 Epoch 8 Loss 1.643 Val Acc 35.300
# L 4 Epoch 9 Loss 1.598 Val Acc 34.400
# L 4 Epoch 10 Loss 1.579 Val Acc 38.420
# L 4 Epoch 11 Loss 1.524 Val Acc 38.260
# L 4 Epoch 12 Loss 1.437 Val Acc 36.480
# L 4 Epoch 13 Loss 1.509 Val Acc 39.040
# L 4 Epoch 14 Loss 1.429 Val Acc 39.120
# ==> Saving model ...
# L 4 Epoch 15 Loss 1.369 Val Acc 43.480
# L 4 Epoch 16 Loss 1.344 Val Acc 38.220
# L 4 Epoch 17 Loss 1.289 Val Acc 39.840
# L 4 Epoch 18 Loss 1.312 Val Acc 41.720
# ==> Saving model ...
# L 4 Epoch 19 Loss 1.246 Val Acc 45.480
# ==> Saving model ...
# L 4 Epoch 20 Loss 1.134 Val Acc 48.240
# L 4 Epoch 21 Loss 1.070 Val Acc 45.880
# ==> Saving model ...
# L 4 Epoch 22 Loss 1.056 Val Acc 49.620
# L 4 Epoch 23 Loss 0.982 Val Acc 47.220
# L 4 Epoch 24 Loss 0.881 Val Acc 47.060
# L 4 Epoch 25 Loss 0.869 Val Acc 49.120
# L 4 Epoch 26 Loss 0.931 Val Acc 48.000
# ==> Saving model ...
# L 4 Epoch 27 Loss 0.883 Val Acc 50.000
# ==> Saving model ...
# L 4 Epoch 28 Loss 0.758 Val Acc 51.600
# L 4 Epoch 29 Loss 0.708 Val Acc 48.760
# L 4 Epoch 30 Loss 0.850 Val Acc 47.840
# L 4 Epoch 31 Loss 0.748 Val Acc 47.500
# L 4 Epoch 32 Loss 0.617 Val Acc 48.960
# L 4 Epoch 33 Loss 0.548 Val Acc 35.900
# L 4 Epoch 34 Loss 0.737 Val Acc 44.960
# L 4 Epoch 35 Loss 0.598 Val Acc 49.660
# L 4 Epoch 36 Loss 0.632 Val Acc 47.780
# L 4 Epoch 37 Loss 0.551 Val Acc 47.120
# L 4 Epoch 38 Loss 0.567 Val Acc 49.700
# L 4 Epoch 39 Loss 0.557 Val Acc 45.780
# ==> Saving model ...
# L 4 Epoch 40 Loss 0.396 Val Acc 53.280
# L 4 Epoch 41 Loss 0.443 Val Acc 48.980
# ==> Saving model ...
# L 4 Epoch 42 Loss 0.327 Val Acc 53.660
# ==> Saving model ...
# L 4 Epoch 43 Loss 0.247 Val Acc 54.280
# L 4 Epoch 44 Loss 0.302 Val Acc 52.580
# L 4 Epoch 45 Loss 0.332 Val Acc 51.520
# L 4 Epoch 46 Loss 0.342 Val Acc 49.840
# L 4 Epoch 47 Loss 0.285 Val Acc 51.340
# L 4 Epoch 48 Loss 0.342 Val Acc 53.340
# L 4 Epoch 49 Loss 0.313 Val Acc 52.200
# ==> Saving model ...
# L 4 Epoch 50 Loss 0.301 Val Acc 54.760
# L 4 Epoch 51 Loss 0.265 Val Acc 46.800
# L 4 Epoch 52 Loss 0.308 Val Acc 49.200
# L 4 Epoch 53 Loss 0.352 Val Acc 52.880
# L 4 Epoch 54 Loss 0.202 Val Acc 54.660
# L 4 Epoch 55 Loss 0.170 Val Acc 54.240
# L 4 Epoch 56 Loss 0.267 Val Acc 53.280
# L 4 Epoch 57 Loss 0.176 Val Acc 51.760
# ==> Saving model ...
# L 4 Epoch 58 Loss 0.209 Val Acc 55.520
# L 4 Epoch 59 Loss 0.132 Val Acc 55.260
# L 4 Epoch 60 Loss 0.165 Val Acc 55.320
# L 4 Epoch 61 Loss 0.195 Val Acc 54.400
# L 4 Epoch 62 Loss 0.164 Val Acc 53.240
# L 4 Epoch 63 Loss 0.198 Val Acc 55.000
# L 4 Epoch 64 Loss 0.163 Val Acc 55.160
# ==> Saving model ...
# L 4 Epoch 65 Loss 0.103 Val Acc 56.500
# L 4 Epoch 66 Loss 0.152 Val Acc 55.040
# L 4 Epoch 67 Loss 0.135 Val Acc 54.840
# L 4 Epoch 68 Loss 0.135 Val Acc 52.980
# L 4 Epoch 69 Loss 0.128 Val Acc 53.740
# L 4 Epoch 70 Loss 0.163 Val Acc 56.220
# L 4 Epoch 71 Loss 0.223 Val Acc 54.180
# L 4 Epoch 72 Loss 0.092 Val Acc 54.800
# L 4 Epoch 73 Loss 0.154 Val Acc 56.160
# ==> Saving model ...
# L 4 Epoch 74 Loss 0.081 Val Acc 56.960
# L 4 Epoch 75 Loss 0.100 Val Acc 56.520
# L 4 Epoch 76 Loss 0.139 Val Acc 56.500
# L 4 Epoch 77 Loss 0.141 Val Acc 54.200
# L 4 Epoch 78 Loss 0.158 Val Acc 54.640
# L 4 Epoch 79 Loss 0.088 Val Acc 54.640
# L 4 Epoch 80 Loss 0.086 Val Acc 56.100
# L 4 Epoch 81 Loss 0.112 Val Acc 56.160
# ==> Saving model ...
# L 4 Epoch 82 Loss 0.092 Val Acc 57.140
# L 4 Epoch 83 Loss 0.081 Val Acc 56.440
# L 4 Epoch 84 Loss 0.043 Val Acc 56.460
# L 4 Epoch 85 Loss 0.067 Val Acc 56.980
# ==> Saving model ...
# L 4 Epoch 86 Loss 0.045 Val Acc 58.100
# L 4 Epoch 87 Loss 0.052 Val Acc 57.300
# L 4 Epoch 88 Loss 0.062 Val Acc 57.440
# L 4 Epoch 89 Loss 0.050 Val Acc 57.380
# L 4 Epoch 90 Loss 0.042 Val Acc 57.360
# L 4 Epoch 91 Loss 0.044 Val Acc 57.660
# L 4 Epoch 92 Loss 0.050 Val Acc 57.760
# L 4 Epoch 93 Loss 0.057 Val Acc 56.820
# L 4 Epoch 94 Loss 0.061 Val Acc 57.500
# L 4 Epoch 95 Loss 0.027 Val Acc 57.960
# L 4 Epoch 96 Loss 0.073 Val Acc 57.880
# ==> Saving model ...
# L 4 Epoch 97 Loss 0.047 Val Acc 58.260
# ==> Saving model ...
# L 4 Epoch 98 Loss 0.031 Val Acc 58.320
# ==> Saving model ...
# L 4 Epoch 99 Loss 0.025 Val Acc 58.500
# L 4 Epoch 100 Loss 0.044 Val Acc 56.820
# L 4 Epoch 101 Loss 0.051 Val Acc 56.440
# L 4 Epoch 102 Loss 0.084 Val Acc 56.920
# L 4 Epoch 103 Loss 0.044 Val Acc 56.060
# L 4 Epoch 104 Loss 0.061 Val Acc 57.080
# L 4 Epoch 105 Loss 0.023 Val Acc 56.860
# L 4 Epoch 106 Loss 0.020 Val Acc 57.640
# L 4 Epoch 107 Loss 0.050 Val Acc 58.400
# ==> Saving model ...
# L 4 Epoch 108 Loss 0.044 Val Acc 58.640
# L 4 Epoch 109 Loss 0.057 Val Acc 57.980
# L 4 Epoch 110 Loss 0.065 Val Acc 56.660
# L 4 Epoch 111 Loss 0.047 Val Acc 56.800
# L 4 Epoch 112 Loss 0.055 Val Acc 55.720
# L 4 Epoch 113 Loss 0.053 Val Acc 57.520
# L 4 Epoch 114 Loss 0.010 Val Acc 58.160
# L 4 Epoch 115 Loss 0.016 Val Acc 58.440
# L 4 Epoch 116 Loss 0.028 Val Acc 58.020
# L 4 Epoch 117 Loss 0.012 Val Acc 57.800
# ==> Saving model ...
# L 4 Epoch 118 Loss 0.016 Val Acc 58.740
# ==> Saving model ...
# L 4 Epoch 119 Loss 0.025 Val Acc 58.840
# L 4 Epoch 120 Loss 0.029 Val Acc 58.540
# L 4 Epoch 121 Loss 0.037 Val Acc 57.760
# L 4 Epoch 122 Loss 0.035 Val Acc 57.540
# L 4 Epoch 123 Loss 0.027 Val Acc 58.240
# L 4 Epoch 124 Loss 0.015 Val Acc 58.420
# L 4 Epoch 125 Loss 0.014 Val Acc 58.660
# L 4 Epoch 126 Loss 0.020 Val Acc 58.240
# L 4 Epoch 127 Loss 0.014 Val Acc 58.080
# L 4 Epoch 128 Loss 0.011 Val Acc 58.220
# L 4 Epoch 129 Loss 0.023 Val Acc 58.480
# ==> Saving model ...
# L 4 Epoch 130 Loss 0.008 Val Acc 59.360
# ==> Saving model ...
# L 4 Epoch 131 Loss 0.010 Val Acc 59.800
# L 4 Epoch 132 Loss 0.011 Val Acc 59.620
# L 4 Epoch 133 Loss 0.016 Val Acc 58.720
# L 4 Epoch 134 Loss 0.025 Val Acc 58.380
# L 4 Epoch 135 Loss 0.018 Val Acc 58.200
# L 4 Epoch 136 Loss 0.010 Val Acc 58.600
# L 4 Epoch 137 Loss 0.024 Val Acc 58.480
# L 4 Epoch 138 Loss 0.010 Val Acc 59.320
# L 4 Epoch 139 Loss 0.005 Val Acc 59.280
# L 4 Epoch 140 Loss 0.010 Val Acc 59.460
# L 4 Epoch 141 Loss 0.014 Val Acc 59.360
# L 4 Epoch 142 Loss 0.026 Val Acc 59.600
# L 4 Epoch 143 Loss 0.007 Val Acc 59.680
# L 4 Epoch 144 Loss 0.019 Val Acc 59.320
# L 4 Epoch 145 Loss 0.009 Val Acc 59.100
# L 4 Epoch 146 Loss 0.003 Val Acc 59.420
# L 4 Epoch 147 Loss 0.009 Val Acc 59.080
# L 4 Epoch 148 Loss 0.013 Val Acc 59.160
# L 4 Epoch 149 Loss 0.014 Val Acc 59.380
# L 4 Epoch 150 Loss 0.005 Val Acc 59.600
# ==> Saving model ...
# L 4 Epoch 151 Loss 0.005 Val Acc 59.840
# ==> Saving model ...
# L 4 Epoch 152 Loss 0.008 Val Acc 60.040
# L 4 Epoch 153 Loss 0.013 Val Acc 59.580
# L 4 Epoch 154 Loss 0.007 Val Acc 59.420
# L 4 Epoch 155 Loss 0.009 Val Acc 59.540
# L 4 Epoch 156 Loss 0.007 Val Acc 59.600
# L 4 Epoch 157 Loss 0.009 Val Acc 59.480
# L 4 Epoch 158 Loss 0.011 Val Acc 59.240
# L 4 Epoch 159 Loss 0.002 Val Acc 59.380
# L 4 Epoch 160 Loss 0.005 Val Acc 59.500
# L 4 Epoch 161 Loss 0.004 Val Acc 59.680
# L 4 Epoch 162 Loss 0.008 Val Acc 59.640
# L 4 Epoch 163 Loss 0.017 Val Acc 59.380
# L 4 Epoch 164 Loss 0.015 Val Acc 59.400
# L 4 Epoch 165 Loss 0.004 Val Acc 59.740
# L 4 Epoch 166 Loss 0.004 Val Acc 60.000
# L 4 Epoch 167 Loss 0.004 Val Acc 59.880
# L 4 Epoch 168 Loss 0.011 Val Acc 59.580
# L 4 Epoch 169 Loss 0.005 Val Acc 59.940
# L 4 Epoch 170 Loss 0.024 Val Acc 59.220
# L 4 Epoch 171 Loss 0.008 Val Acc 59.820
# L 4 Epoch 172 Loss 0.008 Val Acc 59.960
# ==> Saving model ...
# L 4 Epoch 173 Loss 0.006 Val Acc 60.080
# L 4 Epoch 174 Loss 0.005 Val Acc 59.800
# L 4 Epoch 175 Loss 0.008 Val Acc 59.960
# L 4 Epoch 176 Loss 0.007 Val Acc 59.840
# L 4 Epoch 177 Loss 0.006 Val Acc 60.040
# L 4 Epoch 178 Loss 0.008 Val Acc 59.880
# L 4 Epoch 179 Loss 0.002 Val Acc 60.020
# ==> Saving model ...
# L 4 Epoch 180 Loss 0.005 Val Acc 60.280
# ==> Saving model ...
# L 4 Epoch 181 Loss 0.003 Val Acc 60.300
# L 4 Epoch 182 Loss 0.014 Val Acc 60.040
# L 4 Epoch 183 Loss 0.002 Val Acc 60.140
# L 4 Epoch 184 Loss 0.013 Val Acc 59.820
# L 4 Epoch 185 Loss 0.008 Val Acc 59.860
# L 4 Epoch 186 Loss 0.005 Val Acc 60.000
# L 4 Epoch 187 Loss 0.008 Val Acc 59.880
# L 4 Epoch 188 Loss 0.011 Val Acc 59.780
# L 4 Epoch 189 Loss 0.013 Val Acc 59.680
# L 4 Epoch 190 Loss 0.005 Val Acc 59.840
# L 4 Epoch 191 Loss 0.005 Val Acc 59.900
# L 4 Epoch 192 Loss 0.007 Val Acc 60.040
# L 4 Epoch 193 Loss 0.010 Val Acc 59.860
# L 4 Epoch 194 Loss 0.005 Val Acc 60.000
# L 4 Epoch 195 Loss 0.009 Val Acc 59.940
# L 4 Epoch 196 Loss 0.004 Val Acc 60.060
# L 4 Epoch 197 Loss 0.005 Val Acc 59.980
# L 4 Epoch 198 Loss 0.005 Val Acc 60.160
# L 4 Epoch 199 Loss 0.006 Val Acc 59.960
# L 5 Epoch 0 Loss 3.892 Val Acc 10.000
# L 5 Epoch 1 Loss 2.818 Val Acc 8.960
# L 5 Epoch 2 Loss 2.356 Val Acc 15.420
# L 5 Epoch 3 Loss 2.084 Val Acc 18.180
# L 5 Epoch 4 Loss 2.051 Val Acc 23.320
# L 5 Epoch 5 Loss 2.024 Val Acc 19.260
# L 5 Epoch 6 Loss 1.850 Val Acc 25.100
# L 5 Epoch 7 Loss 1.792 Val Acc 29.820
# L 5 Epoch 8 Loss 1.725 Val Acc 32.760
# L 5 Epoch 9 Loss 1.651 Val Acc 35.540
# L 5 Epoch 10 Loss 1.628 Val Acc 35.260
# L 5 Epoch 11 Loss 1.590 Val Acc 35.080
# L 5 Epoch 12 Loss 1.551 Val Acc 38.840
# L 5 Epoch 13 Loss 1.546 Val Acc 38.280
# L 5 Epoch 14 Loss 1.484 Val Acc 36.560
# L 5 Epoch 15 Loss 1.456 Val Acc 38.060
# L 5 Epoch 16 Loss 1.484 Val Acc 38.640
# L 5 Epoch 17 Loss 1.335 Val Acc 38.720
# ==> Saving model ...
# L 5 Epoch 18 Loss 1.332 Val Acc 44.220
# L 5 Epoch 19 Loss 1.327 Val Acc 42.140
# L 5 Epoch 20 Loss 1.304 Val Acc 40.320
# L 5 Epoch 21 Loss 1.330 Val Acc 41.600
# L 5 Epoch 22 Loss 1.217 Val Acc 43.200
# L 5 Epoch 23 Loss 1.100 Val Acc 43.600
# L 5 Epoch 24 Loss 1.057 Val Acc 44.000
# L 5 Epoch 25 Loss 1.054 Val Acc 42.720
# L 5 Epoch 26 Loss 1.106 Val Acc 36.560
# ==> Saving model ...
# L 5 Epoch 27 Loss 0.998 Val Acc 45.440
# L 5 Epoch 28 Loss 1.017 Val Acc 40.060
# L 5 Epoch 29 Loss 1.066 Val Acc 41.560
# L 5 Epoch 30 Loss 0.867 Val Acc 43.040
# L 5 Epoch 31 Loss 0.854 Val Acc 42.740
# L 5 Epoch 32 Loss 0.948 Val Acc 43.280
# ==> Saving model ...
# L 5 Epoch 33 Loss 0.758 Val Acc 47.880
# L 5 Epoch 34 Loss 0.731 Val Acc 44.920
# L 5 Epoch 35 Loss 0.775 Val Acc 42.320
# L 5 Epoch 36 Loss 0.774 Val Acc 44.680
# L 5 Epoch 37 Loss 0.737 Val Acc 46.520
# L 5 Epoch 38 Loss 0.695 Val Acc 45.740
# L 5 Epoch 39 Loss 0.481 Val Acc 47.580
# ==> Saving model ...
# L 5 Epoch 40 Loss 0.514 Val Acc 49.360
# L 5 Epoch 41 Loss 0.653 Val Acc 44.040
# L 5 Epoch 42 Loss 0.522 Val Acc 47.420
# ==> Saving model ...
# L 5 Epoch 43 Loss 0.457 Val Acc 50.160
# L 5 Epoch 44 Loss 0.392 Val Acc 49.540
# L 5 Epoch 45 Loss 0.430 Val Acc 48.880
# L 5 Epoch 46 Loss 0.317 Val Acc 47.300
# ==> Saving model ...
# L 5 Epoch 47 Loss 0.325 Val Acc 50.260
# L 5 Epoch 48 Loss 0.325 Val Acc 48.480
# L 5 Epoch 49 Loss 0.372 Val Acc 49.080
# L 5 Epoch 50 Loss 0.390 Val Acc 48.780
# L 5 Epoch 51 Loss 0.340 Val Acc 48.460
# L 5 Epoch 52 Loss 0.377 Val Acc 48.760
# ==> Saving model ...
# L 5 Epoch 53 Loss 0.264 Val Acc 51.580
# L 5 Epoch 54 Loss 0.318 Val Acc 48.160
# L 5 Epoch 55 Loss 0.304 Val Acc 48.600
# L 5 Epoch 56 Loss 0.324 Val Acc 49.400
# L 5 Epoch 57 Loss 0.260 Val Acc 48.080
# L 5 Epoch 58 Loss 0.311 Val Acc 47.200
# L 5 Epoch 59 Loss 0.277 Val Acc 49.280
# L 5 Epoch 60 Loss 0.262 Val Acc 49.760
# L 5 Epoch 61 Loss 0.293 Val Acc 50.500
# L 5 Epoch 62 Loss 0.200 Val Acc 50.400
# L 5 Epoch 63 Loss 0.365 Val Acc 49.540
# L 5 Epoch 64 Loss 0.250 Val Acc 46.300
# L 5 Epoch 65 Loss 0.225 Val Acc 48.640
# L 5 Epoch 66 Loss 0.276 Val Acc 49.000
# L 5 Epoch 67 Loss 0.215 Val Acc 50.640
# L 5 Epoch 68 Loss 0.134 Val Acc 50.260
# ==> Saving model ...
# L 5 Epoch 69 Loss 0.141 Val Acc 52.480
# ==> Saving model ...
# L 5 Epoch 70 Loss 0.105 Val Acc 52.500
# ==> Saving model ...
# L 5 Epoch 71 Loss 0.074 Val Acc 52.600
# L 5 Epoch 72 Loss 0.131 Val Acc 52.280
# L 5 Epoch 73 Loss 0.090 Val Acc 51.720
# ==> Saving model ...
# L 5 Epoch 74 Loss 0.049 Val Acc 52.700
# ==> Saving model ...
# L 5 Epoch 75 Loss 0.116 Val Acc 52.760
# ==> Saving model ...
# L 5 Epoch 76 Loss 0.140 Val Acc 52.800
# L 5 Epoch 77 Loss 0.095 Val Acc 52.540
# L 5 Epoch 78 Loss 0.089 Val Acc 52.100
# L 5 Epoch 79 Loss 0.150 Val Acc 51.900
# L 5 Epoch 80 Loss 0.084 Val Acc 51.580
# L 5 Epoch 81 Loss 0.114 Val Acc 51.160
# L 5 Epoch 82 Loss 0.062 Val Acc 49.020
# L 5 Epoch 83 Loss 0.111 Val Acc 49.480
# L 5 Epoch 84 Loss 0.151 Val Acc 52.640
# ==> Saving model ...
# L 5 Epoch 85 Loss 0.099 Val Acc 53.440
# L 5 Epoch 86 Loss 0.116 Val Acc 52.400
# L 5 Epoch 87 Loss 0.127 Val Acc 51.300
# L 5 Epoch 88 Loss 0.115 Val Acc 49.120
# L 5 Epoch 89 Loss 0.086 Val Acc 52.120
# L 5 Epoch 90 Loss 0.088 Val Acc 52.440
# L 5 Epoch 91 Loss 0.033 Val Acc 52.900
# ==> Saving model ...
# L 5 Epoch 92 Loss 0.074 Val Acc 53.840
# L 5 Epoch 93 Loss 0.091 Val Acc 51.820
# L 5 Epoch 94 Loss 0.052 Val Acc 51.620
# L 5 Epoch 95 Loss 0.101 Val Acc 51.740
# L 5 Epoch 96 Loss 0.057 Val Acc 52.880
# L 5 Epoch 97 Loss 0.089 Val Acc 52.060
# L 5 Epoch 98 Loss 0.053 Val Acc 51.960
# L 5 Epoch 99 Loss 0.120 Val Acc 50.900
# L 5 Epoch 100 Loss 0.093 Val Acc 49.580
# L 5 Epoch 101 Loss 0.088 Val Acc 50.720
# L 5 Epoch 102 Loss 0.049 Val Acc 52.280
# L 5 Epoch 103 Loss 0.052 Val Acc 51.500
# L 5 Epoch 104 Loss 0.057 Val Acc 52.940
# L 5 Epoch 105 Loss 0.056 Val Acc 52.180
# L 5 Epoch 106 Loss 0.063 Val Acc 51.840
# L 5 Epoch 107 Loss 0.070 Val Acc 51.760
# L 5 Epoch 108 Loss 0.042 Val Acc 51.820
# L 5 Epoch 109 Loss 0.042 Val Acc 53.360
# L 5 Epoch 110 Loss 0.045 Val Acc 52.440
# L 5 Epoch 111 Loss 0.019 Val Acc 52.000
# L 5 Epoch 112 Loss 0.039 Val Acc 52.840
# L 5 Epoch 113 Loss 0.031 Val Acc 53.780
# L 5 Epoch 114 Loss 0.027 Val Acc 52.700
# L 5 Epoch 115 Loss 0.047 Val Acc 51.840
# L 5 Epoch 116 Loss 0.022 Val Acc 52.460
# L 5 Epoch 117 Loss 0.036 Val Acc 52.420
# L 5 Epoch 118 Loss 0.010 Val Acc 52.500
# L 5 Epoch 119 Loss 0.029 Val Acc 53.000
# L 5 Epoch 120 Loss 0.047 Val Acc 52.320
# L 5 Epoch 121 Loss 0.048 Val Acc 53.400
# L 5 Epoch 122 Loss 0.050 Val Acc 53.440
# L 5 Epoch 123 Loss 0.021 Val Acc 52.980
# L 5 Epoch 124 Loss 0.018 Val Acc 53.340
# L 5 Epoch 125 Loss 0.028 Val Acc 53.100
# L 5 Epoch 126 Loss 0.036 Val Acc 53.100
# L 5 Epoch 127 Loss 0.021 Val Acc 53.460
# L 5 Epoch 128 Loss 0.020 Val Acc 53.040
# L 5 Epoch 129 Loss 0.013 Val Acc 53.820
# ==> Saving model ...
# L 5 Epoch 130 Loss 0.010 Val Acc 54.320
# L 5 Epoch 131 Loss 0.040 Val Acc 53.840
# L 5 Epoch 132 Loss 0.035 Val Acc 53.600
# L 5 Epoch 133 Loss 0.028 Val Acc 53.820
# L 5 Epoch 134 Loss 0.020 Val Acc 53.660
# L 5 Epoch 135 Loss 0.030 Val Acc 53.440
# L 5 Epoch 136 Loss 0.030 Val Acc 53.780
# L 5 Epoch 137 Loss 0.021 Val Acc 53.360
# L 5 Epoch 138 Loss 0.018 Val Acc 53.080
# L 5 Epoch 139 Loss 0.024 Val Acc 52.660
# L 5 Epoch 140 Loss 0.020 Val Acc 53.080
# L 5 Epoch 141 Loss 0.023 Val Acc 53.740
# L 5 Epoch 142 Loss 0.008 Val Acc 53.780
# L 5 Epoch 143 Loss 0.023 Val Acc 53.540
# L 5 Epoch 144 Loss 0.021 Val Acc 53.740
# L 5 Epoch 145 Loss 0.008 Val Acc 54.120
# L 5 Epoch 146 Loss 0.006 Val Acc 54.260
# L 5 Epoch 147 Loss 0.013 Val Acc 54.320
# L 5 Epoch 148 Loss 0.013 Val Acc 54.140
# L 5 Epoch 149 Loss 0.020 Val Acc 53.300
# L 5 Epoch 150 Loss 0.017 Val Acc 53.620
# L 5 Epoch 151 Loss 0.029 Val Acc 53.480
# L 5 Epoch 152 Loss 0.014 Val Acc 53.580
# L 5 Epoch 153 Loss 0.029 Val Acc 53.580
# L 5 Epoch 154 Loss 0.015 Val Acc 53.880
# L 5 Epoch 155 Loss 0.027 Val Acc 54.200
# ==> Saving model ...
# L 5 Epoch 156 Loss 0.007 Val Acc 54.520
# ==> Saving model ...
# L 5 Epoch 157 Loss 0.011 Val Acc 54.580
# L 5 Epoch 158 Loss 0.013 Val Acc 54.480
# ==> Saving model ...
# L 5 Epoch 159 Loss 0.003 Val Acc 54.940
# L 5 Epoch 160 Loss 0.016 Val Acc 54.660
# L 5 Epoch 161 Loss 0.009 Val Acc 54.580
# L 5 Epoch 162 Loss 0.017 Val Acc 54.540
# L 5 Epoch 163 Loss 0.014 Val Acc 54.800
# L 5 Epoch 164 Loss 0.010 Val Acc 54.600
# L 5 Epoch 165 Loss 0.018 Val Acc 54.200
# L 5 Epoch 166 Loss 0.006 Val Acc 54.320
# L 5 Epoch 167 Loss 0.010 Val Acc 54.360
# L 5 Epoch 168 Loss 0.011 Val Acc 54.440
# L 5 Epoch 169 Loss 0.016 Val Acc 54.380
# L 5 Epoch 170 Loss 0.009 Val Acc 54.180
# L 5 Epoch 171 Loss 0.013 Val Acc 53.260
# L 5 Epoch 172 Loss 0.010 Val Acc 54.080
# L 5 Epoch 173 Loss 0.009 Val Acc 53.740
# L 5 Epoch 174 Loss 0.013 Val Acc 53.740
# L 5 Epoch 175 Loss 0.020 Val Acc 54.000
# L 5 Epoch 176 Loss 0.009 Val Acc 54.200
# L 5 Epoch 177 Loss 0.019 Val Acc 53.120
# L 5 Epoch 178 Loss 0.011 Val Acc 53.840
# L 5 Epoch 179 Loss 0.008 Val Acc 54.580
# L 5 Epoch 180 Loss 0.007 Val Acc 54.540
# L 5 Epoch 181 Loss 0.019 Val Acc 54.460
# L 5 Epoch 182 Loss 0.005 Val Acc 54.760
# L 5 Epoch 183 Loss 0.015 Val Acc 54.860
# L 5 Epoch 184 Loss 0.006 Val Acc 54.780
# L 5 Epoch 185 Loss 0.017 Val Acc 54.240
# L 5 Epoch 186 Loss 0.009 Val Acc 54.240
# L 5 Epoch 187 Loss 0.009 Val Acc 54.460
# L 5 Epoch 188 Loss 0.016 Val Acc 53.480
# L 5 Epoch 189 Loss 0.006 Val Acc 54.160
# L 5 Epoch 190 Loss 0.009 Val Acc 54.180
# L 5 Epoch 191 Loss 0.019 Val Acc 54.160
# L 5 Epoch 192 Loss 0.001 Val Acc 54.940
# L 5 Epoch 193 Loss 0.009 Val Acc 54.760
# L 5 Epoch 194 Loss 0.023 Val Acc 54.340
# L 5 Epoch 195 Loss 0.028 Val Acc 54.260
# L 5 Epoch 196 Loss 0.025 Val Acc 54.220
# L 5 Epoch 197 Loss 0.011 Val Acc 54.380
# L 5 Epoch 198 Loss 0.006 Val Acc 54.240
# L 5 Epoch 199 Loss 0.014 Val Acc 53.540
# L 6 Epoch 0 Loss 3.911 Val Acc 10.000
# L 6 Epoch 1 Loss 3.211 Val Acc 10.000
# L 6 Epoch 2 Loss 2.731 Val Acc 10.020
# L 6 Epoch 3 Loss 2.328 Val Acc 14.520
# L 6 Epoch 4 Loss 2.031 Val Acc 20.180
# L 6 Epoch 5 Loss 1.947 Val Acc 25.180
# L 6 Epoch 6 Loss 1.893 Val Acc 26.600
# L 6 Epoch 7 Loss 1.773 Val Acc 32.640
# L 6 Epoch 8 Loss 1.748 Val Acc 30.420
# L 6 Epoch 9 Loss 1.727 Val Acc 34.040
# L 6 Epoch 10 Loss 1.624 Val Acc 37.100
# L 6 Epoch 11 Loss 1.585 Val Acc 38.180
# L 6 Epoch 12 Loss 1.583 Val Acc 38.260
# L 6 Epoch 13 Loss 1.557 Val Acc 39.040
# L 6 Epoch 14 Loss 1.557 Val Acc 36.300
# L 6 Epoch 15 Loss 1.451 Val Acc 39.260
# ==> Saving model ...
# L 6 Epoch 16 Loss 1.366 Val Acc 40.540
# ==> Saving model ...
# L 6 Epoch 17 Loss 1.358 Val Acc 41.240
# ==> Saving model ...
# L 6 Epoch 18 Loss 1.323 Val Acc 41.260
# ==> Saving model ...
# L 6 Epoch 19 Loss 1.338 Val Acc 41.460
# ==> Saving model ...
# L 6 Epoch 20 Loss 1.320 Val Acc 41.640
# ==> Saving model ...
# L 6 Epoch 21 Loss 1.287 Val Acc 42.040
# ==> Saving model ...
# L 6 Epoch 22 Loss 1.161 Val Acc 45.120
# L 6 Epoch 23 Loss 1.172 Val Acc 39.760
# L 6 Epoch 24 Loss 1.095 Val Acc 39.080
# L 6 Epoch 25 Loss 1.086 Val Acc 44.340
# L 6 Epoch 26 Loss 1.005 Val Acc 44.540
# L 6 Epoch 27 Loss 1.009 Val Acc 43.440
# L 6 Epoch 28 Loss 0.887 Val Acc 43.620
# ==> Saving model ...
# L 6 Epoch 29 Loss 0.944 Val Acc 45.860
# L 6 Epoch 30 Loss 0.935 Val Acc 40.180
# L 6 Epoch 31 Loss 0.921 Val Acc 44.500
# L 6 Epoch 32 Loss 0.885 Val Acc 44.900
# ==> Saving model ...
# L 6 Epoch 33 Loss 0.897 Val Acc 46.020
# L 6 Epoch 34 Loss 0.764 Val Acc 45.360
# ==> Saving model ...
# L 6 Epoch 35 Loss 0.815 Val Acc 46.580
# L 6 Epoch 36 Loss 0.860 Val Acc 43.660
# L 6 Epoch 37 Loss 0.642 Val Acc 43.600
# L 6 Epoch 38 Loss 0.662 Val Acc 45.840
# ==> Saving model ...
# L 6 Epoch 39 Loss 0.549 Val Acc 48.060
# L 6 Epoch 40 Loss 0.573 Val Acc 46.220
# L 6 Epoch 41 Loss 0.509 Val Acc 46.200
# L 6 Epoch 42 Loss 0.503 Val Acc 44.420
# L 6 Epoch 43 Loss 0.536 Val Acc 45.400
# L 6 Epoch 44 Loss 0.649 Val Acc 46.380
# L 6 Epoch 45 Loss 0.423 Val Acc 47.960
# L 6 Epoch 46 Loss 0.518 Val Acc 47.700
# L 6 Epoch 47 Loss 0.397 Val Acc 46.300
# ==> Saving model ...
# L 6 Epoch 48 Loss 0.376 Val Acc 48.780
# L 6 Epoch 49 Loss 0.509 Val Acc 47.780
# L 6 Epoch 50 Loss 0.444 Val Acc 47.340
# L 6 Epoch 51 Loss 0.532 Val Acc 44.220
# ==> Saving model ...
# L 6 Epoch 52 Loss 0.397 Val Acc 51.140
# L 6 Epoch 53 Loss 0.268 Val Acc 50.040
# L 6 Epoch 54 Loss 0.294 Val Acc 49.560
# L 6 Epoch 55 Loss 0.260 Val Acc 48.820
# L 6 Epoch 56 Loss 0.304 Val Acc 49.880
# L 6 Epoch 57 Loss 0.179 Val Acc 50.560
# L 6 Epoch 58 Loss 0.229 Val Acc 49.400
# L 6 Epoch 59 Loss 0.264 Val Acc 48.900
# L 6 Epoch 60 Loss 0.290 Val Acc 50.160
# L 6 Epoch 61 Loss 0.264 Val Acc 49.500
# L 6 Epoch 62 Loss 0.223 Val Acc 49.900
# L 6 Epoch 63 Loss 0.153 Val Acc 48.080
# L 6 Epoch 64 Loss 0.155 Val Acc 50.440
# L 6 Epoch 65 Loss 0.189 Val Acc 50.560
# L 6 Epoch 66 Loss 0.140 Val Acc 50.520
# L 6 Epoch 67 Loss 0.197 Val Acc 50.340
# L 6 Epoch 68 Loss 0.178 Val Acc 49.400
# L 6 Epoch 69 Loss 0.209 Val Acc 47.540
# ==> Saving model ...
# L 6 Epoch 70 Loss 0.179 Val Acc 51.600
# L 6 Epoch 71 Loss 0.233 Val Acc 47.760
# L 6 Epoch 72 Loss 0.152 Val Acc 50.680
# L 6 Epoch 73 Loss 0.186 Val Acc 49.400
# L 6 Epoch 74 Loss 0.076 Val Acc 49.580
# ==> Saving model ...
# L 6 Epoch 75 Loss 0.164 Val Acc 52.720
# L 6 Epoch 76 Loss 0.147 Val Acc 52.080
# L 6 Epoch 77 Loss 0.162 Val Acc 50.640
# L 6 Epoch 78 Loss 0.104 Val Acc 50.580
# L 6 Epoch 79 Loss 0.094 Val Acc 52.340
# L 6 Epoch 80 Loss 0.103 Val Acc 50.440
# L 6 Epoch 81 Loss 0.106 Val Acc 52.180
# L 6 Epoch 82 Loss 0.084 Val Acc 51.220
# L 6 Epoch 83 Loss 0.187 Val Acc 50.980
# L 6 Epoch 84 Loss 0.177 Val Acc 49.800
# L 6 Epoch 85 Loss 0.168 Val Acc 50.760
# L 6 Epoch 86 Loss 0.151 Val Acc 51.620
# L 6 Epoch 87 Loss 0.078 Val Acc 51.800
# L 6 Epoch 88 Loss 0.063 Val Acc 52.520
# ==> Saving model ...
# L 6 Epoch 89 Loss 0.070 Val Acc 53.120
# L 6 Epoch 90 Loss 0.110 Val Acc 52.520
# L 6 Epoch 91 Loss 0.071 Val Acc 52.940
# ==> Saving model ...
# L 6 Epoch 92 Loss 0.064 Val Acc 53.300
# L 6 Epoch 93 Loss 0.041 Val Acc 51.520
# L 6 Epoch 94 Loss 0.061 Val Acc 51.980
# L 6 Epoch 95 Loss 0.086 Val Acc 52.700
# L 6 Epoch 96 Loss 0.073 Val Acc 51.960
# L 6 Epoch 97 Loss 0.073 Val Acc 52.900
# ==> Saving model ...
# L 6 Epoch 98 Loss 0.041 Val Acc 53.620
# L 6 Epoch 99 Loss 0.055 Val Acc 52.960
# L 6 Epoch 100 Loss 0.058 Val Acc 53.040
# L 6 Epoch 101 Loss 0.086 Val Acc 52.020
# L 6 Epoch 102 Loss 0.039 Val Acc 52.620
# L 6 Epoch 103 Loss 0.063 Val Acc 51.900
# L 6 Epoch 104 Loss 0.046 Val Acc 50.200
# L 6 Epoch 105 Loss 0.052 Val Acc 51.940
# L 6 Epoch 106 Loss 0.035 Val Acc 52.740
# L 6 Epoch 107 Loss 0.059 Val Acc 53.040
# L 6 Epoch 108 Loss 0.053 Val Acc 52.620
# L 6 Epoch 109 Loss 0.032 Val Acc 53.240
# L 6 Epoch 110 Loss 0.038 Val Acc 53.040
# L 6 Epoch 111 Loss 0.043 Val Acc 53.200
# ==> Saving model ...
# L 6 Epoch 112 Loss 0.032 Val Acc 54.460
# ==> Saving model ...
# L 6 Epoch 113 Loss 0.026 Val Acc 54.540
# L 6 Epoch 114 Loss 0.045 Val Acc 53.800
# L 6 Epoch 115 Loss 0.025 Val Acc 52.700
# L 6 Epoch 116 Loss 0.040 Val Acc 52.680
# L 6 Epoch 117 Loss 0.028 Val Acc 53.760
# L 6 Epoch 118 Loss 0.038 Val Acc 53.860
# L 6 Epoch 119 Loss 0.021 Val Acc 53.480
# L 6 Epoch 120 Loss 0.027 Val Acc 53.800
# L 6 Epoch 121 Loss 0.027 Val Acc 54.000
# L 6 Epoch 122 Loss 0.018 Val Acc 54.360
# ==> Saving model ...
# L 6 Epoch 123 Loss 0.010 Val Acc 54.600
# ==> Saving model ...
# L 6 Epoch 124 Loss 0.018 Val Acc 55.180
# L 6 Epoch 125 Loss 0.023 Val Acc 54.740
# L 6 Epoch 126 Loss 0.033 Val Acc 54.160
# L 6 Epoch 127 Loss 0.027 Val Acc 54.700
# L 6 Epoch 128 Loss 0.034 Val Acc 54.100
# L 6 Epoch 129 Loss 0.029 Val Acc 53.640
# L 6 Epoch 130 Loss 0.018 Val Acc 54.200
# L 6 Epoch 131 Loss 0.020 Val Acc 54.420
# L 6 Epoch 132 Loss 0.025 Val Acc 54.480
# L 6 Epoch 133 Loss 0.040 Val Acc 54.440
# L 6 Epoch 134 Loss 0.028 Val Acc 53.820
# L 6 Epoch 135 Loss 0.022 Val Acc 53.420
# L 6 Epoch 136 Loss 0.021 Val Acc 53.560
# L 6 Epoch 137 Loss 0.010 Val Acc 53.820
# L 6 Epoch 138 Loss 0.013 Val Acc 53.940
# L 6 Epoch 139 Loss 0.007 Val Acc 54.360
# L 6 Epoch 140 Loss 0.013 Val Acc 54.600
# L 6 Epoch 141 Loss 0.023 Val Acc 54.320
# L 6 Epoch 142 Loss 0.013 Val Acc 54.620
# L 6 Epoch 143 Loss 0.007 Val Acc 54.740
# L 6 Epoch 144 Loss 0.018 Val Acc 54.760
# L 6 Epoch 145 Loss 0.014 Val Acc 54.820
# ...
# L 19 Epoch 33 Loss 0.888 Val Acc 46.780
# ==> Saving model ...
# L 19 Epoch 34 Loss 0.918 Val Acc 47.580
# ==> Saving model ...
# L 19 Epoch 35 Loss 0.894 Val Acc 48.180
# L 19 Epoch 36 Loss 0.839 Val Acc 46.780
# L 19 Epoch 37 Loss 0.791 Val Acc 42.080
# L 19 Epoch 38 Loss 0.839 Val Acc 46.580
# L 19 Epoch 39 Loss 0.856 Val Acc 46.300
# L 19 Epoch 40 Loss 0.731 Val Acc 44.780
# ==> Saving model ...
# L 19 Epoch 41 Loss 0.738 Val Acc 48.340
# L 19 Epoch 42 Loss 0.776 Val Acc 46.420
# ==> Saving model ...
# L 19 Epoch 43 Loss 0.644 Val Acc 49.460
# L 19 Epoch 44 Loss 0.576 Val Acc 47.380
# L 19 Epoch 45 Loss 0.603 Val Acc 48.940
# L 19 Epoch 46 Loss 0.590 Val Acc 48.820
# L 19 Epoch 47 Loss 0.687 Val Acc 49.020
# L 19 Epoch 48 Loss 0.514 Val Acc 49.140
# ==> Saving model ...
# L 19 Epoch 49 Loss 0.572 Val Acc 49.540
# L 19 Epoch 50 Loss 0.414 Val Acc 47.800
# ==> Saving model ...
# L 19 Epoch 51 Loss 0.435 Val Acc 50.560
# L 19 Epoch 52 Loss 0.375 Val Acc 48.600
# ==> Saving model ...
# L 19 Epoch 53 Loss 0.560 Val Acc 50.700
# L 19 Epoch 54 Loss 0.301 Val Acc 50.660
# L 19 Epoch 55 Loss 0.408 Val Acc 50.040
# ==> Saving model ...
# L 19 Epoch 56 Loss 0.272 Val Acc 51.260
# L 19 Epoch 57 Loss 0.410 Val Acc 50.680
# L 19 Epoch 58 Loss 0.384 Val Acc 50.740
# ==> Saving model ...
# L 19 Epoch 59 Loss 0.338 Val Acc 51.400
# L 19 Epoch 60 Loss 0.348 Val Acc 50.220
# ==> Saving model ...
# L 19 Epoch 61 Loss 0.264 Val Acc 52.300
# L 19 Epoch 62 Loss 0.289 Val Acc 49.780
# L 19 Epoch 63 Loss 0.361 Val Acc 50.960
# L 19 Epoch 64 Loss 0.322 Val Acc 49.060
# ==> Saving model ...
# L 19 Epoch 65 Loss 0.273 Val Acc 52.740
# L 19 Epoch 66 Loss 0.227 Val Acc 52.420
# ==> Saving model ...
# L 19 Epoch 67 Loss 0.242 Val Acc 54.840
# L 19 Epoch 68 Loss 0.134 Val Acc 52.320
# L 19 Epoch 69 Loss 0.198 Val Acc 52.900
# L 19 Epoch 70 Loss 0.152 Val Acc 52.240
# L 19 Epoch 71 Loss 0.144 Val Acc 53.420
# L 19 Epoch 72 Loss 0.224 Val Acc 51.420
# L 19 Epoch 73 Loss 0.272 Val Acc 49.780
# L 19 Epoch 74 Loss 0.187 Val Acc 53.340
# L 19 Epoch 75 Loss 0.159 Val Acc 51.480
# L 19 Epoch 76 Loss 0.207 Val Acc 51.960
# L 19 Epoch 77 Loss 0.178 Val Acc 53.380
# L 19 Epoch 78 Loss 0.151 Val Acc 53.880
# L 19 Epoch 79 Loss 0.162 Val Acc 52.740
# L 19 Epoch 80 Loss 0.155 Val Acc 53.780
# L 19 Epoch 81 Loss 0.117 Val Acc 51.900
# L 19 Epoch 82 Loss 0.092 Val Acc 54.160
# L 19 Epoch 83 Loss 0.082 Val Acc 54.400
# L 19 Epoch 84 Loss 0.117 Val Acc 52.800
# ==> Saving model ...
# L 19 Epoch 85 Loss 0.148 Val Acc 55.080
# L 19 Epoch 86 Loss 0.142 Val Acc 52.460
# L 19 Epoch 87 Loss 0.131 Val Acc 51.960
# L 19 Epoch 88 Loss 0.053 Val Acc 54.900
# ==> Saving model ...
# L 19 Epoch 89 Loss 0.050 Val Acc 55.140
# L 19 Epoch 90 Loss 0.087 Val Acc 55.060
# L 19 Epoch 91 Loss 0.105 Val Acc 54.780
# ==> Saving model ...
# L 19 Epoch 92 Loss 0.061 Val Acc 55.480
# L 19 Epoch 93 Loss 0.078 Val Acc 54.160
# L 19 Epoch 94 Loss 0.044 Val Acc 54.240
# L 19 Epoch 95 Loss 0.048 Val Acc 54.980
# ==> Saving model ...
# L 19 Epoch 96 Loss 0.024 Val Acc 55.780
# ==> Saving model ...
# L 19 Epoch 97 Loss 0.069 Val Acc 57.420
# L 19 Epoch 98 Loss 0.082 Val Acc 55.860
# L 19 Epoch 99 Loss 0.066 Val Acc 54.660
# L 19 Epoch 100 Loss 0.069 Val Acc 55.700
# L 19 Epoch 101 Loss 0.061 Val Acc 54.460
# L 19 Epoch 102 Loss 0.053 Val Acc 55.980
# L 19 Epoch 103 Loss 0.103 Val Acc 56.360
# L 19 Epoch 104 Loss 0.036 Val Acc 54.660
# L 19 Epoch 105 Loss 0.082 Val Acc 54.640
# L 19 Epoch 106 Loss 0.065 Val Acc 55.260
# L 19 Epoch 107 Loss 0.076 Val Acc 55.500
# L 19 Epoch 108 Loss 0.089 Val Acc 55.620
# L 19 Epoch 109 Loss 0.076 Val Acc 54.040
# L 19 Epoch 110 Loss 0.072 Val Acc 53.080
# L 19 Epoch 111 Loss 0.070 Val Acc 54.600
# L 19 Epoch 112 Loss 0.042 Val Acc 55.480
# L 19 Epoch 113 Loss 0.048 Val Acc 55.640
# L 19 Epoch 114 Loss 0.075 Val Acc 55.840
# L 19 Epoch 115 Loss 0.060 Val Acc 56.380
# L 19 Epoch 116 Loss 0.036 Val Acc 57.140
# L 19 Epoch 117 Loss 0.035 Val Acc 56.640
# L 19 Epoch 118 Loss 0.027 Val Acc 56.700
# L 19 Epoch 119 Loss 0.068 Val Acc 57.040
# L 19 Epoch 120 Loss 0.036 Val Acc 57.300
# L 19 Epoch 121 Loss 0.042 Val Acc 57.080
# L 19 Epoch 122 Loss 0.048 Val Acc 56.400
# L 19 Epoch 123 Loss 0.028 Val Acc 56.560
# L 19 Epoch 124 Loss 0.038 Val Acc 56.320
# L 19 Epoch 125 Loss 0.042 Val Acc 56.740
# L 19 Epoch 126 Loss 0.017 Val Acc 57.360
# ==> Saving model ...
# L 19 Epoch 127 Loss 0.026 Val Acc 57.460
# L 19 Epoch 128 Loss 0.013 Val Acc 57.100
# L 19 Epoch 129 Loss 0.022 Val Acc 57.060
# L 19 Epoch 130 Loss 0.026 Val Acc 57.020
# L 19 Epoch 131 Loss 0.039 Val Acc 56.520
# L 19 Epoch 132 Loss 0.040 Val Acc 56.700
# L 19 Epoch 133 Loss 0.021 Val Acc 56.740
# L 19 Epoch 134 Loss 0.017 Val Acc 56.780
# L 19 Epoch 135 Loss 0.033 Val Acc 57.120
# L 19 Epoch 136 Loss 0.020 Val Acc 57.120
# ==> Saving model ...
# L 19 Epoch 137 Loss 0.043 Val Acc 57.500
# L 19 Epoch 138 Loss 0.047 Val Acc 57.180
# L 19 Epoch 139 Loss 0.005 Val Acc 57.400
# ==> Saving model ...
# L 19 Epoch 140 Loss 0.019 Val Acc 57.540
# L 19 Epoch 141 Loss 0.025 Val Acc 57.360
# L 19 Epoch 142 Loss 0.029 Val Acc 57.200
# L 19 Epoch 143 Loss 0.030 Val Acc 56.680
# L 19 Epoch 144 Loss 0.034 Val Acc 56.920
# L 19 Epoch 145 Loss 0.023 Val Acc 56.720
# L 19 Epoch 146 Loss 0.011 Val Acc 57.040
# L 19 Epoch 147 Loss 0.014 Val Acc 57.200
# L 19 Epoch 148 Loss 0.025 Val Acc 57.000
# L 19 Epoch 149 Loss 0.024 Val Acc 57.160
# L 19 Epoch 150 Loss 0.024 Val Acc 57.000
# L 19 Epoch 151 Loss 0.011 Val Acc 57.240
# L 19 Epoch 152 Loss 0.030 Val Acc 57.400
# L 19 Epoch 153 Loss 0.038 Val Acc 56.780
# ==> Saving model ...
# L 19 Epoch 154 Loss 0.022 Val Acc 57.560
# L 19 Epoch 155 Loss 0.032 Val Acc 56.960
# L 19 Epoch 156 Loss 0.020 Val Acc 57.180
# L 19 Epoch 157 Loss 0.031 Val Acc 57.320
# L 19 Epoch 158 Loss 0.019 Val Acc 57.500
# L 19 Epoch 159 Loss 0.019 Val Acc 57.520
# L 19 Epoch 160 Loss 0.039 Val Acc 57.440
# ==> Saving model ...
# L 19 Epoch 161 Loss 0.020 Val Acc 57.720
# ==> Saving model ...
# L 19 Epoch 162 Loss 0.011 Val Acc 57.960
# L 19 Epoch 163 Loss 0.020 Val Acc 57.960
# L 19 Epoch 164 Loss 0.042 Val Acc 57.780
# L 19 Epoch 165 Loss 0.014 Val Acc 57.880
# ==> Saving model ...
# L 19 Epoch 166 Loss 0.013 Val Acc 57.980
# ==> Saving model ...
# L 19 Epoch 167 Loss 0.011 Val Acc 58.440
# L 19 Epoch 168 Loss 0.034 Val Acc 58.200
# L 19 Epoch 169 Loss 0.013 Val Acc 58.200
# L 19 Epoch 170 Loss 0.011 Val Acc 58.340
# L 19 Epoch 171 Loss 0.020 Val Acc 58.120
# L 19 Epoch 172 Loss 0.003 Val Acc 58.160
# L 19 Epoch 173 Loss 0.009 Val Acc 58.300
# ==> Saving model ...
# L 19 Epoch 174 Loss 0.019 Val Acc 58.460
# ==> Saving model ...
# L 19 Epoch 175 Loss 0.009 Val Acc 58.560
# L 19 Epoch 176 Loss 0.016 Val Acc 58.560
# ==> Saving model ...
# L 19 Epoch 177 Loss 0.003 Val Acc 58.760
# L 19 Epoch 178 Loss 0.006 Val Acc 58.640
# L 19 Epoch 179 Loss 0.010 Val Acc 58.700
# L 19 Epoch 180 Loss 0.014 Val Acc 58.580
# L 19 Epoch 181 Loss 0.017 Val Acc 58.480
# L 19 Epoch 182 Loss 0.009 Val Acc 58.620
# L 19 Epoch 183 Loss 0.014 Val Acc 58.560
# L 19 Epoch 184 Loss 0.008 Val Acc 58.520
# L 19 Epoch 185 Loss 0.019 Val Acc 58.500
# L 19 Epoch 186 Loss 0.014 Val Acc 58.460
# ==> Saving model ...
# L 19 Epoch 187 Loss 0.010 Val Acc 58.860
# L 19 Epoch 188 Loss 0.013 Val Acc 58.340
# L 19 Epoch 189 Loss 0.010 Val Acc 58.860
# ==> Saving model ...
# L 19 Epoch 190 Loss 0.008 Val Acc 58.900
# L 19 Epoch 191 Loss 0.019 Val Acc 58.180
# L 19 Epoch 192 Loss 0.007 Val Acc 58.660
# L 19 Epoch 193 Loss 0.014 Val Acc 58.600
# L 19 Epoch 194 Loss 0.012 Val Acc 58.660
# L 19 Epoch 195 Loss 0.010 Val Acc 58.600
# L 19 Epoch 196 Loss 0.017 Val Acc 57.920
# L 19 Epoch 197 Loss 0.004 Val Acc 58.560
# L 19 Epoch 198 Loss 0.008 Val Acc 58.540
# L 19 Epoch 199 Loss 0.023 Val Acc 57.960
# L 20 Epoch 0 Loss 4.028 Val Acc 16.320
# L 20 Epoch 1 Loss 2.931 Val Acc 10.040
# L 20 Epoch 2 Loss 2.441 Val Acc 10.000
# L 20 Epoch 3 Loss 2.298 Val Acc 10.020
# L 20 Epoch 4 Loss 1.997 Val Acc 14.740
# L 20 Epoch 5 Loss 1.913 Val Acc 10.440
# L 20 Epoch 6 Loss 1.813 Val Acc 13.440
# L 20 Epoch 7 Loss 1.763 Val Acc 15.520
# L 20 Epoch 8 Loss 1.657 Val Acc 31.540
# L 20 Epoch 9 Loss 1.645 Val Acc 36.340
# L 20 Epoch 10 Loss 1.583 Val Acc 35.660
# L 20 Epoch 11 Loss 1.577 Val Acc 29.000
# L 20 Epoch 12 Loss 1.541 Val Acc 24.920
# L 20 Epoch 13 Loss 1.477 Val Acc 34.280
# L 20 Epoch 14 Loss 1.391 Val Acc 39.640
# L 20 Epoch 15 Loss 1.439 Val Acc 38.400
# ==> Saving model ...
# L 20 Epoch 16 Loss 1.370 Val Acc 42.840
# L 20 Epoch 17 Loss 1.321 Val Acc 35.000
# ==> Saving model ...
# L 20 Epoch 18 Loss 1.244 Val Acc 43.380
# L 20 Epoch 19 Loss 1.218 Val Acc 43.260
# L 20 Epoch 20 Loss 1.153 Val Acc 35.100
# ==> Saving model ...
# L 20 Epoch 21 Loss 1.196 Val Acc 44.580
# L 20 Epoch 22 Loss 1.231 Val Acc 44.400
# ==> Saving model ...
# L 20 Epoch 23 Loss 1.257 Val Acc 44.980
# L 20 Epoch 24 Loss 1.089 Val Acc 34.640
# L 20 Epoch 25 Loss 1.003 Val Acc 40.800
# L 20 Epoch 26 Loss 1.043 Val Acc 40.980
# L 20 Epoch 27 Loss 0.992 Val Acc 40.960
# L 20 Epoch 28 Loss 1.000 Val Acc 41.960
# L 20 Epoch 29 Loss 0.918 Val Acc 44.320
# L 20 Epoch 30 Loss 0.800 Val Acc 40.380
# ==> Saving model ...
# L 20 Epoch 31 Loss 0.945 Val Acc 45.020
# L 20 Epoch 32 Loss 0.840 Val Acc 44.180
# ==> Saving model ...
# L 20 Epoch 33 Loss 0.854 Val Acc 48.060
# L 20 Epoch 34 Loss 0.758 Val Acc 47.620
# L 20 Epoch 35 Loss 0.742 Val Acc 44.780
# L 20 Epoch 36 Loss 0.866 Val Acc 44.640
# ==> Saving model ...
# L 20 Epoch 37 Loss 0.749 Val Acc 50.560
# L 20 Epoch 38 Loss 0.672 Val Acc 49.200
# L 20 Epoch 39 Loss 0.634 Val Acc 46.140
# L 20 Epoch 40 Loss 0.694 Val Acc 49.980
# L 20 Epoch 41 Loss 0.572 Val Acc 48.840
# L 20 Epoch 42 Loss 0.630 Val Acc 43.700
# L 20 Epoch 43 Loss 0.517 Val Acc 48.440
# L 20 Epoch 44 Loss 0.505 Val Acc 50.000
# L 20 Epoch 45 Loss 0.471 Val Acc 45.200
# L 20 Epoch 46 Loss 0.488 Val Acc 47.400
# L 20 Epoch 47 Loss 0.348 Val Acc 49.760
# L 20 Epoch 48 Loss 0.423 Val Acc 49.080
# L 20 Epoch 49 Loss 0.435 Val Acc 48.940
# ==> Saving model ...
# L 20 Epoch 50 Loss 0.330 Val Acc 50.680
# ==> Saving model ...
# L 20 Epoch 51 Loss 0.315 Val Acc 51.500
# L 20 Epoch 52 Loss 0.265 Val Acc 48.380
# L 20 Epoch 53 Loss 0.270 Val Acc 50.480
# L 20 Epoch 54 Loss 0.318 Val Acc 47.220
# L 20 Epoch 55 Loss 0.290 Val Acc 49.940
# L 20 Epoch 56 Loss 0.338 Val Acc 50.860
# ==> Saving model ...
# L 20 Epoch 57 Loss 0.393 Val Acc 52.200
# L 20 Epoch 58 Loss 0.210 Val Acc 52.160
# L 20 Epoch 59 Loss 0.240 Val Acc 50.560
# ==> Saving model ...
# L 20 Epoch 60 Loss 0.211 Val Acc 53.360
# L 20 Epoch 61 Loss 0.220 Val Acc 49.280
# L 20 Epoch 62 Loss 0.138 Val Acc 48.940
# L 20 Epoch 63 Loss 0.208 Val Acc 51.940
# L 20 Epoch 64 Loss 0.122 Val Acc 51.280
# L 20 Epoch 65 Loss 0.200 Val Acc 51.080
# L 20 Epoch 66 Loss 0.257 Val Acc 50.440
# L 20 Epoch 67 Loss 0.171 Val Acc 52.160
# L 20 Epoch 68 Loss 0.208 Val Acc 52.440
# L 20 Epoch 69 Loss 0.202 Val Acc 51.120
# L 20 Epoch 70 Loss 0.181 Val Acc 50.740
# L 20 Epoch 71 Loss 0.215 Val Acc 51.360
# L 20 Epoch 72 Loss 0.158 Val Acc 51.740
# L 20 Epoch 73 Loss 0.184 Val Acc 51.600
# L 20 Epoch 74 Loss 0.160 Val Acc 52.480
# L 20 Epoch 75 Loss 0.167 Val Acc 50.940
# L 20 Epoch 76 Loss 0.131 Val Acc 52.700
# L 20 Epoch 77 Loss 0.168 Val Acc 51.300
# L 20 Epoch 78 Loss 0.177 Val Acc 50.300
# L 20 Epoch 79 Loss 0.153 Val Acc 52.640
# L 20 Epoch 80 Loss 0.181 Val Acc 52.780
# L 20 Epoch 81 Loss 0.063 Val Acc 52.540
# ==> Saving model ...
# L 20 Epoch 82 Loss 0.103 Val Acc 54.740
# L 20 Epoch 83 Loss 0.132 Val Acc 53.880
# L 20 Epoch 84 Loss 0.095 Val Acc 53.360
# L 20 Epoch 85 Loss 0.080 Val Acc 54.740
# L 20 Epoch 86 Loss 0.122 Val Acc 52.100
# L 20 Epoch 87 Loss 0.095 Val Acc 53.780
# L 20 Epoch 88 Loss 0.149 Val Acc 52.660
# L 20 Epoch 89 Loss 0.075 Val Acc 53.920
# L 20 Epoch 90 Loss 0.121 Val Acc 53.980
# L 20 Epoch 91 Loss 0.070 Val Acc 51.400
# ==> Saving model ...
# L 20 Epoch 92 Loss 0.106 Val Acc 54.960
# L 20 Epoch 93 Loss 0.082 Val Acc 54.900
# L 20 Epoch 94 Loss 0.102 Val Acc 53.260
# L 20 Epoch 95 Loss 0.074 Val Acc 53.220
# L 20 Epoch 96 Loss 0.129 Val Acc 52.500
# L 20 Epoch 97 Loss 0.059 Val Acc 54.540
# L 20 Epoch 98 Loss 0.050 Val Acc 53.960
# ==> Saving model ...
# L 20 Epoch 99 Loss 0.058 Val Acc 55.100
# L 20 Epoch 100 Loss 0.062 Val Acc 54.400
# L 20 Epoch 101 Loss 0.084 Val Acc 53.620
# L 20 Epoch 102 Loss 0.080 Val Acc 54.580
# L 20 Epoch 103 Loss 0.042 Val Acc 54.480
# L 20 Epoch 104 Loss 0.056 Val Acc 55.080
# ==> Saving model ...
# L 20 Epoch 105 Loss 0.026 Val Acc 55.140
# L 20 Epoch 106 Loss 0.059 Val Acc 54.640
# L 20 Epoch 107 Loss 0.065 Val Acc 55.040
# L 20 Epoch 108 Loss 0.029 Val Acc 54.760
# L 20 Epoch 109 Loss 0.049 Val Acc 53.800
# L 20 Epoch 110 Loss 0.050 Val Acc 54.920
# ==> Saving model ...
# L 20 Epoch 111 Loss 0.034 Val Acc 55.880
# L 20 Epoch 112 Loss 0.049 Val Acc 54.260
# L 20 Epoch 113 Loss 0.046 Val Acc 55.660
# ==> Saving model ...
# L 20 Epoch 114 Loss 0.044 Val Acc 56.140
# L 20 Epoch 115 Loss 0.032 Val Acc 55.220
# L 20 Epoch 116 Loss 0.043 Val Acc 55.200
# L 20 Epoch 117 Loss 0.021 Val Acc 55.240
# L 20 Epoch 118 Loss 0.043 Val Acc 55.140
# L 20 Epoch 119 Loss 0.045 Val Acc 55.860
# L 20 Epoch 120 Loss 0.032 Val Acc 55.000
# L 20 Epoch 121 Loss 0.036 Val Acc 55.420
# L 20 Epoch 122 Loss 0.035 Val Acc 55.440
# L 20 Epoch 123 Loss 0.020 Val Acc 55.860
# L 20 Epoch 124 Loss 0.046 Val Acc 56.020
# L 20 Epoch 125 Loss 0.016 Val Acc 55.720
# L 20 Epoch 126 Loss 0.033 Val Acc 56.000
# L 20 Epoch 127 Loss 0.027 Val Acc 55.540
# L 20 Epoch 128 Loss 0.033 Val Acc 55.200
# L 20 Epoch 129 Loss 0.012 Val Acc 56.100
# L 20 Epoch 130 Loss 0.024 Val Acc 56.040
# L 20 Epoch 131 Loss 0.027 Val Acc 55.880
# ==> Saving model ...
# L 20 Epoch 132 Loss 0.030 Val Acc 56.640
# L 20 Epoch 133 Loss 0.014 Val Acc 56.200
# L 20 Epoch 134 Loss 0.042 Val Acc 55.580
# L 20 Epoch 135 Loss 0.022 Val Acc 55.540
# L 20 Epoch 136 Loss 0.010 Val Acc 56.080
# L 20 Epoch 137 Loss 0.013 Val Acc 56.260
# ==> Saving model ...
# L 20 Epoch 138 Loss 0.018 Val Acc 56.860
# ==> Saving model ...
# L 20 Epoch 139 Loss 0.016 Val Acc 56.920
# L 20 Epoch 140 Loss 0.017 Val Acc 56.340
# L 20 Epoch 141 Loss 0.009 Val Acc 56.140
# L 20 Epoch 142 Loss 0.012 Val Acc 56.500
# L 20 Epoch 143 Loss 0.009 Val Acc 56.640
# L 20 Epoch 144 Loss 0.025 Val Acc 56.720
# ==> Saving model ...
# L 20 Epoch 145 Loss 0.020 Val Acc 56.940
# ==> Saving model ...
# L 20 Epoch 146 Loss 0.021 Val Acc 57.320
# L 20 Epoch 147 Loss 0.028 Val Acc 56.300
# L 20 Epoch 148 Loss 0.016 Val Acc 55.780
# L 20 Epoch 149 Loss 0.029 Val Acc 56.580
# L 20 Epoch 150 Loss 0.016 Val Acc 56.200
# L 20 Epoch 151 Loss 0.011 Val Acc 56.900
# L 20 Epoch 152 Loss 0.008 Val Acc 56.660
# L 20 Epoch 153 Loss 0.019 Val Acc 56.420
# L 20 Epoch 154 Loss 0.011 Val Acc 56.640
# L 20 Epoch 155 Loss 0.016 Val Acc 56.260
# L 20 Epoch 156 Loss 0.009 Val Acc 56.080
# L 20 Epoch 157 Loss 0.014 Val Acc 56.400
# L 20 Epoch 158 Loss 0.001 Val Acc 56.780
# L 20 Epoch 159 Loss 0.014 Val Acc 56.800
# L 20 Epoch 160 Loss 0.016 Val Acc 56.620
# L 20 Epoch 161 Loss 0.011 Val Acc 56.560
# L 20 Epoch 162 Loss 0.012 Val Acc 57.080
# L 20 Epoch 163 Loss 0.004 Val Acc 57.060
# L 20 Epoch 164 Loss 0.010 Val Acc 57.020
# L 20 Epoch 165 Loss 0.014 Val Acc 57.020
# L 20 Epoch 166 Loss 0.006 Val Acc 57.260
# L 20 Epoch 167 Loss 0.020 Val Acc 57.160
# L 20 Epoch 168 Loss 0.007 Val Acc 57.280
# L 20 Epoch 169 Loss 0.014 Val Acc 56.900
# L 20 Epoch 170 Loss 0.010 Val Acc 57.020
# L 20 Epoch 171 Loss 0.012 Val Acc 56.600
# L 20 Epoch 172 Loss 0.004 Val Acc 57.240
# L 20 Epoch 173 Loss 0.012 Val Acc 57.220
# L 20 Epoch 174 Loss 0.015 Val Acc 56.660
# L 20 Epoch 175 Loss 0.009 Val Acc 56.900
# L 20 Epoch 176 Loss 0.007 Val Acc 57.220
# ==> Saving model ...
# L 20 Epoch 177 Loss 0.011 Val Acc 57.480
# L 20 Epoch 178 Loss 0.012 Val Acc 56.680
# L 20 Epoch 179 Loss 0.004 Val Acc 57.240
# L 20 Epoch 180 Loss 0.014 Val Acc 56.980
# L 20 Epoch 181 Loss 0.015 Val Acc 56.800
# L 20 Epoch 182 Loss 0.013 Val Acc 56.960
# L 20 Epoch 183 Loss 0.008 Val Acc 57.240
# L 20 Epoch 184 Loss 0.012 Val Acc 57.120
# L 20 Epoch 185 Loss 0.022 Val Acc 56.900
# L 20 Epoch 186 Loss 0.016 Val Acc 56.720
# L 20 Epoch 187 Loss 0.010 Val Acc 56.760
# L 20 Epoch 188 Loss 0.006 Val Acc 56.800
# L 20 Epoch 189 Loss 0.009 Val Acc 56.840
# L 20 Epoch 190 Loss 0.010 Val Acc 56.920
# L 20 Epoch 191 Loss 0.030 Val Acc 56.080
# L 20 Epoch 192 Loss 0.015 Val Acc 56.500
# L 20 Epoch 193 Loss 0.009 Val Acc 56.500
# L 20 Epoch 194 Loss 0.008 Val Acc 56.360
# L 20 Epoch 195 Loss 0.012 Val Acc 56.700
# L 20 Epoch 196 Loss 0.010 Val Acc 57.000
# L 20 Epoch 197 Loss 0.004 Val Acc 57.420
# L 20 Epoch 198 Loss 0.008 Val Acc 57.180
# L 20 Epoch 199 Loss 0.005 Val Acc 57.160

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
for L in range(1, 21):
    model = ScatResNet18(L).to(device)
    checkpoint = torch.load(checkpoint_dir / f"{MODEL_NAME}_L{L}_max_acc.pth", map_location=device)
    model.load_state_dict(checkpoint['net'])
    model.eval()
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=True)
    print(f'Final test accuracy for L {L} is: {calculate_accuracy(model, testloader, device):.3f}')
# Out:
# Final test accuracy for L 1 is: 49.670
# Final test accuracy for L 2 is: 54.760
# Final test accuracy for L 3 is: 54.760
# Final test accuracy for L 4 is: 61.840
# Final test accuracy for L 5 is: 55.920
# Final test accuracy for L 6 is: 55.280
# Final test accuracy for L 7 is: 59.210
# Final test accuracy for L 8 is: 57.640
# Final test accuracy for L 9 is: 55.550
# Final test accuracy for L 10 is: 61.690
# Final test accuracy for L 11 is: 55.840
# Final test accuracy for L 12 is: 58.270
# Final test accuracy for L 13 is: 57.800
# Final test accuracy for L 14 is: 56.550
# Final test accuracy for L 15 is: 55.680
# Final test accuracy for L 16 is: 57.170
# Final test accuracy for L 17 is: 56.600
# Final test accuracy for L 18 is: 55.790
# Final test accuracy for L 19 is: 58.220
# Final test accuracy for L 20 is: 57.430

# %%
for L in range(1,21):
    stats = stats_list[L - 1]
    total_params, model_size_mb = get_model_summary(ScatResNet18(L))
    stats['total_params'] = total_params
    stats['model_size_mb'] = model_size_mb
    stats['train_acc'] = calculate_accuracy(model, trainloader, device)
    stats['val_acc'] = calculate_accuracy(model, valloader, device)
    stats['test_acc'] = calculate_accuracy(model, testloader, device)
    
    with open(training_stats_dir / f'{MODEL_NAME}_L{L}_stats.pkl', 'wb') as file:
        pickle.dump(stats, file)
