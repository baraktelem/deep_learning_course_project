# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms

# !pip install kornia
from kornia import augmentation as K
from kornia.augmentation import AugmentationSequential
from torch.utils.data import random_split

import numpy as np

import os
import time
from pathlib import Path
import pickle

from torch.utils.data import Subset
from sklearn.model_selection import train_test_split

DEBUG = False
MODEL_NAME = "baseline_500"
TRAIN_SIZE = 5000
VALIDATION_SIZE = 5000
env = 'kaggle' # 'kaggle' or 'colab'

if env == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')
    base_dir = Path('/content/drive/MyDrive/dl_pj')    
elif env == 'kaggle':
    base_dir = Path('/kaggle/working/')

checkpoint_dir = base_dir / 'checkpoints'
checkpoint_dir.mkdir(parents=True, exist_ok=True)
training_stats_dir = base_dir / 'stats'
training_stats_dir.mkdir(parents=True, exist_ok=True)
# Out:
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia) (0.1.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from kornia) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->kornia) (3.0.3)

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes,kernel_size=1,stride=stride,bias=False),
                nn.BatchNorm2d(planes)
            )


    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out



class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layer = []
        for s in strides:
            layer.append(block(self.in_planes, planes, s))
            self.in_planes = planes
        return nn.Sequential(*layer)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
def get_model_summary(model):
    num_params = sum(p.numel() for p in model.parameters())
    total_bytes = sum(p.numel() * p.element_size() for p in model.parameters())
    size_mb = total_bytes / (1024 ** 2)
    return num_params, size_mb

total_params, model_size_mb = get_model_summary(ResNet18())
print(f"Total Parameters: {total_params:,}")
print(f"Model Size: {model_size_mb:.2f} MB")
# Out:
# Total Parameters: 11,173,962
# Model Size: 42.63 MB

# %%
def calculate_accuracy(model, dataloader, device):
    model.eval() # put in evaluation mode,  turn off Dropout, BatchNorm uses learned statistics
    total_correct = 0
    total_images = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            images = normalize(images)
            outputs = model(images)
            predictions = torch.argmax(outputs, dim=-1)
            total_images += labels.size(0)
            total_correct += (predictions == labels).sum().item()

    model_accuracy = total_correct / total_images * 100
    return model_accuracy

# %% [markdown]
# Split data set into train-validation-test.
# We are using 80% train, 20% validation split

# %%
transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor()]
)

# 80/20% split
train_val_set = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform
)


targets = np.array(train_val_set.targets)

indices = np.arange(len(targets))
train_indices, remaining_indices = train_test_split(
    indices,
    train_size=TRAIN_SIZE,
    stratify=targets,
    random_state=42
)

validation_indices, _ = train_test_split(
    remaining_indices,
    train_size=VALIDATION_SIZE,
    stratify=targets[remaining_indices],
    random_state=42
)

trainset = Subset(train_val_set, train_indices)
valset = Subset(train_val_set, validation_indices)
print(f"Original size: {len(train_val_set)}")
print(f"Train size: {len(trainset)}")
print(f"Val size: {len(valset)}")

from collections import Counter 
subset_labels = [targets[i] for i in train_indices]
print("Samples per class", Counter(subset_labels))
subset_labels = [targets[i] for i in validation_indices]
print("Samples per class", Counter(subset_labels))

testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform
)
# Out:
# 100%|██████████| 170M/170M [00:12<00:00, 13.9MB/s]
# Original size: 50000
# Train size: 5000
# Val size: 5000
# Samples per class Counter({np.int64(4): 500, np.int64(7): 500, np.int64(3): 500, np.int64(1): 500, np.int64(2): 500, np.int64(8): 500, np.int64(5): 500, np.int64(0): 500, np.int64(9): 500, np.int64(6): 500})
# Samples per class Counter({np.int64(5): 500, np.int64(8): 500, np.int64(2): 500, np.int64(9): 500, np.int64(1): 500, np.int64(3): 500, np.int64(0): 500, np.int64(6): 500, np.int64(7): 500, np.int64(4): 500})

# %%
# Hyperparamters
batch_size = 128

lr = 0.1
momentum = 0.9
weight_decay = 5e-4

T_max = 200

n_epochs = 1 if DEBUG else 200

print_progress_every = 1
val_accuracy_storing_threshold = 50

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
mean = torch.tensor([0.4914, 0.4822, 0.4465]).to(device)
std = torch.tensor([0.2023, 0.1994, 0.2010]).to(device)
normalize = K.Normalize(mean=mean, std=std)
# define a sequence of augmentations
aug_list = AugmentationSequential(
    K.RandomHorizontalFlip(p=0.5),
    K.ColorJitter(0.1, 0.1, 0.1, 0.1, p=0.2),
    K.RandomResizedCrop(size=(32,32), scale=(0.7, 1.0), p=0.5),
    normalize,
    same_on_batch=False
).to(device)


trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=True)
model = ResNet18().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)

stats = {
    'total_training_time': 0,
    'loss': [],
    'time_per_epoch': [],
    'total_time_per_epoch': [],
    'val_accuracy': [],
    'max_val_accuracy': 0,
    'allocated_memory': [], # Memory currently used by Tensors
    'reserved_memory': [], # Memory held by the PyTorch caching allocator
}

start_time = time.time()
for epoch in range(n_epochs):
    model.train()
    iteration_losses = []
    epoch_start_time = time.time()
    for inputs, targets in trainloader:
        inputs = inputs.to(device)
        targets = targets.to(device)

        inputs = aug_list(inputs)

        outputs = model(inputs)

        optimizer.zero_grad()
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        iteration_losses.append(loss.item())

    scheduler.step()
    epoch_end_time = time.time()

    model.eval()
    val_accuracy = calculate_accuracy(model, valloader, device)

    # Track stats
    if (epoch % 1) == 0:
        stats['loss'].append(
            np.mean(iteration_losses)
        )
        stats['val_accuracy'].append(
            val_accuracy
        )
        stats['allocated_memory'].append(torch.cuda.memory_allocated())
        stats['reserved_memory'].append(torch.cuda.memory_reserved())
        stats['time_per_epoch'].append(epoch_end_time - epoch_start_time)
        stats['total_time_per_epoch'].append(time.time() - start_time)

    # Store best model
    if (val_accuracy > stats['max_val_accuracy']):
        if (val_accuracy > val_accuracy_storing_threshold):
            stats['max_val_accuracy'] = val_accuracy
            print('==> Saving model ...')
            state = {
                'net': model.state_dict(),
                'epoch': epoch,
                'acc':val_accuracy
            }
            save_path = checkpoint_dir / f"{MODEL_NAME}_max_acc.pth"
            torch.save(state, save_path)

    if DEBUG:
        print('==> Saving model ... DEBUG')
        state = {
            'net': model.state_dict(),
            'epoch': epoch,
            'acc':val_accuracy
        }
        save_path = checkpoint_dir / f"{MODEL_NAME}_max_acc.pth"
        torch.save(state, save_path)
        
    # Print progress
    if (epoch % print_progress_every) == 0:
        print(f"Epoch {epoch} Loss {stats['loss'][-1]:.3f} Val Acc {stats['val_accuracy'][-1]:.3f}")
# Out:
# Epoch 0 Loss 3.026 Val Acc 17.780
# Epoch 1 Loss 2.169 Val Acc 22.740
# Epoch 2 Loss 1.983 Val Acc 27.300
# Epoch 3 Loss 1.988 Val Acc 29.600
# Epoch 4 Loss 1.943 Val Acc 32.160
# Epoch 5 Loss 1.863 Val Acc 32.400
# Epoch 6 Loss 1.816 Val Acc 33.260
# Epoch 7 Loss 1.812 Val Acc 30.200
# Epoch 8 Loss 1.732 Val Acc 37.780
# Epoch 9 Loss 1.646 Val Acc 35.820
# Epoch 10 Loss 1.667 Val Acc 38.620
# Epoch 11 Loss 1.660 Val Acc 37.520
# Epoch 12 Loss 1.654 Val Acc 38.720
# Epoch 13 Loss 1.574 Val Acc 40.560
# Epoch 14 Loss 1.521 Val Acc 44.260
# Epoch 15 Loss 1.470 Val Acc 43.020
# Epoch 16 Loss 1.429 Val Acc 45.380
# Epoch 17 Loss 1.419 Val Acc 45.020
# Epoch 18 Loss 1.449 Val Acc 47.440
# Epoch 19 Loss 1.369 Val Acc 45.640
# Epoch 20 Loss 1.381 Val Acc 43.920
# Epoch 21 Loss 1.341 Val Acc 45.820
# ==> Saving model ...
# Epoch 22 Loss 1.365 Val Acc 50.580
# ==> Saving model ...
# Epoch 23 Loss 1.256 Val Acc 50.800
# Epoch 24 Loss 1.254 Val Acc 49.500
# ==> Saving model ...
# Epoch 25 Loss 1.172 Val Acc 55.700
# Epoch 26 Loss 1.124 Val Acc 55.300
# Epoch 27 Loss 1.099 Val Acc 48.780
# Epoch 28 Loss 1.150 Val Acc 52.880
# Epoch 29 Loss 1.138 Val Acc 54.000
# ==> Saving model ...
# Epoch 30 Loss 1.053 Val Acc 58.640
# ==> Saving model ...
# Epoch 31 Loss 1.005 Val Acc 58.940
# Epoch 32 Loss 0.931 Val Acc 58.120
# Epoch 33 Loss 0.891 Val Acc 57.200
# Epoch 34 Loss 0.922 Val Acc 57.760
# ==> Saving model ...
# Epoch 35 Loss 0.928 Val Acc 59.980
# Epoch 36 Loss 0.812 Val Acc 58.760
# Epoch 37 Loss 0.804 Val Acc 56.640
# Epoch 38 Loss 0.802 Val Acc 57.080
# Epoch 39 Loss 0.789 Val Acc 57.160
# Epoch 40 Loss 0.741 Val Acc 57.760
# Epoch 41 Loss 0.812 Val Acc 58.360
# Epoch 42 Loss 0.821 Val Acc 56.820
# ==> Saving model ...
# Epoch 43 Loss 0.705 Val Acc 63.440
# ==> Saving model ...
# Epoch 44 Loss 0.565 Val Acc 64.280
# Epoch 45 Loss 0.624 Val Acc 64.200
# ==> Saving model ...
# Epoch 46 Loss 0.553 Val Acc 67.020
# Epoch 47 Loss 0.523 Val Acc 66.740
# Epoch 48 Loss 0.534 Val Acc 62.520
# Epoch 49 Loss 0.575 Val Acc 64.780
# Epoch 50 Loss 0.489 Val Acc 65.440
# ==> Saving model ...
# Epoch 51 Loss 0.402 Val Acc 67.060
# Epoch 52 Loss 0.443 Val Acc 66.380
# Epoch 53 Loss 0.447 Val Acc 59.520
# Epoch 54 Loss 0.572 Val Acc 64.280
# Epoch 55 Loss 0.515 Val Acc 66.740
# ==> Saving model ...
# Epoch 56 Loss 0.487 Val Acc 68.840
# Epoch 57 Loss 0.364 Val Acc 65.240
# ==> Saving model ...
# Epoch 58 Loss 0.441 Val Acc 68.940
# ==> Saving model ...
# Epoch 59 Loss 0.303 Val Acc 69.340
# ==> Saving model ...
# Epoch 60 Loss 0.349 Val Acc 70.300
# Epoch 61 Loss 0.296 Val Acc 64.800
# Epoch 62 Loss 0.446 Val Acc 67.940
# Epoch 63 Loss 0.370 Val Acc 68.160
# Epoch 64 Loss 0.291 Val Acc 68.160
# Epoch 65 Loss 0.302 Val Acc 69.500
# Epoch 66 Loss 0.402 Val Acc 68.620
# ==> Saving model ...
# Epoch 67 Loss 0.307 Val Acc 70.660
# Epoch 68 Loss 0.299 Val Acc 65.020
# Epoch 69 Loss 0.462 Val Acc 68.300
# Epoch 70 Loss 0.339 Val Acc 68.600
# Epoch 71 Loss 0.298 Val Acc 67.840
# Epoch 72 Loss 0.388 Val Acc 69.600
# Epoch 73 Loss 0.359 Val Acc 68.160
# Epoch 74 Loss 0.381 Val Acc 66.600
# Epoch 75 Loss 0.408 Val Acc 67.060
# ==> Saving model ...
# Epoch 76 Loss 0.282 Val Acc 71.760
# Epoch 77 Loss 0.246 Val Acc 69.600
# Epoch 78 Loss 0.212 Val Acc 70.620
# Epoch 79 Loss 0.558 Val Acc 68.300
# ==> Saving model ...
# Epoch 80 Loss 0.234 Val Acc 71.800
# Epoch 81 Loss 0.227 Val Acc 67.680
# Epoch 82 Loss 0.237 Val Acc 68.320
# ==> Saving model ...
# Epoch 83 Loss 0.164 Val Acc 72.280
# ==> Saving model ...
# Epoch 84 Loss 0.130 Val Acc 72.440
# Epoch 85 Loss 0.216 Val Acc 69.260
# Epoch 86 Loss 0.141 Val Acc 70.720
# Epoch 87 Loss 0.185 Val Acc 71.380
# Epoch 88 Loss 0.164 Val Acc 70.540
# Epoch 89 Loss 0.329 Val Acc 67.440
# Epoch 90 Loss 0.192 Val Acc 69.160
# Epoch 91 Loss 0.252 Val Acc 68.400
# Epoch 92 Loss 0.211 Val Acc 71.340
# Epoch 93 Loss 0.332 Val Acc 67.320
# Epoch 94 Loss 0.216 Val Acc 69.960
# Epoch 95 Loss 0.193 Val Acc 71.440
# Epoch 96 Loss 0.130 Val Acc 71.320
# Epoch 97 Loss 0.145 Val Acc 72.220
# Epoch 98 Loss 0.224 Val Acc 70.080
# Epoch 99 Loss 0.243 Val Acc 68.400
# Epoch 100 Loss 0.303 Val Acc 71.300
# Epoch 101 Loss 0.234 Val Acc 69.680
# Epoch 102 Loss 0.236 Val Acc 72.040
# Epoch 103 Loss 0.125 Val Acc 72.180
# Epoch 104 Loss 0.186 Val Acc 72.180
# ==> Saving model ...
# Epoch 105 Loss 0.286 Val Acc 72.840
# Epoch 106 Loss 0.129 Val Acc 72.360
# ==> Saving model ...
# Epoch 107 Loss 0.113 Val Acc 73.540
# Epoch 108 Loss 0.143 Val Acc 72.840
# Epoch 109 Loss 0.229 Val Acc 72.180
# Epoch 110 Loss 0.133 Val Acc 71.540
# Epoch 111 Loss 0.191 Val Acc 69.900
# Epoch 112 Loss 0.254 Val Acc 73.120
# Epoch 113 Loss 0.142 Val Acc 72.280
# Epoch 114 Loss 0.085 Val Acc 72.980
# ==> Saving model ...
# Epoch 115 Loss 0.083 Val Acc 74.080
# ==> Saving model ...
# Epoch 116 Loss 0.061 Val Acc 74.480
# Epoch 117 Loss 0.075 Val Acc 72.960
# Epoch 118 Loss 0.103 Val Acc 73.260
# Epoch 119 Loss 0.101 Val Acc 74.160
# Epoch 120 Loss 0.077 Val Acc 73.380
# Epoch 121 Loss 0.108 Val Acc 73.960
# Epoch 122 Loss 0.126 Val Acc 73.660
# Epoch 123 Loss 0.086 Val Acc 73.160
# ==> Saving model ...
# Epoch 124 Loss 0.061 Val Acc 74.740
# Epoch 125 Loss 0.101 Val Acc 73.260
# Epoch 126 Loss 0.149 Val Acc 72.640
# Epoch 127 Loss 0.088 Val Acc 73.980
# Epoch 128 Loss 0.074 Val Acc 72.960
# Epoch 129 Loss 0.132 Val Acc 72.920
# Epoch 130 Loss 0.079 Val Acc 74.380
# Epoch 131 Loss 0.081 Val Acc 74.240
# Epoch 132 Loss 0.085 Val Acc 73.920
# Epoch 133 Loss 0.126 Val Acc 73.160
# Epoch 134 Loss 0.076 Val Acc 74.500
# Epoch 135 Loss 0.060 Val Acc 74.160
# ==> Saving model ...
# Epoch 136 Loss 0.047 Val Acc 75.840
# Epoch 137 Loss 0.055 Val Acc 73.200
# Epoch 138 Loss 0.042 Val Acc 74.780
# Epoch 139 Loss 0.062 Val Acc 74.860
# Epoch 140 Loss 0.068 Val Acc 74.060
# Epoch 141 Loss 0.063 Val Acc 74.720
# Epoch 142 Loss 0.075 Val Acc 73.860
# Epoch 143 Loss 0.054 Val Acc 75.500
# Epoch 144 Loss 0.052 Val Acc 75.500
# Epoch 145 Loss 0.047 Val Acc 74.700
# Epoch 146 Loss 0.067 Val Acc 75.200
# Epoch 147 Loss 0.063 Val Acc 74.740
# Epoch 148 Loss 0.057 Val Acc 74.760
# Epoch 149 Loss 0.032 Val Acc 75.580
# Epoch 150 Loss 0.031 Val Acc 75.360
# Epoch 151 Loss 0.036 Val Acc 75.200
# ==> Saving model ...
# Epoch 152 Loss 0.025 Val Acc 76.740
# Epoch 153 Loss 0.029 Val Acc 75.780
# Epoch 154 Loss 0.035 Val Acc 74.640
# Epoch 155 Loss 0.036 Val Acc 76.440
# Epoch 156 Loss 0.056 Val Acc 75.900
# Epoch 157 Loss 0.054 Val Acc 76.200
# Epoch 158 Loss 0.041 Val Acc 76.380
# Epoch 159 Loss 0.025 Val Acc 75.960
# Epoch 160 Loss 0.038 Val Acc 76.700
# Epoch 161 Loss 0.038 Val Acc 75.540
# Epoch 162 Loss 0.023 Val Acc 75.600
# Epoch 163 Loss 0.024 Val Acc 76.040
# Epoch 164 Loss 0.019 Val Acc 75.920
# Epoch 165 Loss 0.075 Val Acc 75.560
# Epoch 166 Loss 0.035 Val Acc 75.340
# Epoch 167 Loss 0.033 Val Acc 75.860
# Epoch 168 Loss 0.027 Val Acc 75.080
# Epoch 169 Loss 0.024 Val Acc 75.600
# Epoch 170 Loss 0.030 Val Acc 75.760
# Epoch 171 Loss 0.027 Val Acc 75.460
# Epoch 172 Loss 0.020 Val Acc 76.320
# Epoch 173 Loss 0.020 Val Acc 76.340
# Epoch 174 Loss 0.017 Val Acc 76.620
# Epoch 175 Loss 0.015 Val Acc 76.500
# Epoch 176 Loss 0.014 Val Acc 75.460
# ==> Saving model ...
# Epoch 177 Loss 0.021 Val Acc 76.880
# Epoch 178 Loss 0.018 Val Acc 76.620
# Epoch 179 Loss 0.029 Val Acc 75.420
# Epoch 180 Loss 0.015 Val Acc 76.580
# Epoch 181 Loss 0.013 Val Acc 76.620
# Epoch 182 Loss 0.021 Val Acc 76.580
# Epoch 183 Loss 0.028 Val Acc 75.980
# Epoch 184 Loss 0.025 Val Acc 76.020
# Epoch 185 Loss 0.015 Val Acc 75.940
# Epoch 186 Loss 0.018 Val Acc 75.940
# Epoch 187 Loss 0.029 Val Acc 75.880
# Epoch 188 Loss 0.026 Val Acc 75.540
# Epoch 189 Loss 0.016 Val Acc 76.460
# Epoch 190 Loss 0.014 Val Acc 76.220
# Epoch 191 Loss 0.017 Val Acc 75.760
# Epoch 192 Loss 0.018 Val Acc 76.080
# Epoch 193 Loss 0.017 Val Acc 75.800
# Epoch 194 Loss 0.020 Val Acc 76.220
# Epoch 195 Loss 0.023 Val Acc 76.320
# ==> Saving model ...
# Epoch 196 Loss 0.010 Val Acc 76.900
# Epoch 197 Loss 0.017 Val Acc 76.000
# Epoch 198 Loss 0.011 Val Acc 76.840
# Epoch 199 Loss 0.016 Val Acc 76.560

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = ResNet18().to(device)
checkpoint = torch.load(checkpoint_dir / f"{MODEL_NAME}_max_acc.pth", map_location=device)
model.load_state_dict(checkpoint['net'])
model.eval()
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=True)
print(f'Final test accuracy is: {calculate_accuracy(model, testloader, device):.3f}')
# Out:
# Final test accuracy is: 77.020

# %%
with open(training_stats_dir / f'{MODEL_NAME}_stats.pkl', 'wb') as file:
    pickle.dump(stats, file)
